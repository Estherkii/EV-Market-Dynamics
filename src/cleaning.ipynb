# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Cleaning EV database

# %%
ev = pd.read_csv(r"C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\ev_population_data.csv", encoding='latin1')
ev.head()
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year    Make  \
# 0  5YJ3E1EA0K   Thurston   Tumwater    WA      98512.0        2019   TESLA
# 1  1N4BZ1DV4N     Island    Clinton    WA      98236.0        2022  NISSAN
# 2  5YJ3E1EA0L  Snohomish  Snohomish    WA      98290.0        2020   TESLA
# 3  5YJ3E1EBXL       King    Seattle    WA      98134.0        2020   TESLA
# 4  5YJSA1CP0D  Snohomish    Edmonds    WA      98020.0        2013   TESLA
#
#      Model           Electric Vehicle Type  \
# 0  MODEL 3  Battery Electric Vehicle (BEV)
# 1     LEAF  Battery Electric Vehicle (BEV)
# 2  MODEL 3  Battery Electric Vehicle (BEV)
# 3  MODEL 3  Battery Electric Vehicle (BEV)
# 4  MODEL S  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible           220.0
# 1  Eligibility unknown as battery range has not b...             0.0
# 2            Clean Alternative Fuel Vehicle Eligible           266.0
# 3            Clean Alternative Fuel Vehicle Eligible           322.0
# 4            Clean Alternative Fuel Vehicle Eligible           208.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  22.0       242565116
# 1        0.0                  10.0       183272785
# 2        0.0                  44.0       112552366
# 3        0.0                  11.0         6336319
# 4    69900.0                  21.0       186212960
#
#                                  Vehicle Location  \
# 0   POINT (-122.91310169999997 47.01359260000004)
# 1   POINT (-122.35936399999997 47.97965520000008)
# 2   POINT (-122.09150499999998 47.91555500000004)
# 3  POINT (-122.32981499999994 47.579810000000066)
# 4            POINT (-122.37507 47.80807000000004)
#
#                                Electric Utility  2020 Census Tract
# 0                        PUGET SOUND ENERGY INC       5.306701e+10
# 1                        PUGET SOUND ENERGY INC       5.302997e+10
# 2                        PUGET SOUND ENERGY INC       5.306105e+10
# 3  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 4                        PUGET SOUND ENERGY INC       5.306105e+10

# %%
ev.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  135030.000000  135038.000000   135037.000000  135037.000000
# mean    98171.001577    2019.662880       74.591964    1448.407325
# std      2450.367211       3.001676       98.744120    9683.658138
# min      1730.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2018.000000        0.000000       0.000000
# 50%     98121.000000    2021.000000       21.000000       0.000000
# 75%     98370.000000    2022.000000      150.000000       0.000000
# max     99701.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         134726.000000    1.350380e+05       1.350300e+05
# mean              29.504379    2.063432e+08       5.297233e+10
# std               14.783780    8.582417e+07       1.635783e+09
# min                1.000000    4.385000e+03       1.081042e+09
# 25%               18.000000    1.606305e+08       5.303301e+10
# 50%               34.000000    2.059563e+08       5.303303e+10
# 75%               43.000000    2.308888e+08       5.305307e+10
# max               49.000000    4.792548e+08       5.603300e+10

# %%
ev.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 8
# City                                                   8
# State                                                  0
# Postal Code                                            8
# Model Year                                             0
# Make                                                   0
# Model                                                249
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         1
# Base MSRP                                              1
# Legislative District                                 312
# DOL Vehicle ID                                         0
# Vehicle Location                                      10
# Electric Utility                                       8
# 2020 Census Tract                                      8
# dtype: int64

# %%
ev.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                       float64
# Base MSRP                                            float64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# Electric Utility                                      object
# 2020 Census Tract                                    float64
# dtype: object

# %%
ev['Postal Code'] = ev['Postal Code'].astype(str)
ev['2020 Census Tract'] = ev['2020 Census Tract'].astype(str)

# %% [markdown]
# ### change column

# %%
ev = ev.drop('VIN (1-10)', axis=1)

# %%
ev.columns = [col.lower().replace(' ', '_') for col in ev.columns]

# %%
ev = ev.rename(columns={'clean_alternative_fuel_vehicle_(cafv)_eligibility':'cafv_eligibility'})
ev.head()
# Out:
#       county       city state postal_code  model_year    make    model  \
# 0   Thurston   Tumwater    WA     98512.0        2019   TESLA  MODEL 3
# 1     Island    Clinton    WA     98236.0        2022  NISSAN     LEAF
# 2  Snohomish  Snohomish    WA     98290.0        2020   TESLA  MODEL 3
# 3       King    Seattle    WA     98134.0        2020   TESLA  MODEL 3
# 4  Snohomish    Edmonds    WA     98020.0        2013   TESLA  MODEL S
#
#             electric_vehicle_type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
# 2  Battery Electric Vehicle (BEV)
# 3  Battery Electric Vehicle (BEV)
# 4  Battery Electric Vehicle (BEV)
#
#                                     cafv_eligibility  electric_range  \
# 0            Clean Alternative Fuel Vehicle Eligible           220.0
# 1  Eligibility unknown as battery range has not b...             0.0
# 2            Clean Alternative Fuel Vehicle Eligible           266.0
# 3            Clean Alternative Fuel Vehicle Eligible           322.0
# 4            Clean Alternative Fuel Vehicle Eligible           208.0
#
#    base_msrp  legislative_district  dol_vehicle_id  \
# 0        0.0                  22.0       242565116
# 1        0.0                  10.0       183272785
# 2        0.0                  44.0       112552366
# 3        0.0                  11.0         6336319
# 4    69900.0                  21.0       186212960
#
#                                  vehicle_location  \
# 0   POINT (-122.91310169999997 47.01359260000004)
# 1   POINT (-122.35936399999997 47.97965520000008)
# 2   POINT (-122.09150499999998 47.91555500000004)
# 3  POINT (-122.32981499999994 47.579810000000066)
# 4            POINT (-122.37507 47.80807000000004)
#
#                                electric_utility 2020_census_tract
# 0                        PUGET SOUND ENERGY INC     53067010910.0
# 1                        PUGET SOUND ENERGY INC     53029972000.0
# 2                        PUGET SOUND ENERGY INC     53061052502.0
# 3  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)     53033009300.0
# 4                        PUGET SOUND ENERGY INC     53061050403.0

# %%
ev['country'] = 'USA'
ev.head()
# Out:
#       county       city state postal_code  model_year    make    model  \
# 0   Thurston   Tumwater    WA     98512.0        2019   TESLA  MODEL 3
# 1     Island    Clinton    WA     98236.0        2022  NISSAN     LEAF
# 2  Snohomish  Snohomish    WA     98290.0        2020   TESLA  MODEL 3
# 3       King    Seattle    WA     98134.0        2020   TESLA  MODEL 3
# 4  Snohomish    Edmonds    WA     98020.0        2013   TESLA  MODEL S
#
#             electric_vehicle_type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
# 2  Battery Electric Vehicle (BEV)
# 3  Battery Electric Vehicle (BEV)
# 4  Battery Electric Vehicle (BEV)
#
#                                     cafv_eligibility  electric_range  \
# 0            Clean Alternative Fuel Vehicle Eligible           220.0
# 1  Eligibility unknown as battery range has not b...             0.0
# 2            Clean Alternative Fuel Vehicle Eligible           266.0
# 3            Clean Alternative Fuel Vehicle Eligible           322.0
# 4            Clean Alternative Fuel Vehicle Eligible           208.0
#
#    base_msrp  legislative_district  dol_vehicle_id  \
# 0        0.0                  22.0       242565116
# 1        0.0                  10.0       183272785
# 2        0.0                  44.0       112552366
# 3        0.0                  11.0         6336319
# 4    69900.0                  21.0       186212960
#
#                                  vehicle_location  \
# 0   POINT (-122.91310169999997 47.01359260000004)
# 1   POINT (-122.35936399999997 47.97965520000008)
# 2   POINT (-122.09150499999998 47.91555500000004)
# 3  POINT (-122.32981499999994 47.579810000000066)
# 4            POINT (-122.37507 47.80807000000004)
#
#                                electric_utility 2020_census_tract country
# 0                        PUGET SOUND ENERGY INC     53067010910.0     USA
# 1                        PUGET SOUND ENERGY INC     53029972000.0     USA
# 2                        PUGET SOUND ENERGY INC     53061052502.0     USA
# 3  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)     53033009300.0     USA
# 4                        PUGET SOUND ENERGY INC     53061050403.0     USA

# %%
ev['model'].unique()
# Out:
# array(['MODEL 3', 'LEAF', 'MODEL S', 'I3', 'Q5 E', 'PRIUS PRIME', 'NIRO',
#        'MODEL Y', '500', 'C-MAX', 'MODEL X', 'VOLT', 'X5', 'FUSION',
#        'IONIQ', 'X3', 'XC90', 'FOCUS', 'I8', 'BOLT EV', 'E-TRON', 'RAV4',
#        'A3', 'XC60', 'F-150', 'E-GOLF', 'S90', 'XC40', 'PACIFICA',
#        'RAV4 PRIME', 'FORTWO', 'KONA ELECTRIC', 'ID.4', 'SPARK', 'R1S',
#        '330E', 'SOLTERRA', 'WRANGLER', 'C40', 'CLARITY', 'IONIQ 5',
#        'MUSTANG MACH-E', 'AVIATOR', 'AIR', 'SORENTO', 'EV6', 'EDV',
#        'CAYENNE', 'ESCAPE', 'S60', 'OUTLANDER', 'Q4', 'PS2',
#        'FORTWO ELECTRIC DRIVE', 'PRIUS PLUG-IN', nan, 'EQS-CLASS SEDAN',
#        'BOLT EUV', 'BZ4X', 'R1T', 'OPTIMA', 'TAYCAN', 'I4', 'COUNTRYMAN',
#        'EQ FORTWO', 'PANAMERA', 'IX', 'ARIYA', 'SOUL', '530E', 'I-MIEV',
#        'EQB-CLASS', 'HARDTOP', 'GRAND CHEROKEE', 'S-CLASS', 'E-TRON GT',
#        'SOUL EV', 'CORSAIR', 'B-CLASS', 'I-PACE', 'E-TRON SPORTBACK',
#        'TRANSIT', 'ELR', 'GLE-CLASS', 'SANTA FE', 'KONA', 'Q5', 'NX',
#        'ROADSTER', 'SONATA', 'EQS-CLASS SUV', 'GLC-CLASS', 'G80', 'GV60',
#        'SPORTAGE', 'RS E-TRON GT', '740E', 'WHEEGO', 'CROSSTREK',
#        'ACCORD', 'TUCSON', 'LYRIQ', 'IONIQ 6', 'KARMA', 'CX-90',
#        'FLYING SPUR', 'CITY', 'CT6', 'V60', 'RANGE ROVER SPORT', 'A7',
#        'RANGER', 'RANGE ROVER', 'PRIUS', 'EQE-CLASS SEDAN', '745E',
#        '745LE', 'C-CLASS', 'RZ 450E', 'TRANSIT CONNECT ELECTRIC', '918',
#        'BENTAYGA', 'Q8', 'A8 E', 'GV70', 'S-10 PICKUP'], dtype=object)

# %%
ev.dtypes
# Out:
# county                    object
# city                      object
# state                     object
# postal_code               object
# model_year                 int64
# make                      object
# model                     object
# electric_vehicle_type     object
# cafv_eligibility          object
# electric_range           float64
# base_msrp                float64
# legislative_district     float64
# dol_vehicle_id             int64
# vehicle_location          object
# electric_utility          object
# 2020_census_tract         object
# country                   object
# dtype: object

# %% [markdown]
# ###### checking nulls

# %%
ev.isnull().sum()
# Out:
# county                     8
# city                       8
# state                      0
# postal_code                0
# model_year                 0
# make                       0
# model                    249
# electric_vehicle_type      0
# cafv_eligibility           0
# electric_range             1
# base_msrp                  1
# legislative_district     312
# dol_vehicle_id             0
# vehicle_location          10
# electric_utility           8
# 2020_census_tract          0
# country                    0
# dtype: int64

# %%
ev = ev.drop(columns=['legislative_district'])

# %%
ev = ev.dropna(subset=['model', 'vehicle_location'])

# %%
ev.isnull().sum()
# Out:
# county                   0
# city                     0
# state                    0
# postal_code              0
# model_year               0
# make                     0
# model                    0
# electric_vehicle_type    0
# cafv_eligibility         0
# electric_range           1
# base_msrp                1
# dol_vehicle_id           0
# vehicle_location         0
# electric_utility         0
# 2020_census_tract        0
# country                  0
# dtype: int64

# %%
csv_file_path = r'C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\ev.csv'
ev.to_csv(csv_file_path, index=False)

# %% [markdown]
# # Cleaning EV Prices

# %%
ev_prices = pd.read_csv(r"C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\scraping\insideevs_ev_prices_scraping.csv", encoding='latin1')
ev_prices
# Out:
#                                                  Model Base Price  \
# 0                  2023 Audi e-tron GT quattro 20-inch   $104,900
# 1               2023 Audi RS e-tron GT quattro 20-inch   $143,900
# 2                          2024 Audi Q8 e-tron 20-inch    $74,400
# 3    2024 Audi Q8 e-tron Sportback (Ultra pack) 19-...    $77,800
# 4                2024 Audi Q8 e-tron Sportback 20-inch    $77,800
# ..                                                 ...        ...
# 212                   2023 Volvo XC40 Recharge 19-inch    $53,550
# 213                2024 Volvo C40 Recharge RWD 19-inch        NaN
# 214                2024 Volvo C40 Recharge AWD 19-inch        NaN
# 215               2024 Volvo XC40 Recharge RWD 19-inch        NaN
# 216               2024 Volvo XC40 Recharge AWD 19-inch        NaN
#
#     Dest. Charge Tax Credit Effective Price
# 0        +$1,495        NaN        $106,395
# 1        +$1,495        NaN        $145,395
# 2        +$1,195        NaN         $75,595
# 3        +$1,195        NaN         $78,995
# 4        +$1,195        NaN         $78,995
# ..           ...        ...             ...
# 212      +$1,095        NaN         $54,645
# 213          NaN        NaN             NaN
# 214          NaN        NaN             NaN
# 215          NaN        NaN             NaN
# 216          NaN        NaN             NaN
#
# [217 rows x 5 columns]

# %%
ev_prices.dtypes
# Out:
# Model              object
# Base Price         object
# Dest. Charge       object
# Tax Credit         object
# Effective Price    object
# dtype: object

# %%
ev_prices.describe()
# Out:
#                                       Model Base Price Dest. Charge  \
# count                                   217        205          205
# unique                                  217        175           22
# top     2023 Audi e-tron GT quattro 20-inch   $107,400      +$1,800
# freq                                      1          4           37
#
#        Tax Credit Effective Price
# count          37             205
# unique          2             179
# top        $7,500         $79,050
# freq           20               3

# %%
ev_prices.isnull().sum()
# Out:
# Model                0
# Base Price          12
# Dest. Charge        12
# Tax Credit         180
# Effective Price     12
# dtype: int64

# %% [markdown]
# ### separating the year, brand, and model from model column

# %%
def extract_details_and_add(df, column_name):    
    pattern = r'(?P<Year>\d{4}) (?P<Brand>\w+) (?P<Model>.*?)( \d+|$)'

    details = df[column_name].str.extract(pattern, expand=True)

    df['Year'] = details['Year']
    df['Brand'] = details['Brand']
    df['Model'] = details['Model']

    return df

# %%
ev_prices = extract_details_and_add(ev_prices, 'Model')
ev_prices
# Out:
#                                 Model Base Price Dest. Charge Tax Credit  \
# 0                   e-tron GT quattro   $104,900      +$1,495        NaN
# 1                RS e-tron GT quattro   $143,900      +$1,495        NaN
# 2                           Q8 e-tron    $74,400      +$1,195        NaN
# 3    Q8 e-tron Sportback (Ultra pack)    $77,800      +$1,195        NaN
# 4                 Q8 e-tron Sportback    $77,800      +$1,195        NaN
# ..                                ...        ...          ...        ...
# 212                     XC40 Recharge    $53,550      +$1,095        NaN
# 213                  C40 Recharge RWD        NaN          NaN        NaN
# 214                  C40 Recharge AWD        NaN          NaN        NaN
# 215                 XC40 Recharge RWD        NaN          NaN        NaN
# 216                 XC40 Recharge AWD        NaN          NaN        NaN
#
#     Effective Price  Year  Brand
# 0          $106,395  2023   Audi
# 1          $145,395  2023   Audi
# 2           $75,595  2024   Audi
# 3           $78,995  2024   Audi
# 4           $78,995  2024   Audi
# ..              ...   ...    ...
# 212         $54,645  2023  Volvo
# 213             NaN  2024  Volvo
# 214             NaN  2024  Volvo
# 215             NaN  2024  Volvo
# 216             NaN  2024  Volvo
#
# [217 rows x 7 columns]

# %% [markdown]
# ### removing 'Tax Credit' column

# %%
ev_prices = ev_prices.drop('Tax Credit', axis=1)

# %%
ev_prices.head()
# Out:
#                               Model Base Price Dest. Charge Effective Price  \
# 0                 e-tron GT quattro   $104,900      +$1,495        $106,395
# 1              RS e-tron GT quattro   $143,900      +$1,495        $145,395
# 2                         Q8 e-tron    $74,400      +$1,195         $75,595
# 3  Q8 e-tron Sportback (Ultra pack)    $77,800      +$1,195         $78,995
# 4               Q8 e-tron Sportback    $77,800      +$1,195         $78,995
#
#    Year Brand
# 0  2023  Audi
# 1  2023  Audi
# 2  2024  Audi
# 3  2024  Audi
# 4  2024  Audi

# %% [markdown]
# ### changing column names

# %%
ev_prices = ev_prices.rename(columns={
    'Model': 'model',
    'Base Price': 'base_price',
    'Dest. Charge': 'delivery_charge',
    'Effective Price': 'final_price',
    'Year': 'year',
    'Brand': 'brand'
})

# %% [markdown]
# ### cleaning prices columns

# %%
columns_to_clean ={
    'base_price', 'delivery_charge', 'final_price'
}

# %%
def clean_price_columns(df, columns):
    for column in columns:
        
        df[column] = df[column].astype(str).str.replace(r'[^0-9.-]', '', regex=True)

        df[column] = pd.to_numeric(df[column], errors='coerce')

    return df


ev_prices = clean_price_columns(ev_prices, columns_to_clean)

# %%
ev_prices.head()
# Out:
#                               model  base_price  delivery_charge  final_price  \
# 0                 e-tron GT quattro    104900.0           1495.0     106395.0
# 1              RS e-tron GT quattro    143900.0           1495.0     145395.0
# 2                         Q8 e-tron     74400.0           1195.0      75595.0
# 3  Q8 e-tron Sportback (Ultra pack)     77800.0           1195.0      78995.0
# 4               Q8 e-tron Sportback     77800.0           1195.0      78995.0
#
#    year brand
# 0  2023  Audi
# 1  2023  Audi
# 2  2024  Audi
# 3  2024  Audi
# 4  2024  Audi

# %% [markdown]
# ### checking nans

# %%
has_nan = ev_prices.isna().any().any()
total_nan = ev_prices.isna().sum().sum()
total_nan
# Out:
# 36

# %%
rows_with_nan = ev_prices[ev_prices['base_price'].isna()]
rows_with_nan
# Out:
#                                model  base_price  delivery_charge  \
# 27   F-150 Lightning Pro ER (fleets)         NaN              NaN
# 81                         Endurance         NaN              NaN
# 147         R1S DM AWD, Max Pack, AT         NaN              NaN
# 148            R1S DM AWD, Max Pack,         NaN              NaN
# 149            R1S DM AWD, Max Pack,         NaN              NaN
# 153   R1S Perf. DM AWD, Max Pack, AT         NaN              NaN
# 154      R1S Perf. DM AWD, Max Pack,         NaN              NaN
# 155      R1S Perf. DM AWD, Max Pack,         NaN              NaN
# 213                 C40 Recharge RWD         NaN              NaN
# 214                 C40 Recharge AWD         NaN              NaN
# 215                XC40 Recharge RWD         NaN              NaN
# 216                XC40 Recharge AWD         NaN              NaN
#
#      final_price  year      brand
# 27           NaN  2023       Ford
# 81           NaN  2023  Lordstown
# 147          NaN  2023     Rivian
# 148          NaN  2023     Rivian
# 149          NaN  2023     Rivian
# 153          NaN  2023     Rivian
# 154          NaN  2023     Rivian
# 155          NaN  2023     Rivian
# 213          NaN  2024      Volvo
# 214          NaN  2024      Volvo
# 215          NaN  2024      Volvo
# 216          NaN  2024      Volvo

# %% [markdown]
# ### adding base_prices found on websites

# %%
base_prices = {
    'F-150 Lightning Pro ER (fleets)': 54369,
    'Endurance': 65060,  
    'R1S DM AWD, Max Pack, AT': 78000,
    'R1S DM AWD, Max Pack': 78000,
    'R1S Perf. DM AWD, Max Pack, AT': 99000, 
    'R1S Perf. DM AWD, Max Pack': 99000,  
    'R1S DM AWD, Max Pack,': 94000,  
    'R1S Perf. DM AWD, Max Pack,': 99000,  
    'C40 Recharge RWD': 53600,  
    'C40 Recharge AWD': 53600,  
    'XC40 Recharge RWD': 52450,  
    'XC40 Recharge AWD': 54200  
}

# %% [markdown]
# ### updating base_price

# %%
def update_base_price(row):
    model = row['model']
    return base_prices.get(model, row['base_price'])

ev_prices['base_price'] = ev_prices.apply(update_base_price, axis=1)

# %%
has_nan = ev_prices.isna().any().any()
total_nan = ev_prices.isna().sum().sum()
total_nan
# Out:
# 24

# %% [markdown]
# ### same with delivery_charge

# %%
delivery_charge = {
    'F-150 Lightning Pro ER (fleets)': 1895,
    'Endurance': 1800, 
    'R1S DM AWD, Max Pack, AT': 1800,
    'R1S DM AWD, Max Pack': 1800,
    'R1S Perf. DM AWD, Max Pack, AT': 1800,
    'R1S Perf. DM AWD, Max Pack': 1800,
    'R1S DM AWD, Max Pack,': 1800,  
    'R1S Perf. DM AWD, Max Pack,': 1800, 
    'C40 Recharge RWD': 1750,  
    'C40 Recharge AWD': 1750,
    'XC40 Recharge RWD': 1750,
    'XC40 Recharge AWD': 1750
}

# %% [markdown]
# ### updating delivery_price

# %%
def update_delivery_price(row):
    model = row['model']
    return delivery_charge.get(model, row['delivery_charge'])

ev_prices['delivery_charge'] = ev_prices.apply(update_delivery_price, axis=1)

# %%
has_nan = ev_prices.isna().any().any()
total_nan = ev_prices.isna().sum().sum()
total_nan
# Out:
# 12

# %% [markdown]
# ### updating final_price

# %%
ev_prices['final_price'] = ev_prices['base_price'] + ev_prices['delivery_charge']

# %%
has_nan = ev_prices.isna().any().any()
total_nan = ev_prices.isna().sum().sum()
total_nan
# Out:
# 0

# %%
ev_prices['brand'] = ev_prices['brand'].str.upper()

# %%
ev_prices.head()
# Out:
#                               model  base_price  delivery_charge  final_price  \
# 0                 e-tron GT quattro    104900.0           1495.0     106395.0
# 1              RS e-tron GT quattro    143900.0           1495.0     145395.0
# 2                         Q8 e-tron     74400.0           1195.0      75595.0
# 3  Q8 e-tron Sportback (Ultra pack)     77800.0           1195.0      78995.0
# 4               Q8 e-tron Sportback     77800.0           1195.0      78995.0
#
#    year brand
# 0  2023  AUDI
# 1  2023  AUDI
# 2  2024  AUDI
# 3  2024  AUDI
# 4  2024  AUDI

# %%
ev_prices['model'].unique()
# Out:
# array(['e-tron GT quattro', 'RS e-tron GT quattro', 'Q8 e-tron',
#        'Q8 e-tron Sportback (Ultra pack)', 'Q8 e-tron Sportback', 'Q4',
#        'Q4 Sportback', 'i4 eDrive35', 'i4 eDrive40', 'i4 M50',
#        'i7 xDrive60', 'iX xDrive50', 'iX M60', 'Lyriq Tech RWD',
#        'Lyriq Tech AWD', 'Bolt EV', 'Bolt EUV LT',
#        'F-150 Lightning Pro SR', 'F-150 Lightning Pro ER (fleets)',
#        'F-150 Lightning XLT SR', 'F-150 Lightning XLT ER',
#        'F-150 Lightning Lariat SR', 'F-150 Lightning Lariat ER',
#        'F-150 Lightning Platinum ER', 'Mustang Mach-E Select SR LFP RWD',
#        'Mustang Mach-E Select SR LFP AWD',
#        'Mustang Mach-E Premium SR LFP RWD',
#        'Mustang Mach-E Premium SR LFP AWD',
#        'Mustang Mach-E Premium ER RWD', 'Mustang Mach-E Premium ER AWD',
#        'Mustang Mach-E Route', 'Mustang Mach-E GT ER AWD',
#        'Mustang Mach-E GT Perf. ER AWD', 'Electrified G80 AWD',
#        'GV60 Advanced AWD', 'GV60 Performance AWD',
#        'Electrified GV70 Advanced AWD', 'Hummer EV Pickup (Edition',
#        'Hummer EV Pickup (3X)', 'Hummer EV Pickup (2X)',
#        'Hummer EV Pickup (2)', 'Hummer EV SUV (Edition',
#        'Hummer EV SUV (3X)', 'Hummer EV SUV (2X)', 'Hummer EV SUV (2)',
#        'Ioniq', 'Kona Electric', 'I-PACE EV400', 'EV6 RWD SR',
#        'EV6 Wind RWD LR', 'EV6 Wind AWD LR', 'EV6 GT-Line RWD LR',
#        'EV6 GT-Line AWD LR', 'EV6 GT AWD LR', 'Niro EV', 'RZ',
#        'Endurance', 'Air Pure RWD', 'Air Pure AWD', 'Air Touring AWD',
#        'Air Grand Touring AWD', 'Air Grand Touring Performance',
#        'Air Sapphire', 'MX-30', 'EQB', 'EQE', 'AMG EQE', 'EQS', 'AMG EQS',
#        'Cooper SE Hardtop', 'Ariya Engage FWD (63 kWh)',
#        'Ariya Engage e-4ORCE AWD (63 kWh)', 'Ariya Venture+ FWD (87 kWh)',
#        'Ariya Evolve+ FWD (87 kWh)', 'Ariya Empower+ FWD (87 kWh)',
#        'Ariya Premiere FWD', 'Ariya Engage+ e-4ORCE AWD',
#        'Ariya Evolve+ e-4ORCE AWD', 'Ariya Platinum+ e-4ORCE AWD',
#        'Leaf S (40 kWh)', 'Leaf e+ SV Plus (60 kWh)', '2 Single Motor',
#        '2 Dual Motor', '2 Dual Motor Perf Pack',
#        '2 Dual Motor BST edition', 'Taycan (79 kWh)', 'Taycan (93 kWh)',
#        'Taycan', 'Taycan GTS (93 kWh)',
#        'Taycan GTS Sport Turismo (93 kWh)', 'Taycan Turbo (93 kWh)',
#        'Taycan Turbo S (93 kWh)', 'Taycan Turbo Cross Turismo (93 kWh)',
#        'Taycan Turbo S Cross Turismo (93 kWh)', 'R1S DM AWD, Std Pack,',
#        'R1S DM AWD, Large Pack, AT', 'R1S DM AWD, Large Pack,',
#        'R1S DM AWD, Max Pack, AT', 'R1S DM AWD, Max Pack,',
#        'R1S Perf. DM AWD, Large Pack, AT',
#        'R1S Perf. DM AWD, Large Pack,', 'R1S Perf. DM AWD, Max Pack, AT',
#        'R1S Perf. DM AWD, Max Pack,', 'R1S QM AWD, Large Pack, AT',
#        'R1S QM AWD, Large Pack,', 'R1T DM AWD, Std Pack,',
#        'R1T DM AWD, Large Pack, AT', 'R1T DM AWD, Large Pack,',
#        'R1T DM AWD, Max Pack, AT', 'R1T DM AWD, Max Pack,',
#        'R1T Perf. DM AWD, Large Pack, AT',
#        'R1T Perf. DM AWD, Large Pack,', 'R1T Perf. DM AWD, Max Pack, AT',
#        'R1T Perf. DM AWD, Max Pack,', 'R1T QM AWD, Large Pack, AT',
#        'R1T QM AWD, Large Pack,', 'Solterra Premium AWD',
#        'Solterra Limited AWD', 'Solterra Touring AWD', 'Model',
#        'Model S LR AWD', 'Model S Plaid', 'Model X LR AWD',
#        'Model X Plaid', 'Model Y AWD (4680)', 'Model Y Long Range AWD',
#        'Model Y Perf. LR AWD', 'bZ4X XLE FWD', 'bZ4X Limited FWD',
#        'bZ4X XLE AWD', 'bZ4X Limited AWD', 'VF', 'ID.4 Standard',
#        'ID.4 S', 'ID.4 Pro', 'ID.4 Pro S', 'ID.4 AWD Pro',
#        'ID.4 AWD Pro S', 'C40 Recharge', 'XC40 Recharge',
#        'C40 Recharge RWD', 'C40 Recharge AWD', 'XC40 Recharge RWD',
#        'XC40 Recharge AWD'], dtype=object)

# %%
csv_file_path = r'C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\ev_prices.csv'
ev_prices.to_csv(csv_file_path, index=False)

# %% [markdown]
# # Cleaning Ev Sales and Stock per Year

# %%
ev_sales_scraping = pd.read_csv(r"C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\scraping\wikipedia_ev_sales_scraping.csv", encoding='latin1')
ev_sales_scraping.head()
# Out:
#             Country                   2021          2021.1             2020  \
# 0           Country                  stock           sales            stock
# 1      China[i][ii]     7,842,668 [87][88]  3,334,000 [87]   4,508,668 [88]
# 2  United States[i]         2,322,291 [16]    607,567 [16]   1,741,566 [94]
# 3        Germany[i]  â1,380,000 [18][19]    681,410 [19]  â700,000 [18]
# 4            France          786,274 [103]   315,978 [103]    470,295 [104]
#
#            2020.1                         2019          2019.1  \
# 0           sales                        stock           sales
# 1  1,246,000 [89]                3,349,100 [1]  1,204,000 [90]
# 2    297,939 [94]                1,450,020 [1]    329,528 [95]
# 3    394,632 [99]  305,589 [32][100][101][102]   108,839 [102]
# 4   194,881 [104]                275,575 [104]    69,466 [105]
#
#                           2018             2018.1                    2017  \
# 0                        stock              sales                   stock
# 1           2,243,772 [91][92]  1,016,002 [92][i]          1,227,770 [91]
# 2               1,126,000 [96]       361,307 [96]        764,666 [97][98]
# 3       196,750 [32][100][101]       67,504 [101]       129,246 [32][100]
# 4  204,617 [52][106][107][108]       53,745 [108]  149,797 [52][106][107]
#
#             2017.1
# 0            sales
# 1  579,000 [93][i]
# 2     199,818 [96]
# 3     54,492 [100]
# 4     42,799 [108]

# %% [markdown]
# #### Modifying columns

# %%
ev_sales_scraping.columns = [col.lower().replace(' ', '_') for col in ev_sales_scraping.columns]

# %%
def remove_brackets(text):
    return re.sub(r"\[.*?\]", "", text) if isinstance(text, str) else text

for column in ev_sales_scraping.columns:
    ev_sales_scraping['country'] = ev_sales_scraping['country'].apply(remove_brackets)

# %%
ev_sales_scraping
# Out:
#                                               country  \
# 0                                             Country
# 1                                               China
# 2                                       United States
# 3                                             Germany
# 4                                              France
# 5                                      United Kingdom
# 6                                              Norway
# 7                                         Netherlands
# 8                                              Sweden
# 9                                               Japan
# 10                                             Canada
# 11                                       Global total
# 12  Light-duty plug-in cumulative registrations in...
# 13                                      Europe (EU+3)
# 14                                         California
# 15  Plug-in vehicle cumulative sales for all class...
# 16                         China (all class segments)
# 17  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2021  \
# 0                                               stock
# 1                                  7,842,668 [87][88]
# 2                                      2,322,291 [16]
# 3                               â1,380,000 [18][19]
# 4                                       786,274 [103]
# 5                                    â745,000 [109]
# 6                                       647,000 [115]
# 7                                       390,454 [124]
# 8                               355,737 [1][129][130]
# 9                                       337,377 [133]
# 10                                      297,960 [136]
# 11                             17.5Â million [5][138]
# 12  Light-duty plug-in cumulative registrations in...
# 13      5.67Â million [13][14][15][32][139][140][141]
# 14                      1,072,136 [144][145][20][146]
# 15  Plug-in vehicle cumulative sales for all class...
# 16                9,076,447 [87][89][32][90][93][151]
# 17  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                2021.1  \
# 0                                               sales
# 1                                      3,334,000 [87]
# 2                                        607,567 [16]
# 3                                        681,410 [19]
# 4                                       315,978 [103]
# 5                                       305,281 [110]
# 6                                       167,949 [116]
# 7                                        95,464 [125]
# 8                                       138,033 [130]
# 9                                        44,296 [133]
# 10                                       87,700 [136]
# 11                                    6,754,000 [138]
# 12  Light-duty plug-in cumulative registrations in...
# 13                                 2,332,798 [13][15]
# 14                                      237,618 [144]
# 15  Plug-in vehicle cumulative sales for all class...
# 16                                     3,521,000 [87]
# 17  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2020  \
# 0                                               stock
# 1                                      4,508,668 [88]
# 2                                      1,741,566 [94]
# 3                                     â700,000 [18]
# 4                                       470,295 [104]
# 5                                    434,282 [1][111]
# 6                                       480,008 [117]
# 7                                       297,380 [126]
# 8                                    193,054 [1][129]
# 9                                         297,181 [2]
# 10                                      209,075 [136]
# 11                               10.8Â million [5][v]
# 12  Light-duty plug-in cumulative registrations in...
# 13                  3,336,141 [14][32][139][140][141]
# 14                             834,518 [145][20][146]
# 15  Plug-in vehicle cumulative sales for all class...
# 16                    5,555,447 [89][32][90][93][151]
# 17  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                2020.1  \
# 0                                               sales
# 1                                      1,246,000 [89]
# 2                                        297,939 [94]
# 3                                        394,632 [99]
# 4                                       194,881 [104]
# 5                                       175,082 [111]
# 6                                       113,588 [118]
# 7                                        89,362 [127]
# 8                                        96,054 [129]
# 9                                          29,000 [2]
# 10                                       51,376 [136]
# 11                                  3,240,000 [25][v]
# 12  Light-duty plug-in cumulative registrations in...
# 13                                     1,403,812 [14]
# 14                                      132,742 [145]
# 15  Plug-in vehicle cumulative sales for all class...
# 16                                     1,367,000 [89]
# 17  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2019  \
# 0                                               stock
# 1                                       3,349,100 [1]
# 2                                       1,450,020 [1]
# 3                         305,589 [32][100][101][102]
# 4                                       275,575 [104]
# 5                                         259,200 [1]
# 6                                       384,066 [119]
# 7                                       207,922 [126]
# 8                                          97,000 [1]
# 9                                         267,415 [2]
# 10                                        141,100 [1]
# 11                                      7,167,830 [1]
# 12  Light-duty plug-in cumulative registrations in...
# 13                      1,935,010 [32][139][140][141]
# 14                             701,776 [145][20][146]
# 15  Plug-in vehicle cumulative sales for all class...
# 16                        4,188,447 [32][90][93][151]
# 17  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                2019.1  \
# 0                                               sales
# 1                                      1,204,000 [90]
# 2                                        329,528 [95]
# 3                                       108,839 [102]
# 4                                        69,466 [105]
# 5                                        72,584 [112]
# 6                                        88,443 [120]
# 7                                          67,520 [1]
# 8                                        41,784 [131]
# 9                                        43,867 [134]
# 10                                         50,960 [1]
# 11                                      2,101,680 [1]
# 12  Light-duty plug-in cumulative registrations in...
# 13                                  588,575 [14][141]
# 14                                      159,081 [145]
# 15  Plug-in vehicle cumulative sales for all class...
# 16                                     1,204,000 [90]
# 17  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2018  \
# 0                                               stock
# 1                                  2,243,772 [91][92]
# 2                                      1,126,000 [96]
# 3                              196,750 [32][100][101]
# 4                         204,617 [52][106][107][108]
# 5                                       197,000 [113]
# 6                                       296,215 [121]
# 7                                       145,882 [126]
# 8                                    79,579 [91][132]
# 9                                         239,242 [2]
# 10                                         90,100 [1]
# 11                                  5,127,297 [8][91]
# 12  Light-duty plug-in cumulative registrations in...
# 13                      1,346,435 [32][142][140][143]
# 14                                  542,695 [20][145]
# 15  Plug-in vehicle cumulative sales for all class...
# 16                            2,984,447 [32][93][151]
# 17  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                2018.1  \
# 0                                               sales
# 1                                   1,016,002 [92][i]
# 2                                        361,307 [96]
# 3                                        67,504 [101]
# 4                                        53,745 [108]
# 5                                     59,911 [i][114]
# 6                                        86,290 [122]
# 7                                        29,187 [128]
# 8                                        29,909 [132]
# 9                                        52,013 [135]
# 10                                         44,150 [1]
# 11                                      2,018,247 [8]
# 12  Light-duty plug-in cumulative registrations in...
# 13                                 406,052 [142][143]
# 14                                      163,765 [145]
# 15  Plug-in vehicle cumulative sales for all class...
# 16                                    1,256,000 [151]
# 17  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2017  \
# 0                                               stock
# 1                                      1,227,770 [91]
# 2                                    764,666 [97][98]
# 3                                   129,246 [32][100]
# 4                              149,797 [52][106][107]
# 5                                        137,000[113]
# 6                                       209,122 [121]
# 7                                       121,540 [126]
# 8                                         49,670 [91]
# 9                                        205,212 [91]
# 10                                        45,950 [91]
# 11                                     3,109,050 [91]
# 12  Light-duty plug-in cumulative registrations in...
# 13                             940,383 [32][142][140]
# 14                                  378,930 [20][145]
# 15  Plug-in vehicle cumulative sales for all class...
# 16                                 1,728,447 [32][93]
# 17  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                2017.1
# 0                                               sales
# 1                                     579,000 [93][i]
# 2                                        199,818 [96]
# 3                                        54,492 [100]
# 4                                        42,799 [108]
# 5                                     49,182 [i][114]
# 6                                        71,737 [123]
# 7                                        11,085 [128]
# 8                                        19,793 [132]
# 9                                         54,100 [91]
# 10                                       18,746 [137]
# 11                                     1,148,700 [91]
# 12  Light-duty plug-in cumulative registrations in...
# 13                                 302,383 [142][140]
# 14                                      107,779 [145]
# 15  Plug-in vehicle cumulative sales for all class...
# 16                                       777,000 [93]
# 17  Notes ^ a b c d e f g h i j Only includes plug...

# %% [markdown]
# ## diving the df in two tables, one with stock and other one with sales
# ###### first cleaning row Europe

# %%
ev_sales_scraping.loc[ev_sales_scraping['country'] == 'Europe (EU+3)', 'country'] = 'Europe'

# %%
valid_countries = [
    'United States', 'Germany', 'France', 'United Kingdom',
    'Norway', 'Netherlands', 'Sweden', 'Japan', 'Canada', 'China', 'Europe'
]

ev_sales_scraping = ev_sales_scraping[ev_sales_scraping['country'].isin(valid_countries)]

ev_sales_scraping.reset_index(drop=True, inplace=True)

# %%
ev_sales_scraping
# Out:
#            country                                           2021  \
# 0            China                             7,842,668 [87][88]
# 1    United States                                 2,322,291 [16]
# 2          Germany                          â1,380,000 [18][19]
# 3           France                                  786,274 [103]
# 4   United Kingdom                               â745,000 [109]
# 5           Norway                                  647,000 [115]
# 6      Netherlands                                  390,454 [124]
# 7           Sweden                          355,737 [1][129][130]
# 8            Japan                                  337,377 [133]
# 9           Canada                                  297,960 [136]
# 10          Europe  5.67Â million [13][14][15][32][139][140][141]
#
#                 2021.1                               2020          2020.1  \
# 0       3,334,000 [87]                     4,508,668 [88]  1,246,000 [89]
# 1         607,567 [16]                     1,741,566 [94]    297,939 [94]
# 2         681,410 [19]                    â700,000 [18]    394,632 [99]
# 3        315,978 [103]                      470,295 [104]   194,881 [104]
# 4        305,281 [110]                   434,282 [1][111]   175,082 [111]
# 5        167,949 [116]                      480,008 [117]   113,588 [118]
# 6         95,464 [125]                      297,380 [126]    89,362 [127]
# 7        138,033 [130]                   193,054 [1][129]    96,054 [129]
# 8         44,296 [133]                        297,181 [2]      29,000 [2]
# 9         87,700 [136]                      209,075 [136]    51,376 [136]
# 10  2,332,798 [13][15]  3,336,141 [14][32][139][140][141]  1,403,812 [14]
#
#                              2019             2019.1  \
# 0                   3,349,100 [1]     1,204,000 [90]
# 1                   1,450,020 [1]       329,528 [95]
# 2     305,589 [32][100][101][102]      108,839 [102]
# 3                   275,575 [104]       69,466 [105]
# 4                     259,200 [1]       72,584 [112]
# 5                   384,066 [119]       88,443 [120]
# 6                   207,922 [126]         67,520 [1]
# 7                      97,000 [1]       41,784 [131]
# 8                     267,415 [2]       43,867 [134]
# 9                     141,100 [1]         50,960 [1]
# 10  1,935,010 [32][139][140][141]  588,575 [14][141]
#
#                              2018              2018.1                    2017  \
# 0              2,243,772 [91][92]   1,016,002 [92][i]          1,227,770 [91]
# 1                  1,126,000 [96]        361,307 [96]        764,666 [97][98]
# 2          196,750 [32][100][101]        67,504 [101]       129,246 [32][100]
# 3     204,617 [52][106][107][108]        53,745 [108]  149,797 [52][106][107]
# 4                   197,000 [113]     59,911 [i][114]            137,000[113]
# 5                   296,215 [121]        86,290 [122]           209,122 [121]
# 6                   145,882 [126]        29,187 [128]           121,540 [126]
# 7                79,579 [91][132]        29,909 [132]             49,670 [91]
# 8                     239,242 [2]        52,013 [135]            205,212 [91]
# 9                      90,100 [1]          44,150 [1]             45,950 [91]
# 10  1,346,435 [32][142][140][143]  406,052 [142][143]  940,383 [32][142][140]
#
#                 2017.1
# 0      579,000 [93][i]
# 1         199,818 [96]
# 2         54,492 [100]
# 3         42,799 [108]
# 4      49,182 [i][114]
# 5         71,737 [123]
# 6         11,085 [128]
# 7         19,793 [132]
# 8          54,100 [91]
# 9         18,746 [137]
# 10  302,383 [142][140]

# %% [markdown]
# ###### dividing stock

# %%
columns_to_include = [col for col in ev_sales_scraping.columns if '.1' not in col]

ev_stock = ev_sales_scraping[columns_to_include]

# %%
ev_stock.head()
# Out:
#           country                   2021              2020  \
# 0           China     7,842,668 [87][88]    4,508,668 [88]
# 1   United States         2,322,291 [16]    1,741,566 [94]
# 2         Germany  â1,380,000 [18][19]   â700,000 [18]
# 3          France          786,274 [103]     470,295 [104]
# 4  United Kingdom       â745,000 [109]  434,282 [1][111]
#
#                           2019                         2018  \
# 0                3,349,100 [1]           2,243,772 [91][92]
# 1                1,450,020 [1]               1,126,000 [96]
# 2  305,589 [32][100][101][102]       196,750 [32][100][101]
# 3                275,575 [104]  204,617 [52][106][107][108]
# 4                  259,200 [1]                197,000 [113]
#
#                      2017
# 0          1,227,770 [91]
# 1        764,666 [97][98]
# 2       129,246 [32][100]
# 3  149,797 [52][106][107]
# 4            137,000[113]

# %%
def clean_numeric(value):
  
    cleaned_value = re.sub(r'\[.*?\]', '', str(value))
    cleaned_value = re.sub(r'[^\d.]+', '', cleaned_value)
    

    if not cleaned_value or not any(char.isdigit() for char in cleaned_value):
        return None

    try:
        
        return int(cleaned_value)
    except ValueError:
        return float(cleaned_value)

# %%
for col in ev_stock.columns:
    if col != 'country':
        ev_stock.loc[:, col] = ev_stock[col].apply(clean_numeric)

# %%
ev_stock
# Out:
#            country       2021     2020     2019     2018     2017
# 0            China  7842668.0  4508668  3349100  2243772  1227770
# 1    United States  2322291.0  1741566  1450020  1126000   764666
# 2          Germany  1380000.0   700000   305589   196750   129246
# 3           France   786274.0   470295   275575   204617   149797
# 4   United Kingdom   745000.0   434282   259200   197000   137000
# 5           Norway   647000.0   480008   384066   296215   209122
# 6      Netherlands   390454.0   297380   207922   145882   121540
# 7           Sweden   355737.0   193054    97000    79579    49670
# 8            Japan   337377.0   297181   267415   239242   205212
# 9           Canada   297960.0   209075   141100    90100    45950
# 10          Europe       5.67  3336141  1935010  1346435   940383

# %%
ev_stock.dtypes
# Out:
# country    object
# 2021       object
# 2020       object
# 2019       object
# 2018       object
# 2017       object
# dtype: object

# %%
ev_stock = ev_stock.copy()

# %%
for col in ev_stock.columns:
    if col != 'country':
        ev_stock[col] = ev_stock[col].astype(float)

print(ev_stock.dtypes)
# Out:
# country     object
# 2021       float64
# 2020       float64
# 2019       float64
# 2018       float64
# 2017       float64
# dtype: object

# %%
csv_file_path = r'C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\ev_stock.csv'
ev_stock.to_csv(csv_file_path, index=False)

# %% [markdown]
# ###### dividing sales

# %%
columns_sales = [col for col in ev_sales_scraping.columns if col.endswith('.1')]

# Seleccionar estas columnas en el DataFrame
ev_sales = ev_sales_scraping[columns_sales]

# %%
ev_sales
# Out:
#                 2021.1          2020.1             2019.1              2018.1  \
# 0       3,334,000 [87]  1,246,000 [89]     1,204,000 [90]   1,016,002 [92][i]
# 1         607,567 [16]    297,939 [94]       329,528 [95]        361,307 [96]
# 2         681,410 [19]    394,632 [99]      108,839 [102]        67,504 [101]
# 3        315,978 [103]   194,881 [104]       69,466 [105]        53,745 [108]
# 4        305,281 [110]   175,082 [111]       72,584 [112]     59,911 [i][114]
# 5        167,949 [116]   113,588 [118]       88,443 [120]        86,290 [122]
# 6         95,464 [125]    89,362 [127]         67,520 [1]        29,187 [128]
# 7        138,033 [130]    96,054 [129]       41,784 [131]        29,909 [132]
# 8         44,296 [133]      29,000 [2]       43,867 [134]        52,013 [135]
# 9         87,700 [136]    51,376 [136]         50,960 [1]          44,150 [1]
# 10  2,332,798 [13][15]  1,403,812 [14]  588,575 [14][141]  406,052 [142][143]
#
#                 2017.1
# 0      579,000 [93][i]
# 1         199,818 [96]
# 2         54,492 [100]
# 3         42,799 [108]
# 4      49,182 [i][114]
# 5         71,737 [123]
# 6         11,085 [128]
# 7         19,793 [132]
# 8          54,100 [91]
# 9         18,746 [137]
# 10  302,383 [142][140]

# %%
def clean_numeric(value):
  
    cleaned_value = re.sub(r'\[.*?\]', '', str(value))
    cleaned_value = re.sub(r'[^\d.]+', '', cleaned_value)
    

    if not cleaned_value or not any(char.isdigit() for char in cleaned_value):
        return None

    try:
        
        return int(cleaned_value)
    except ValueError:
        return float(cleaned_value)

# %%
for col in ev_sales.columns:
    if col != 'country':
        ev_sales.loc[:, col] = ev_sales[col].apply(clean_numeric)

# %%
ev_sales.dtypes
# Out:
# 2021.1    object
# 2020.1    object
# 2019.1    object
# 2018.1    object
# 2017.1    object
# dtype: object

# %%
ev_sales.head()
# Out:
#     2021.1   2020.1   2019.1   2018.1  2017.1
# 0  3334000  1246000  1204000  1016002  579000
# 1   607567   297939   329528   361307  199818
# 2   681410   394632   108839    67504   54492
# 3   315978   194881    69466    53745   42799
# 4   305281   175082    72584    59911   49182

# %%
ev_sales = ev_sales.copy()

# %%
for col in ev_sales.columns:
    if col != 'country':
        ev_sales[col] = ev_sales[col].astype(float)

print(ev_sales.dtypes)
# Out:
# 2021.1    float64
# 2020.1    float64
# 2019.1    float64
# 2018.1    float64
# 2017.1    float64
# dtype: object

# %%
csv_file_path = r'C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\ev_sales.csv'
ev_stock.to_csv(csv_file_path, index=False)
