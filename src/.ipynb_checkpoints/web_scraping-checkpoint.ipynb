# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen
import re
from datetime import datetime
import calendar
import csv
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time
import csv

# %% [markdown]
# # Getting EV prices information from website

# %%
url = "https://insideevs.com/news/565883/electric-car-prices-us/"

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

# %%
tbody = soup.find('tbody')

# %%
rows = tbody.find_all('tr')

# %%
all_rows = []

for row in tbody.find_all('tr'):
    cols = row.find_all('td')
    cols_text = [ele.text.strip() for ele in cols]
    all_rows.append(cols_text)

# %%
headers = all_rows[0]
data_rows = all_rows[1:]

# %%
ev_prices_scraping = pd.DataFrame(data_rows, columns=headers)
ev_prices_scraping
# Out:
#                                                  Model Base Price  \
# 0                  2023 Audi e-tron GT quattro 20-inch   $104,900
# 1               2023 Audi RS e-tron GT quattro 20-inch   $143,900
# 2                          2024 Audi Q8 e-tron 20-inch    $74,400
# 3    2024 Audi Q8 e-tron Sportback (Ultra pack) 19-...    $77,800
# 4                2024 Audi Q8 e-tron Sportback 20-inch    $77,800
# ..                                                 ...        ...
# 212                   2023 Volvo XC40 Recharge 19-inch    $53,550
# 213                2024 Volvo C40 Recharge RWD 19-inch
# 214                2024 Volvo C40 Recharge AWD 19-inch
# 215               2024 Volvo XC40 Recharge RWD 19-inch
# 216               2024 Volvo XC40 Recharge AWD 19-inch
#
#     Dest. Charge Tax Credit Effective Price
# 0        +$1,495        N/A        $106,395
# 1        +$1,495        N/A        $145,395
# 2        +$1,195        N/A         $75,595
# 3        +$1,195        N/A         $78,995
# 4        +$1,195        N/A         $78,995
# ..           ...        ...             ...
# 212      +$1,095        N/A         $54,645
# 213                     N/A
# 214                     N/A
# 215                     N/A
# 216                     N/A
#
# [217 rows x 5 columns]

# %%
csv_file_path = r'C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\ev_prices_scraping.csv'
ev_prices_scraping.to_csv(csv_file_path, index=False)

# %% [markdown]
# # Getting EV countries Sales, market, and usage share 2022
# ###### Light-duty plug-in electric vehicle stock, market penetration, annual sales, and market share in the top selling countries and regional markets for latest available year

# %%
url2 = "https://en.wikipedia.org/wiki/Electric_car_use_by_country"
ev_sales22 = pd.read_html(url2)[2]
ev_sales22
# Out:
#                                     Country or region  \
# 0                                          China[iii]
# 1                                          Europe[iv]
# 2                                  United States[iii]
# 3                                        Germany[iii]
# 4                                     California[iii]
# 5                                              France
# 6                                      United Kingdom
# 7                                           Norway[v]
# 8                                     Netherlands[vi]
# 9                                              Sweden
# 10                                    Japan[iii][vii]
# 11                                        Canada[iii]
# 12                                  Global total[iii]
# 13  Notes ^ Includes sales or registrations of hig...
#
#                PEV stock/ cumulative sales  (2022)[i]  \
# 0                                      14,100,000[71]
# 1                                       7,800,000[71]
# 2                                       2,960,000[71]
# 3                                       1,877,721[74]
# 4                                       1,385,383[76]
# 5                                         990,000[71]
# 6                                         950,000[71]
# 7                                         817,471[82]
# 8                                         515,838[84]
# 9                                         440,000[71]
# 10                                        410,000[71]
# 11                                        380,000[71]
# 12                                     25,900,000[71]
# 13  Notes ^ Includes sales or registrations of hig...
#
#                                  Annual sales  (2022)  \
# 0                                       5,924,421[72]
# 1                                       2,602,431[73]
# 2                                         990,000[71]
# 3                                         832,652[75]
# 4                                         343,244[76]
# 5                                         346,849[78]
# 6                                         368,617[80]
# 7                                         153,144[83]
# 8                                         106,854[84]
# 9                                         161,649[85]
# 10                                        102,000[71]
# 11                                        114,000[71]
# 12                                     10,200,000[71]
# 13  Notes ^ Includes sales or registrations of hig...
#
#                                  Market share  (2022)  \
# 0                                           30.0%[72]
# 1                                           23.0%[73]
# 2                                            7.7%[71]
# 3                                           31.4%[75]
# 4                                           18.7%[76]
# 5                                           21.6%[79]
# 6                                           22.9%[81]
# 7                                           87.8%[83]
# 8                                           34.9%[84]
# 9                                           56.1%[86]
# 10                                           3.0%[71]
# 11                                           9.4%[71]
# 12                                          14.0%[71]
# 13  Notes ^ Includes sales or registrations of hig...
#
#                           % of cars in use (2022)[ii]
# 0                                            4.9%[71]
# 1                                            2.4%[71]
# 2                                            1.3%[71]
# 3                                           3.85%[74]
# 4                                    3.85% (2021)[77]
# 5                                            2.7%[71]
# 6                                            2.8%[71]
# 7                                          27.73%[82]
# 8                                            5.8%[84]
# 9                                            8.8%[71]
# 10                                           0.6%[71]
# 11                                           1.6%[71]
# 12                                           2.1%[71]
# 13  Notes ^ Includes sales or registrations of hig...

# %%
csv_file_path = r'C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\ev_sales22_scraping.csv'
ev_sales22.to_csv(csv_file_path, index=False)

# %% [markdown]
# # Ev sales per country 2027-2021
# ###### Light-duty plug-in electric vehicle yearly new sales and end-of-year cumulative sales (or stock) in the top PEV selling countries and regional markets

# %%
url3 = "https://en.wikipedia.org/wiki/Electric_car_use_by_country"
ev_sales = pd.read_html(url3)[3]
ev_sales
# Out:
#                                               Country  \
#                                               Country
# 0                                        China[i][ii]
# 1                                    United States[i]
# 2                                          Germany[i]
# 3                                              France
# 4                                      United Kingdom
# 5                                     Norway[iii][ii]
# 6                                     Netherlands[ii]
# 7                                          Sweden[ii]
# 8                                    Japan[i][iv][ii]
# 9                                              Canada
# 10                                    Global total[i]
# 11  Light-duty plug-in cumulative registrations in...
# 12                                  Europe (EU+3)[vi]
# 13                                      California[i]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                    China[vii] (all class segments)
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2021  \
#                                                 stock
# 0                                  7,842,668 [87][88]
# 1                                      2,322,291 [16]
# 2                                 ≈1,380,000 [18][19]
# 3                                       786,274 [103]
# 4                                      ≈745,000 [109]
# 5                                       647,000 [115]
# 6                                       390,454 [124]
# 7                               355,737 [1][129][130]
# 8                                       337,377 [133]
# 9                                       297,960 [136]
# 10                              17.5 million [5][138]
# 11  Light-duty plug-in cumulative registrations in...
# 12       5.67 million [13][14][15][32][139][140][141]
# 13                      1,072,136 [144][145][20][146]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                9,076,447 [87][89][32][90][93][151]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                        \
#                                                 sales
# 0                                      3,334,000 [87]
# 1                                        607,567 [16]
# 2                                        681,410 [19]
# 3                                       315,978 [103]
# 4                                       305,281 [110]
# 5                                       167,949 [116]
# 6                                        95,464 [125]
# 7                                       138,033 [130]
# 8                                        44,296 [133]
# 9                                        87,700 [136]
# 10                                    6,754,000 [138]
# 11  Light-duty plug-in cumulative registrations in...
# 12                                 2,332,798 [13][15]
# 13                                      237,618 [144]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                                     3,521,000 [87]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2020  \
#                                                 stock
# 0                                      4,508,668 [88]
# 1                                      1,741,566 [94]
# 2                                       ≈700,000 [18]
# 3                                       470,295 [104]
# 4                                    434,282 [1][111]
# 5                                       480,008 [117]
# 6                                       297,380 [126]
# 7                                    193,054 [1][129]
# 8                                         297,181 [2]
# 9                                       209,075 [136]
# 10                                10.8 million [5][v]
# 11  Light-duty plug-in cumulative registrations in...
# 12                  3,336,141 [14][32][139][140][141]
# 13                             834,518 [145][20][146]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                    5,555,447 [89][32][90][93][151]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                        \
#                                                 sales
# 0                                      1,246,000 [89]
# 1                                        297,939 [94]
# 2                                        394,632 [99]
# 3                                       194,881 [104]
# 4                                       175,082 [111]
# 5                                       113,588 [118]
# 6                                        89,362 [127]
# 7                                        96,054 [129]
# 8                                          29,000 [2]
# 9                                        51,376 [136]
# 10                                  3,240,000 [25][v]
# 11  Light-duty plug-in cumulative registrations in...
# 12                                     1,403,812 [14]
# 13                                      132,742 [145]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                                     1,367,000 [89]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2019  \
#                                                 stock
# 0                                       3,349,100 [1]
# 1                                       1,450,020 [1]
# 2                         305,589 [32][100][101][102]
# 3                                       275,575 [104]
# 4                                         259,200 [1]
# 5                                       384,066 [119]
# 6                                       207,922 [126]
# 7                                          97,000 [1]
# 8                                         267,415 [2]
# 9                                         141,100 [1]
# 10                                      7,167,830 [1]
# 11  Light-duty plug-in cumulative registrations in...
# 12                      1,935,010 [32][139][140][141]
# 13                             701,776 [145][20][146]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                        4,188,447 [32][90][93][151]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                        \
#                                                 sales
# 0                                      1,204,000 [90]
# 1                                        329,528 [95]
# 2                                       108,839 [102]
# 3                                        69,466 [105]
# 4                                        72,584 [112]
# 5                                        88,443 [120]
# 6                                          67,520 [1]
# 7                                        41,784 [131]
# 8                                        43,867 [134]
# 9                                          50,960 [1]
# 10                                      2,101,680 [1]
# 11  Light-duty plug-in cumulative registrations in...
# 12                                  588,575 [14][141]
# 13                                      159,081 [145]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                                     1,204,000 [90]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2018  \
#                                                 stock
# 0                                  2,243,772 [91][92]
# 1                                      1,126,000 [96]
# 2                              196,750 [32][100][101]
# 3                         204,617 [52][106][107][108]
# 4                                       197,000 [113]
# 5                                       296,215 [121]
# 6                                       145,882 [126]
# 7                                    79,579 [91][132]
# 8                                         239,242 [2]
# 9                                          90,100 [1]
# 10                                  5,127,297 [8][91]
# 11  Light-duty plug-in cumulative registrations in...
# 12                      1,346,435 [32][142][140][143]
# 13                                  542,695 [20][145]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                            2,984,447 [32][93][151]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                        \
#                                                 sales
# 0                                   1,016,002 [92][i]
# 1                                        361,307 [96]
# 2                                        67,504 [101]
# 3                                        53,745 [108]
# 4                                     59,911 [i][114]
# 5                                        86,290 [122]
# 6                                        29,187 [128]
# 7                                        29,909 [132]
# 8                                        52,013 [135]
# 9                                          44,150 [1]
# 10                                      2,018,247 [8]
# 11  Light-duty plug-in cumulative registrations in...
# 12                                 406,052 [142][143]
# 13                                      163,765 [145]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                                    1,256,000 [151]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2017  \
#                                                 stock
# 0                                      1,227,770 [91]
# 1                                    764,666 [97][98]
# 2                                   129,246 [32][100]
# 3                              149,797 [52][106][107]
# 4                                        137,000[113]
# 5                                       209,122 [121]
# 6                                       121,540 [126]
# 7                                         49,670 [91]
# 8                                        205,212 [91]
# 9                                         45,950 [91]
# 10                                     3,109,050 [91]
# 11  Light-duty plug-in cumulative registrations in...
# 12                             940,383 [32][142][140]
# 13                                  378,930 [20][145]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                                 1,728,447 [32][93]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#
#                                                 sales
# 0                                     579,000 [93][i]
# 1                                        199,818 [96]
# 2                                        54,492 [100]
# 3                                        42,799 [108]
# 4                                     49,182 [i][114]
# 5                                        71,737 [123]
# 6                                        11,085 [128]
# 7                                        19,793 [132]
# 8                                         54,100 [91]
# 9                                        18,746 [137]
# 10                                     1,148,700 [91]
# 11  Light-duty plug-in cumulative registrations in...
# 12                                 302,383 [142][140]
# 13                                      107,779 [145]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                                       777,000 [93]
# 16  Notes ^ a b c d e f g h i j Only includes plug...

# %%
csv_file_path = r'C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\ev_sales_scraping.csv'
ev_sales.to_csv(csv_file_path, index=False)

# %% [markdown]
# # Scraping updated prices

# %%
url = "https://ev-database.org/#sort:path~type~order=.rank~number~desc|range-slider-range:prev~next=0~1200|range-slider-acceleration:prev~next=2~23|range-slider-topspeed:prev~next=110~350|range-slider-battery:prev~next=10~200|range-slider-towweight:prev~next=0~2500|range-slider-fastcharge:prev~next=0~1500|paging:currentPage=0|paging:number=all"

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

# %%
ev_prices2 = []

ev_elements = soup.find_all('div', class_='list-item')

# %%
data_wrappers = soup.find_all('div', class_='data-wrapper')

cars_list = []

for wrapper in data_wrappers:
    car_name_element = wrapper.find('h2')
    car_name = car_name_element.get_text(strip=True) if car_name_element else 'Name not found'

    price_de_element = wrapper.find('span', class_='country_de')
    price_de = price_de_element.get_text(strip=True) if price_de_element else 'DE Price not found'

    price_uk_element = wrapper.find('span', class_='country_uk')
    price_uk = price_uk_element.get_text(strip=True) if price_uk_element else 'UK Price not found'

    price_nl_element = wrapper.find('span', class_='country_nl')  
    price_nl = price_nl_element.get_text(strip=True) if price_us_element else 'NL Price not found'

    car_acceleration_element = wrapper.find('span', class_='acceleration')  
    car_acceleration = car_acceleration_element.get_text(strip=True) if car_acceleration_element else 'Acceleration not found'

    car_top_speed_element = wrapper.find('span', class_='topspeed')  
    car_top_speed = car_top_speed_element.get_text(strip=True) if car_top_speed_element else 'Top speed not found'

    car_range_element = wrapper.find('span', class_='erange_real')  
    car_range = car_range_element.get_text(strip=True) if car_range_element else 'Range not found'

    car_efficiency_element = wrapper.find('span', class_='efficiency')  
    car_efficiency = car_efficiency_element.get_text(strip=True) if car_efficiency_element else 'Efficiency not found'

    car_fastcharge_element = wrapper.find('span', class_='fastcharge_speed_print')  
    car_fastcharge = car_fastcharge_element.get_text(strip=True) if car_fastcharge_element else 'Fastcharge not found'
    
    car_towing_capacity_element = wrapper.find('span', class_='towweight')  
    car_towing_capacity = car_towing_capacity_element.get_text(strip=True) if car_towing_capacity_element else 'Towing capacity not found' 
    
    car_towing_capacity_element = wrapper.find('span', class_='towweight')  
    car_towing_capacity = car_towing_capacity_element.get_text(strip=True) if car_towing_capacity_element else 'Towing capacity not found' 
    
    

    car_data = {
        'Name': car_name,
        'DE Price': price_de,
        'UK Price': price_uk,
        'NL Price': price_nl,
        'Acceleration 0 to 100': car_acceleration,
        'Top Speed': car_top_speed,
        'Range': car_range,
        'Efficiency': car_efficiency,
        'Fastcharge': car_fastcharge,
        'Towing capacity in kg': car_towing_capacity
    }
    cars_list.append(car_data)

for car in cars_list:
    print(car)
# Out:
# {'Name': 'TeslaModel Y Long Range Dual Motor', 'DE Price': '€59,017', 'UK Price': '£52,990', 'NL Price': '€54,993', 'Acceleration 0 to 100': '5.0 sec', 'Top Speed': '217 km/h', 'Range': '435 km', 'Efficiency': '172 Wh/km', 'Fastcharge': '670 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'BYDATTO 3', 'DE Price': '€44,625', 'UK Price': '£37,195', 'NL Price': '€42,998', 'Acceleration 0 to 100': '7.3 sec', 'Top Speed': '160 km/h', 'Range': '330 km', 'Efficiency': '183 Wh/km', 'Fastcharge': '370 km/h', 'Towing capacity in kg': ''}
# {'Name': 'TeslaModel 3', 'DE Price': '€46,220', 'UK Price': '£39,990', 'NL Price': '€43,993', 'Acceleration 0 to 100': '6.1 sec', 'Top Speed': '201 km/h', 'Range': '420 km', 'Efficiency': '137 Wh/km', 'Fastcharge': '700 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'TeslaModel 3 Long Range Dual Motor', 'DE Price': '€55,220', 'UK Price': '£49,990', 'NL Price': '€51,993', 'Acceleration 0 to 100': '4.4 sec', 'Top Speed': '201 km/h', 'Range': '505 km', 'Efficiency': '149 Wh/km', 'Fastcharge': '780 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'TeslaModel Y', 'DE Price': '€47,567', 'UK Price': '£44,990', 'NL Price': '€45,993', 'Acceleration 0 to 100': '6.9 sec', 'Top Speed': '217 km/h', 'Range': '350 km', 'Efficiency': '164 Wh/km', 'Fastcharge': '580 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'MGMG4 Electric 64 kWh', 'DE Price': '€39,990', 'UK Price': '£29,495', 'NL Price': '€35,785', 'Acceleration 0 to 100': '7.9 sec', 'Top Speed': '160 km/h', 'Range': '360 km', 'Efficiency': '171 Wh/km', 'Fastcharge': '630 km/h', 'Towing capacity in kg': '500'}
# {'Name': 'BYDSEAL 82.5 kWh AWD Excellence', 'DE Price': '€53,668', 'UK Price': '£48,695', 'NL Price': '€50,990', 'Acceleration 0 to 100': '3.8 sec', 'Top Speed': '180 km/h', 'Range': '485 km', 'Efficiency': '170 Wh/km', 'Fastcharge': '530 km/h', 'Towing capacity in kg': ''}
# {'Name': 'BMWiX xDrive40', 'DE Price': '€77,300', 'UK Price': '£69,905', 'NL Price': '€84,998', 'Acceleration 0 to 100': '6.1 sec', 'Top Speed': '200 km/h', 'Range': '360 km', 'Efficiency': '197 Wh/km', 'Fastcharge': '480 km/h', 'Towing capacity in kg': '2500'}
# {'Name': 'Citroene-C3', 'DE Price': '€23,300', 'UK Price': '* £21,000', 'NL Price': '€24,290', 'Acceleration 0 to 100': '11.0 sec', 'Top Speed': '135 km/h', 'Range': '250 km', 'Efficiency': '176 Wh/km', 'Fastcharge': '320 km/h', 'Towing capacity in kg': ''}
# {'Name': 'BMWi4 eDrive40', 'DE Price': '€59,200', 'UK Price': '£57,890', 'NL Price': '€62,992', 'Acceleration 0 to 100': '5.7 sec', 'Top Speed': '190 km/h', 'Range': '515 km', 'Efficiency': '157 Wh/km', 'Fastcharge': '800 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'BMWiX1 xDrive30', 'DE Price': '€55,000', 'UK Price': '£47,465', 'NL Price': '€57,850', 'Acceleration 0 to 100': '5.6 sec', 'Top Speed': '180 km/h', 'Range': '380 km', 'Efficiency': '170 Wh/km', 'Fastcharge': '550 km/h', 'Towing capacity in kg': '1200'}
# {'Name': 'HyundaiKona Electric 64 kWh', 'DE Price': '€42,900', 'UK Price': 'N/A', 'NL Price': 'N/A', 'Acceleration 0 to 100': '7.9 sec', 'Top Speed': '167 km/h', 'Range': '390 km', 'Efficiency': '164 Wh/km', 'Fastcharge': '370 km/h', 'Towing capacity in kg': '300'}
# {'Name': 'KiaNiro EV', 'DE Price': '€45,690', 'UK Price': '£37,295', 'NL Price': '€39,995', 'Acceleration 0 to 100': '7.8 sec', 'Top Speed': '167 km/h', 'Range': '385 km', 'Efficiency': '168 Wh/km', 'Fastcharge': '390 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'VolvoEX30 Single Motor ER', 'DE Price': '€41,790', 'UK Price': '£38,545', 'NL Price': '€41,495', 'Acceleration 0 to 100': '5.3 sec', 'Top Speed': '180 km/h', 'Range': '370 km', 'Efficiency': '173 Wh/km', 'Fastcharge': '550 km/h', 'Towing capacity in kg': '1400'}
# {'Name': 'BYDHAN', 'DE Price': '€70,805', 'UK Price': 'N/A', 'NL Price': '€71,490', 'Acceleration 0 to 100': '3.9 sec', 'Top Speed': '180 km/h', 'Range': '475 km', 'Efficiency': '180 Wh/km', 'Fastcharge': '450 km/h', 'Towing capacity in kg': ''}
# {'Name': 'RenaultMegane E-Tech EV60 220hp', 'DE Price': '€46,600', 'UK Price': '£36,995', 'NL Price': '€42,970', 'Acceleration 0 to 100': '7.4 sec', 'Top Speed': '160 km/h', 'Range': '380 km', 'Efficiency': '158 Wh/km', 'Fastcharge': '530 km/h', 'Towing capacity in kg': '900'}
# {'Name': 'Rolls-RoyceSpectre', 'DE Price': '* €400,000', 'UK Price': '* £350,000', 'NL Price': '* €400,000', 'Acceleration 0 to 100': '4.5 sec', 'Top Speed': '250 km/h', 'Range': '465 km', 'Efficiency': '219 Wh/km', 'Fastcharge': '540 km/h', 'Towing capacity in kg': ''}
# {'Name': 'TeslaModel Y Performance', 'DE Price': '€63,667', 'UK Price': '£59,990', 'NL Price': '€60,993', 'Acceleration 0 to 100': '3.7 sec', 'Top Speed': '250 km/h', 'Range': '415 km', 'Efficiency': '181 Wh/km', 'Fastcharge': '640 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'Smart#1', 'DE Price': '€42,490', 'UK Price': '£35,950', 'NL Price': '€41,395', 'Acceleration 0 to 100': '6.7 sec', 'Top Speed': '180 km/h', 'Range': '335 km', 'Efficiency': '185 Wh/km', 'Fastcharge': '520 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'BYDDOLPHIN 60.4 kWh', 'DE Price': '€35,990', 'UK Price': '£30,195', 'NL Price': '€36,490', 'Acceleration 0 to 100': '7.0 sec', 'Top Speed': '160 km/h', 'Range': '340 km', 'Efficiency': '178 Wh/km', 'Fastcharge': '340 km/h', 'Towing capacity in kg': '0'}
# {'Name': 'DaciaSpring Electric 45', 'DE Price': '€22,550', 'UK Price': 'N/A', 'NL Price': '€21,750', 'Acceleration 0 to 100': '19.1 sec', 'Top Speed': '125 km/h', 'Range': '165 km', 'Efficiency': '152 Wh/km', 'Fastcharge': '180 km/h', 'Towing capacity in kg': ''}
# {'Name': 'TeslaModel S Plaid', 'DE Price': '€110,970', 'UK Price': '* £100,000', 'NL Price': '€110,993', 'Acceleration 0 to 100': '2.1 sec', 'Top Speed': '282 km/h', 'Range': '560 km', 'Efficiency': '170 Wh/km', 'Fastcharge': '780 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'BMWi5 eDrive40 Sedan', 'DE Price': '€70,200', 'UK Price': '£74,105', 'NL Price': '€77,572', 'Acceleration 0 to 100': '6.0 sec', 'Top Speed': '193 km/h', 'Range': '475 km', 'Efficiency': '171 Wh/km', 'Fastcharge': '710 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'TeslaModel S Dual Motor', 'DE Price': '€95,970', 'UK Price': '* £85,000', 'NL Price': '€95,993', 'Acceleration 0 to 100': '3.2 sec', 'Top Speed': '250 km/h', 'Range': '575 km', 'Efficiency': '165 Wh/km', 'Fastcharge': '800 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'BYDSEAL 82.5 kWh RWD Design', 'DE Price': '€47,578', 'UK Price': '£45,695', 'NL Price': '€47,990', 'Acceleration 0 to 100': '5.9 sec', 'Top Speed': '180 km/h', 'Range': '500 km', 'Efficiency': '165 Wh/km', 'Fastcharge': '550 km/h', 'Towing capacity in kg': ''}
# {'Name': 'AudiQ8 e-tron 55 quattro', 'DE Price': '€85,300', 'UK Price': '£77,800', 'NL Price': '€82,985', 'Acceleration 0 to 100': '5.6 sec', 'Top Speed': '200 km/h', 'Range': '505 km', 'Efficiency': '210 Wh/km', 'Fastcharge': '640 km/h', 'Towing capacity in kg': '1800'}
# {'Name': 'BMWiX3', 'DE Price': '€67,300', 'UK Price': '£64,165', 'NL Price': '€71,462', 'Acceleration 0 to 100': '6.8 sec', 'Top Speed': '180 km/h', 'Range': '385 km', 'Efficiency': '192 Wh/km', 'Fastcharge': '520 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'HyundaiIONIQ 6 Long Range AWD', 'DE Price': '€61,100', 'UK Price': '£50,540', 'NL Price': '€59,395', 'Acceleration 0 to 100': '5.1 sec', 'Top Speed': '185 km/h', 'Range': '440 km', 'Efficiency': '168 Wh/km', 'Fastcharge': '1150 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'MGZS EV Long Range', 'DE Price': '€37,990', 'UK Price': '£32,995', 'NL Price': '€39,885', 'Acceleration 0 to 100': '8.4 sec', 'Top Speed': '175 km/h', 'Range': '370 km', 'Efficiency': '185 Wh/km', 'Fastcharge': '420 km/h', 'Towing capacity in kg': '500'}
# {'Name': 'BYDTANG', 'DE Price': '€71,400', 'UK Price': 'N/A', 'NL Price': '€73,300', 'Acceleration 0 to 100': '4.6 sec', 'Top Speed': '180 km/h', 'Range': '360 km', 'Efficiency': '240 Wh/km', 'Fastcharge': '330 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'HongqiE-HS9 99 kWh', 'DE Price': 'N/A', 'UK Price': 'N/A', 'NL Price': '€79,995', 'Acceleration 0 to 100': '4.9 sec', 'Top Speed': '200 km/h', 'Range': '370 km', 'Efficiency': '243 Wh/km', 'Fastcharge': '430 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'KiaEV6 Long Range 2WD', 'DE Price': '€51,990', 'UK Price': '£45,245', 'NL Price': '€51,995', 'Acceleration 0 to 100': '7.3 sec', 'Top Speed': '185 km/h', 'Range': '410 km', 'Efficiency': '180 Wh/km', 'Fastcharge': '1070 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'HyundaiKona Electric 65 kWh', 'DE Price': '€47,190', 'UK Price': '£38,595', 'NL Price': '€43,995', 'Acceleration 0 to 100': '8.8 sec', 'Top Speed': '170 km/h', 'Range': '390 km', 'Efficiency': '168 Wh/km', 'Fastcharge': '400 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'TeslaModel Y', 'DE Price': '€47,567', 'UK Price': '£44,990', 'NL Price': '€45,993', 'Acceleration 0 to 100': '6.9 sec', 'Top Speed': '217 km/h', 'Range': '350 km', 'Efficiency': '164 Wh/km', 'Fastcharge': '810 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'ToyotabZ4X FWD', 'DE Price': '€47,490', 'UK Price': '£46,110', 'NL Price': '€48,995', 'Acceleration 0 to 100': '7.5 sec', 'Top Speed': '160 km/h', 'Range': '340 km', 'Efficiency': '188 Wh/km', 'Fastcharge': '510 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'AudiQ4 e-tron 40', 'DE Price': 'N/A', 'UK Price': '£50,630', 'NL Price': 'N/A', 'Acceleration 0 to 100': '8.5 sec', 'Top Speed': '160 km/h', 'Range': '405 km', 'Efficiency': '189 Wh/km', 'Fastcharge': '630 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'BMWiX xDrive50', 'DE Price': '€100,100', 'UK Price': '£102,755', 'NL Price': '€105,097', 'Acceleration 0 to 100': '4.6 sec', 'Top Speed': '200 km/h', 'Range': '505 km', 'Efficiency': '208 Wh/km', 'Fastcharge': '680 km/h', 'Towing capacity in kg': '2500'}
# {'Name': 'BMWi4 M50', 'DE Price': '€70,800', 'UK Price': '£71,085', 'NL Price': '€76,786', 'Acceleration 0 to 100': '3.9 sec', 'Top Speed': '225 km/h', 'Range': '450 km', 'Efficiency': '179 Wh/km', 'Fastcharge': '700 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'Peugeote-3008 73 kWh', 'DE Price': '€48,650', 'UK Price': '* £42,000', 'NL Price': '€48,190', 'Acceleration 0 to 100': '8.7 sec', 'Top Speed': '170 km/h', 'Range': '385 km', 'Efficiency': '190 Wh/km', 'Fastcharge': '440 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Fiat500e Hatchback 42 kWh', 'DE Price': '€34,990', 'UK Price': '£31,195', 'NL Price': '€34,490', 'Acceleration 0 to 100': '9.0 sec', 'Top Speed': '150 km/h', 'Range': '235 km', 'Efficiency': '159 Wh/km', 'Fastcharge': '390 km/h', 'Towing capacity in kg': ''}
# {'Name': 'HyundaiIONIQ 6 Long Range 2WD', 'DE Price': '€54,000', 'UK Price': '£47,040', 'NL Price': '€50,895', 'Acceleration 0 to 100': '7.4 sec', 'Top Speed': '185 km/h', 'Range': '495 km', 'Efficiency': '149 Wh/km', 'Fastcharge': '1290 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'RenaultZoe ZE50 R110', 'DE Price': '€36,840', 'UK Price': 'N/A', 'NL Price': '€34,895', 'Acceleration 0 to 100': '11.4 sec', 'Top Speed': '135 km/h', 'Range': '315 km', 'Efficiency': '165 Wh/km', 'Fastcharge': '230 km/h', 'Towing capacity in kg': ''}
# {'Name': 'BMWi7 xDrive60', 'DE Price': '€139,900', 'UK Price': '£113,970', 'NL Price': '€145,453', 'Acceleration 0 to 100': '4.7 sec', 'Top Speed': '240 km/h', 'Range': '510 km', 'Efficiency': '199 Wh/km', 'Fastcharge': '760 km/h', 'Towing capacity in kg': '2000'}
# {'Name': 'VolkswagenID.7 Pro', 'DE Price': '€56,995', 'UK Price': '£55,570', 'NL Price': '€63,990', 'Acceleration 0 to 100': '6.5 sec', 'Top Speed': '180 km/h', 'Range': '475 km', 'Efficiency': '162 Wh/km', 'Fastcharge': '710 km/h', 'Towing capacity in kg': '1200'}
# {'Name': 'HyundaiIONIQ 5 Long Range 2WD', 'DE Price': '€47,900', 'UK Price': '£46,945', 'NL Price': '€52,895', 'Acceleration 0 to 100': '7.3 sec', 'Top Speed': '185 km/h', 'Range': '390 km', 'Efficiency': '190 Wh/km', 'Fastcharge': '1020 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'SkodaEnyaq 85', 'DE Price': '€48,900', 'UK Price': '£44,540', 'NL Price': '€49,990', 'Acceleration 0 to 100': '6.7 sec', 'Top Speed': '180 km/h', 'Range': '455 km', 'Efficiency': '169 Wh/km', 'Fastcharge': '680 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'Peugeote-208', 'DE Price': '€39,100', 'UK Price': '£31,595', 'NL Price': 'N/A', 'Acceleration 0 to 100': '8.1 sec', 'Top Speed': '150 km/h', 'Range': '285 km', 'Efficiency': '162 Wh/km', 'Fastcharge': '460 km/h', 'Towing capacity in kg': ''}
# {'Name': 'CUPRABorn 150 kW - 58 kWh', 'DE Price': '€39,370', 'UK Price': '£36,475', 'NL Price': '€39,990', 'Acceleration 0 to 100': '7.3 sec', 'Top Speed': '160 km/h', 'Range': '350 km', 'Efficiency': '166 Wh/km', 'Fastcharge': '470 km/h', 'Towing capacity in kg': ''}
# {'Name': 'BYDDOLPHIN 44.9 kWh Active', 'DE Price': '€29,990', 'UK Price': '* £26,000', 'NL Price': '€29,990', 'Acceleration 0 to 100': '10.0 sec', 'Top Speed': '150 km/h', 'Range': '255 km', 'Efficiency': '176 Wh/km', 'Fastcharge': '260 km/h', 'Towing capacity in kg': ''}
# {'Name': 'MGMG4 Electric 51 kWh', 'DE Price': '€34,990', 'UK Price': '£26,995', 'NL Price': '€32,285', 'Acceleration 0 to 100': '7.7 sec', 'Top Speed': '160 km/h', 'Range': '300 km', 'Efficiency': '169 Wh/km', 'Fastcharge': '390 km/h', 'Towing capacity in kg': '500'}
# {'Name': 'RenaultTwingo Electric', 'DE Price': '€28,000', 'UK Price': 'N/A', 'NL Price': '€24,190', 'Acceleration 0 to 100': '12.6 sec', 'Top Speed': '135 km/h', 'Range': '135 km', 'Efficiency': '158 Wh/km', 'Fastcharge': '-', 'Towing capacity in kg': ''}
# {'Name': 'Citroene-C4', 'DE Price': '€36,040', 'UK Price': '£31,995', 'NL Price': '€37,830', 'Acceleration 0 to 100': '9.7 sec', 'Top Speed': '150 km/h', 'Range': '290 km', 'Efficiency': '160 Wh/km', 'Fastcharge': '460 km/h', 'Towing capacity in kg': ''}
# {'Name': 'MiniCooper SE', 'DE Price': '€35,700', 'UK Price': '£32,550', 'NL Price': '€38,690', 'Acceleration 0 to 100': '7.3 sec', 'Top Speed': '150 km/h', 'Range': '180 km', 'Efficiency': '161 Wh/km', 'Fastcharge': '260 km/h', 'Towing capacity in kg': ''}
# {'Name': 'MercedesEQA 250+', 'DE Price': 'N/A', 'UK Price': '£49,750', 'NL Price': 'N/A', 'Acceleration 0 to 100': '8.6 sec', 'Top Speed': '160 km/h', 'Range': '420 km', 'Efficiency': '168 Wh/km', 'Fastcharge': '580 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'HyundaiIONIQ 5 N', 'DE Price': 'N/A', 'UK Price': '£65,000', 'NL Price': 'N/A', 'Acceleration 0 to 100': '3.4 sec', 'Top Speed': '260 km/h', 'Range': '385 km', 'Efficiency': '208 Wh/km', 'Fastcharge': '950 km/h', 'Towing capacity in kg': ''}
# {'Name': 'VolkswagenID.3 Pro', 'DE Price': '€39,995', 'UK Price': '£37,115', 'NL Price': '€44,990', 'Acceleration 0 to 100': '7.3 sec', 'Top Speed': '160 km/h', 'Range': '350 km', 'Efficiency': '166 Wh/km', 'Fastcharge': '450 km/h', 'Towing capacity in kg': '0'}
# {'Name': 'KiaEV6 GT', 'DE Price': '€72,990', 'UK Price': '£62,645', 'NL Price': '€69,295', 'Acceleration 0 to 100': '3.5 sec', 'Top Speed': '260 km/h', 'Range': '360 km', 'Efficiency': '206 Wh/km', 'Fastcharge': '940 km/h', 'Towing capacity in kg': '1800'}
# {'Name': 'BMWi4 eDrive35', 'DE Price': '€56,500', 'UK Price': '£49,995', 'NL Price': '€59,362', 'Acceleration 0 to 100': '6.0 sec', 'Top Speed': '190 km/h', 'Range': '430 km', 'Efficiency': '156 Wh/km', 'Fastcharge': '580 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'JeepAvenger Electric', 'DE Price': '€37,000', 'UK Price': '£35,700', 'NL Price': '€39,500', 'Acceleration 0 to 100': '9.0 sec', 'Top Speed': '150 km/h', 'Range': '310 km', 'Efficiency': '164 Wh/km', 'Fastcharge': '500 km/h', 'Towing capacity in kg': ''}
# {'Name': 'KiaEV9 99.8 kWh AWD', 'DE Price': '€76,490', 'UK Price': 'N/A', 'NL Price': '€71,495', 'Acceleration 0 to 100': '6.0 sec', 'Top Speed': '200 km/h', 'Range': '425 km', 'Efficiency': '226 Wh/km', 'Fastcharge': '740 km/h', 'Towing capacity in kg': '2500'}
# {'Name': 'Zeekr001 Performance AWD', 'DE Price': '€63,970', 'UK Price': 'N/A', 'NL Price': '€63,490', 'Acceleration 0 to 100': '3.8 sec', 'Top Speed': '200 km/h', 'Range': '505 km', 'Efficiency': '186 Wh/km', 'Fastcharge': '700 km/h', 'Towing capacity in kg': '2000'}
# {'Name': 'VolkswagenID. Buzz Pro', 'DE Price': '€64,581', 'UK Price': '£58,915', 'NL Price': '€66,160', 'Acceleration 0 to 100': '10.2 sec', 'Top Speed': '145 km/h', 'Range': '345 km', 'Efficiency': '223 Wh/km', 'Fastcharge': '480 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'VolkswagenID.4 Pro', 'DE Price': '€46,335', 'UK Price': '£46,035', 'NL Price': '* €52,000', 'Acceleration 0 to 100': '6.7 sec', 'Top Speed': '180 km/h', 'Range': '435 km', 'Efficiency': '177 Wh/km', 'Fastcharge': '650 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'Audie-tron GT RS', 'DE Price': '€146,050', 'UK Price': '£119,000', 'NL Price': '€154,835', 'Acceleration 0 to 100': '3.3 sec', 'Top Speed': '250 km/h', 'Range': '405 km', 'Efficiency': '210 Wh/km', 'Fastcharge': '1000 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Hondae:Ny1', 'DE Price': '€47,590', 'UK Price': 'N/A', 'NL Price': '€48,750', 'Acceleration 0 to 100': '7.6 sec', 'Top Speed': '160 km/h', 'Range': '335 km', 'Efficiency': '185 Wh/km', 'Fastcharge': '300 km/h', 'Towing capacity in kg': ''}
# {'Name': 'BMWiX1 eDrive20', 'DE Price': '€47,900', 'UK Price': '£45,465', 'NL Price': '€48,316', 'Acceleration 0 to 100': '8.3 sec', 'Top Speed': '170 km/h', 'Range': '390 km', 'Efficiency': '166 Wh/km', 'Fastcharge': '560 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'OpelAstra Electric', 'DE Price': '€41,990', 'UK Price': '£37,795', 'NL Price': '€39,999', 'Acceleration 0 to 100': '9.2 sec', 'Top Speed': '170 km/h', 'Range': '305 km', 'Efficiency': '167 Wh/km', 'Fastcharge': '490 km/h', 'Towing capacity in kg': '0'}
# {'Name': 'OpelCorsa-e', 'DE Price': 'N/A', 'UK Price': '£33,930', 'NL Price': 'N/A', 'Acceleration 0 to 100': '8.1 sec', 'Top Speed': '150 km/h', 'Range': '295 km', 'Efficiency': '157 Wh/km', 'Fastcharge': '470 km/h', 'Towing capacity in kg': ''}
# {'Name': 'NissanAriya 87kWh', 'DE Price': '€58,990', 'UK Price': '£44,645', 'NL Price': '€47,990', 'Acceleration 0 to 100': '7.6 sec', 'Top Speed': '160 km/h', 'Range': '450 km', 'Efficiency': '193 Wh/km', 'Fastcharge': '540 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'Peugeote-3008 98 kWh Long Range', 'DE Price': '* €55,000', 'UK Price': '* £48,000', 'NL Price': '* €55,000', 'Acceleration 0 to 100': '9.0 sec', 'Top Speed': '170 km/h', 'Range': '505 km', 'Efficiency': '194 Wh/km', 'Fastcharge': '660 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Smart#1 Brabus', 'DE Price': '€48,990', 'UK Price': '£43,450', 'NL Price': '€48,895', 'Acceleration 0 to 100': '3.9 sec', 'Top Speed': '180 km/h', 'Range': '315 km', 'Efficiency': '197 Wh/km', 'Fastcharge': '490 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'NissanLeaf', 'DE Price': '€33,400', 'UK Price': '£28,995', 'NL Price': '€35,090', 'Acceleration 0 to 100': '7.9 sec', 'Top Speed': '144 km/h', 'Range': '235 km', 'Efficiency': '166 Wh/km', 'Fastcharge': '230 km/h', 'Towing capacity in kg': ''}
# {'Name': 'LucidAir Dream Edition R', 'DE Price': '€218,000', 'UK Price': 'N/A', 'NL Price': '€222,000', 'Acceleration 0 to 100': '2.9 sec', 'Top Speed': '270 km/h', 'Range': '685 km', 'Efficiency': '172 Wh/km', 'Fastcharge': '870 km/h', 'Towing capacity in kg': ''}
# {'Name': 'LotusEletre', 'DE Price': '€95,990', 'UK Price': '£89,500', 'NL Price': '€98,690', 'Acceleration 0 to 100': '4.5 sec', 'Top Speed': '250 km/h', 'Range': '495 km', 'Efficiency': '220 Wh/km', 'Fastcharge': '1040 km/h', 'Towing capacity in kg': '2250'}
# {'Name': 'VolvoEX30 Single Motor', 'DE Price': '€36,590', 'UK Price': '£33,795', 'NL Price': '€36,795', 'Acceleration 0 to 100': '5.7 sec', 'Top Speed': '180 km/h', 'Range': '280 km', 'Efficiency': '175 Wh/km', 'Fastcharge': '430 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'MGMG4 Electric 77 kWh', 'DE Price': '€45,990', 'UK Price': '£36,495', 'NL Price': '€41,285', 'Acceleration 0 to 100': '6.5 sec', 'Top Speed': '180 km/h', 'Range': '425 km', 'Efficiency': '175 Wh/km', 'Fastcharge': '430 km/h', 'Towing capacity in kg': '500'}
# {'Name': 'HyundaiIONIQ 5 Standard Range 2WD', 'DE Price': '€43,900', 'UK Price': '£43,445', 'NL Price': '€49,295', 'Acceleration 0 to 100': '8.5 sec', 'Top Speed': '185 km/h', 'Range': '295 km', 'Efficiency': '183 Wh/km', 'Fastcharge': '720 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'CUPRABorn 170 kW - 77 kWh', 'DE Price': '€46,450', 'UK Price': '£41,975', 'NL Price': '€51,990', 'Acceleration 0 to 100': '7.0 sec', 'Top Speed': '160 km/h', 'Range': '450 km', 'Efficiency': '171 Wh/km', 'Fastcharge': '630 km/h', 'Towing capacity in kg': ''}
# {'Name': 'FiskerOcean One', 'DE Price': '€69,950', 'UK Price': '£60,880', 'NL Price': 'N/A', 'Acceleration 0 to 100': '3.9 sec', 'Top Speed': '205 km/h', 'Range': '530 km', 'Efficiency': '201 Wh/km', 'Fastcharge': '630 km/h', 'Towing capacity in kg': '1820'}
# {'Name': 'VolkswagenID.7 Pro S', 'DE Price': '* €60,000', 'UK Price': '* £59,000', 'NL Price': '* €68,000', 'Acceleration 0 to 100': '7.0 sec', 'Top Speed': '180 km/h', 'Range': '520 km', 'Efficiency': '165 Wh/km', 'Fastcharge': '800 km/h', 'Towing capacity in kg': ''}
# {'Name': 'SubaruSolterra AWD', 'DE Price': '€57,490', 'UK Price': '£49,995', 'NL Price': '€56,395', 'Acceleration 0 to 100': '6.9 sec', 'Top Speed': '160 km/h', 'Range': '320 km', 'Efficiency': '200 Wh/km', 'Fastcharge': '480 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'MGMG4 Electric XPOWER', 'DE Price': '€46,990', 'UK Price': '£36,495', 'NL Price': '€42,285', 'Acceleration 0 to 100': '3.8 sec', 'Top Speed': '200 km/h', 'Range': '320 km', 'Efficiency': '193 Wh/km', 'Fastcharge': '560 km/h', 'Towing capacity in kg': '500'}
# {'Name': 'Smart#3', 'DE Price': '€43,490', 'UK Price': '* £37,000', 'NL Price': '* €42,500', 'Acceleration 0 to 100': '6.7 sec', 'Top Speed': '180 km/h', 'Range': '355 km', 'Efficiency': '175 Wh/km', 'Fastcharge': '550 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'MazdaMX-30', 'DE Price': '€35,990', 'UK Price': '£31,250', 'NL Price': '€36,440', 'Acceleration 0 to 100': '9.7 sec', 'Top Speed': '140 km/h', 'Range': '170 km', 'Efficiency': '176 Wh/km', 'Fastcharge': '210 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Polestar4 Long Range Dual Motor', 'DE Price': '* €65,000', 'UK Price': '* £60,000', 'NL Price': '* €65,000', 'Acceleration 0 to 100': '3.8 sec', 'Top Speed': '200 km/h', 'Range': '465 km', 'Efficiency': '202 Wh/km', 'Fastcharge': '690 km/h', 'Towing capacity in kg': '2000'}
# {'Name': 'Polestar2 Long Range Single Motor', 'DE Price': '€54,475', 'UK Price': '£48,950', 'NL Price': '€55,200', 'Acceleration 0 to 100': '6.2 sec', 'Top Speed': '205 km/h', 'Range': '470 km', 'Efficiency': '168 Wh/km', 'Fastcharge': '700 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'Zeekr001 Long Range RWD', 'DE Price': '€60,970', 'UK Price': 'N/A', 'NL Price': '€60,490', 'Acceleration 0 to 100': '7.2 sec', 'Top Speed': '200 km/h', 'Range': '530 km', 'Efficiency': '177 Wh/km', 'Fastcharge': '740 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'MGMG5 Electric Long Range', 'DE Price': '€38,490', 'UK Price': '£30,995', 'NL Price': '€38,885', 'Acceleration 0 to 100': '7.7 sec', 'Top Speed': '185 km/h', 'Range': '335 km', 'Efficiency': '171 Wh/km', 'Fastcharge': '330 km/h', 'Towing capacity in kg': '500'}
# {'Name': 'OpelMokka-e', 'DE Price': '€40,650', 'UK Price': '£38,835', 'NL Price': '€39,749', 'Acceleration 0 to 100': '9.2 sec', 'Top Speed': '150 km/h', 'Range': '260 km', 'Efficiency': '178 Wh/km', 'Fastcharge': '420 km/h', 'Towing capacity in kg': ''}
# {'Name': 'LexusRZ 450e', 'DE Price': '€68,000', 'UK Price': '£64,500', 'NL Price': '€67,495', 'Acceleration 0 to 100': '5.6 sec', 'Top Speed': '160 km/h', 'Range': '320 km', 'Efficiency': '200 Wh/km', 'Fastcharge': '480 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'FiskerOcean Ultra', 'DE Price': '€57,000', 'UK Price': '£49,880', 'NL Price': '€58,990', 'Acceleration 0 to 100': '4.2 sec', 'Top Speed': '200 km/h', 'Range': '535 km', 'Efficiency': '199 Wh/km', 'Fastcharge': '640 km/h', 'Towing capacity in kg': '1820'}
# {'Name': 'TeslaModel X Dual Motor', 'DE Price': '€100,970', 'UK Price': '* £105,000', 'NL Price': '€100,993', 'Acceleration 0 to 100': '3.9 sec', 'Top Speed': '250 km/h', 'Range': '475 km', 'Efficiency': '200 Wh/km', 'Fastcharge': '660 km/h', 'Towing capacity in kg': '2250'}
# {'Name': 'RenaultZoe ZE50 R135', 'DE Price': '€37,840', 'UK Price': '£29,995', 'NL Price': '€36,195', 'Acceleration 0 to 100': '9.5 sec', 'Top Speed': '140 km/h', 'Range': '310 km', 'Efficiency': '168 Wh/km', 'Fastcharge': '230 km/h', 'Towing capacity in kg': ''}
# {'Name': 'SkodaEnyaq Coupe 85', 'DE Price': '€51,150', 'UK Price': '£46,440', 'NL Price': '€52,990', 'Acceleration 0 to 100': '6.7 sec', 'Top Speed': '180 km/h', 'Range': '485 km', 'Efficiency': '159 Wh/km', 'Fastcharge': '720 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'NIOET7 75 kWh', 'DE Price': '€81,900', 'UK Price': 'N/A', 'NL Price': '€84,900', 'Acceleration 0 to 100': '3.8 sec', 'Top Speed': '200 km/h', 'Range': '400 km', 'Efficiency': '176 Wh/km', 'Fastcharge': '540 km/h', 'Towing capacity in kg': '2000'}
# {'Name': 'Peugeote-308', 'DE Price': '€44,765', 'UK Price': '* £42,025', 'NL Price': '€43,585', 'Acceleration 0 to 100': '9.8 sec', 'Top Speed': '170 km/h', 'Range': '300 km', 'Efficiency': '169 Wh/km', 'Fastcharge': '450 km/h', 'Towing capacity in kg': ''}
# {'Name': 'MercedesEQB 250+', 'DE Price': '€53,514', 'UK Price': 'N/A', 'NL Price': '€54,966', 'Acceleration 0 to 100': '8.9 sec', 'Top Speed': '160 km/h', 'Range': '415 km', 'Efficiency': '170 Wh/km', 'Fastcharge': '560 km/h', 'Towing capacity in kg': '1400'}
# {'Name': 'VolvoEX30 Twin Motor Performance', 'DE Price': '€48,490', 'UK Price': '£40,995', 'NL Price': '€49,995', 'Acceleration 0 to 100': '3.6 sec', 'Top Speed': '180 km/h', 'Range': '360 km', 'Efficiency': '178 Wh/km', 'Fastcharge': '540 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'MercedesEQB 350 4MATIC', 'DE Price': 'N/A', 'UK Price': '£56,810', 'NL Price': 'N/A', 'Acceleration 0 to 100': '6.2 sec', 'Top Speed': '160 km/h', 'Range': '340 km', 'Efficiency': '196 Wh/km', 'Fastcharge': '490 km/h', 'Towing capacity in kg': ''}
# {'Name': 'HyundaiIONIQ 5 Long Range AWD', 'DE Price': '€59,200', 'UK Price': '£50,445', 'NL Price': '€60,995', 'Acceleration 0 to 100': '5.1 sec', 'Top Speed': '185 km/h', 'Range': '385 km', 'Efficiency': '192 Wh/km', 'Fastcharge': '1010 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'BMWi5 M60 xDrive Sedan', 'DE Price': '€99,500', 'UK Price': '£97,745', 'NL Price': '€108,427', 'Acceleration 0 to 100': '3.8 sec', 'Top Speed': '230 km/h', 'Range': '425 km', 'Efficiency': '191 Wh/km', 'Fastcharge': '630 km/h', 'Towing capacity in kg': '2000'}
# {'Name': 'KiaEV6 Long Range AWD', 'DE Price': '€55,980', 'UK Price': '£51,745', 'NL Price': '€57,995', 'Acceleration 0 to 100': '5.2 sec', 'Top Speed': '185 km/h', 'Range': '400 km', 'Efficiency': '185 Wh/km', 'Fastcharge': '1050 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'HyundaiKona Electric 39 kWh', 'DE Price': '€36,400', 'UK Price': 'N/A', 'NL Price': 'N/A', 'Acceleration 0 to 100': '9.9 sec', 'Top Speed': '155 km/h', 'Range': '245 km', 'Efficiency': '160 Wh/km', 'Fastcharge': '210 km/h', 'Towing capacity in kg': ''}
# {'Name': 'MercedesEQS 450+', 'DE Price': '€109,551', 'UK Price': 'N/A', 'NL Price': '€112,720', 'Acceleration 0 to 100': '6.1 sec', 'Top Speed': '210 km/h', 'Range': '635 km', 'Efficiency': '171 Wh/km', 'Fastcharge': '950 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'HyundaiIONIQ 6 Standard Range 2WD', 'DE Price': '€43,900', 'UK Price': 'N/A', 'NL Price': '€45,895', 'Acceleration 0 to 100': '8.8 sec', 'Top Speed': '185 km/h', 'Range': '365 km', 'Efficiency': '148 Wh/km', 'Fastcharge': '900 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'AudiQ8 e-tron Sportback 55 quattro', 'DE Price': '€87,550', 'UK Price': '£80,300', 'NL Price': '€85,385', 'Acceleration 0 to 100': '5.6 sec', 'Top Speed': '200 km/h', 'Range': '525 km', 'Efficiency': '202 Wh/km', 'Fastcharge': '660 km/h', 'Towing capacity in kg': '1800'}
# {'Name': 'VolvoXC40 Recharge Single Motor ER', 'DE Price': '€53,000', 'UK Price': 'N/A', 'NL Price': '€51,495', 'Acceleration 0 to 100': '7.3 sec', 'Top Speed': '180 km/h', 'Range': '405 km', 'Efficiency': '195 Wh/km', 'Fastcharge': '600 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'Fiat600e', 'DE Price': '€36,490', 'UK Price': '* £31,000', 'NL Price': '€35,990', 'Acceleration 0 to 100': '9.0 sec', 'Top Speed': '150 km/h', 'Range': '305 km', 'Efficiency': '167 Wh/km', 'Fastcharge': '490 km/h', 'Towing capacity in kg': ''}
# {'Name': 'MaxusMIFA 9', 'DE Price': '€68,990', 'UK Price': '£65,290', 'NL Price': 'N/A', 'Acceleration 0 to 100': '9.2 sec', 'Top Speed': '180 km/h', 'Range': '365 km', 'Efficiency': '230 Wh/km', 'Fastcharge': '330 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'Citroene-C4 X', 'DE Price': '€37,540', 'UK Price': '£31,995', 'NL Price': '€38,680', 'Acceleration 0 to 100': '9.7 sec', 'Top Speed': '150 km/h', 'Range': '285 km', 'Efficiency': '162 Wh/km', 'Fastcharge': '460 km/h', 'Towing capacity in kg': ''}
# {'Name': 'VolvoXC40 Recharge Twin Motor', 'DE Price': '€59,950', 'UK Price': '£51,755', 'NL Price': '€59,995', 'Acceleration 0 to 100': '4.8 sec', 'Top Speed': '180 km/h', 'Range': '390 km', 'Efficiency': '203 Wh/km', 'Fastcharge': '580 km/h', 'Towing capacity in kg': '1800'}
# {'Name': 'BMWiX M60', 'DE Price': '€136,100', 'UK Price': '£122,775', 'NL Price': '€138,383', 'Acceleration 0 to 100': '3.8 sec', 'Top Speed': '250 km/h', 'Range': '485 km', 'Efficiency': '217 Wh/km', 'Fastcharge': '650 km/h', 'Towing capacity in kg': '2500'}
# {'Name': 'MercedesEQB 300 4MATIC', 'DE Price': 'N/A', 'UK Price': '£55,310', 'NL Price': 'N/A', 'Acceleration 0 to 100': '8.0 sec', 'Top Speed': '160 km/h', 'Range': '340 km', 'Efficiency': '196 Wh/km', 'Fastcharge': '490 km/h', 'Towing capacity in kg': ''}
# {'Name': 'VolkswagenID.5 Pro', 'DE Price': '€48,970', 'UK Price': '£50,940', 'NL Price': '* €56,000', 'Acceleration 0 to 100': '6.7 sec', 'Top Speed': '180 km/h', 'Range': '455 km', 'Efficiency': '169 Wh/km', 'Fastcharge': '680 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'MGMarvel R', 'DE Price': '€46,990', 'UK Price': 'N/A', 'NL Price': '€49,485', 'Acceleration 0 to 100': '7.9 sec', 'Top Speed': '200 km/h', 'Range': '365 km', 'Efficiency': '192 Wh/km', 'Fastcharge': '400 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'ZeekrX Privilege AWD', 'DE Price': '€50,470', 'UK Price': 'N/A', 'NL Price': '€50,490', 'Acceleration 0 to 100': '3.8 sec', 'Top Speed': '180 km/h', 'Range': '350 km', 'Efficiency': '183 Wh/km', 'Fastcharge': '520 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'NIOET5 100 kWh', 'DE Price': '€68,500', 'UK Price': 'N/A', 'NL Price': '€71,700', 'Acceleration 0 to 100': '4.0 sec', 'Top Speed': '200 km/h', 'Range': '500 km', 'Efficiency': '180 Wh/km', 'Fastcharge': '520 km/h', 'Towing capacity in kg': '1400'}
# {'Name': 'TeslaModel X Plaid', 'DE Price': '€115,970', 'UK Price': '* £120,000', 'NL Price': '€115,993', 'Acceleration 0 to 100': '2.6 sec', 'Top Speed': '262 km/h', 'Range': '455 km', 'Efficiency': '209 Wh/km', 'Fastcharge': '630 km/h', 'Towing capacity in kg': '2250'}
# {'Name': 'Polestar4 Long Range Single Motor', 'DE Price': '* €60,000', 'UK Price': '* £55,000', 'NL Price': '* €60,000', 'Acceleration 0 to 100': '7.4 sec', 'Top Speed': '180 km/h', 'Range': '495 km', 'Efficiency': '190 Wh/km', 'Fastcharge': '740 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'Audie-tron GT quattro', 'DE Price': '€106,050', 'UK Price': '£87,800', 'NL Price': '€111,115', 'Acceleration 0 to 100': '4.1 sec', 'Top Speed': '245 km/h', 'Range': '420 km', 'Efficiency': '202 Wh/km', 'Fastcharge': '1030 km/h', 'Towing capacity in kg': ''}
# {'Name': 'NissanLeaf e+', 'DE Price': '€41,100', 'UK Price': '£34,945', 'NL Price': '€41,890', 'Acceleration 0 to 100': '6.9 sec', 'Top Speed': '157 km/h', 'Range': '340 km', 'Efficiency': '174 Wh/km', 'Fastcharge': '240 km/h', 'Towing capacity in kg': ''}
# {'Name': 'BMWiX2 xDrive30', 'DE Price': '€56,500', 'UK Price': '£57,445', 'NL Price': '€59,350', 'Acceleration 0 to 100': '5.6 sec', 'Top Speed': '180 km/h', 'Range': '380 km', 'Efficiency': '170 Wh/km', 'Fastcharge': '550 km/h', 'Towing capacity in kg': '1200'}
# {'Name': 'ToyotabZ4X AWD', 'DE Price': '€57,390', 'UK Price': '£52,510', 'NL Price': '€59,995', 'Acceleration 0 to 100': '6.9 sec', 'Top Speed': '160 km/h', 'Range': '315 km', 'Efficiency': '203 Wh/km', 'Fastcharge': '470 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'MercedesEQA 250', 'DE Price': '€50,777', 'UK Price': 'N/A', 'NL Price': 'N/A', 'Acceleration 0 to 100': '8.6 sec', 'Top Speed': '160 km/h', 'Range': '405 km', 'Efficiency': '164 Wh/km', 'Fastcharge': '580 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'VolvoXC40 Recharge Single Motor', 'DE Price': '€47,500', 'UK Price': '£46,505', 'NL Price': '€45,995', 'Acceleration 0 to 100': '7.3 sec', 'Top Speed': '180 km/h', 'Range': '345 km', 'Efficiency': '191 Wh/km', 'Fastcharge': '420 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'Smart#3 Brabus', 'DE Price': '€50,990', 'UK Price': '* £45,000', 'NL Price': '* €51,000', 'Acceleration 0 to 100': '3.7 sec', 'Top Speed': '180 km/h', 'Range': '330 km', 'Efficiency': '188 Wh/km', 'Fastcharge': '510 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'MercedesEQE 350+', 'DE Price': 'N/A', 'UK Price': 'N/A', 'NL Price': '€82,028', 'Acceleration 0 to 100': '6.4 sec', 'Top Speed': '210 km/h', 'Range': '530 km', 'Efficiency': '171 Wh/km', 'Fastcharge': '790 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'MGMarvel R Performance', 'DE Price': '€50,990', 'UK Price': 'N/A', 'NL Price': '€52,485', 'Acceleration 0 to 100': '4.9 sec', 'Top Speed': '200 km/h', 'Range': '350 km', 'Efficiency': '200 Wh/km', 'Fastcharge': '380 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'KiaEV9 99.8 kWh RWD', 'DE Price': '€72,490', 'UK Price': '£64,995', 'NL Price': '€67,995', 'Acceleration 0 to 100': '9.4 sec', 'Top Speed': '185 km/h', 'Range': '450 km', 'Efficiency': '213 Wh/km', 'Fastcharge': '780 km/h', 'Towing capacity in kg': '900'}
# {'Name': 'DaciaSpring Electric 65 Extreme', 'DE Price': '€24,550', 'UK Price': 'N/A', 'NL Price': '€23,400', 'Acceleration 0 to 100': '13.7 sec', 'Top Speed': '125 km/h', 'Range': '160 km', 'Efficiency': '156 Wh/km', 'Fastcharge': '170 km/h', 'Towing capacity in kg': ''}
# {'Name': 'XPENGG9 RWD Standard Range', 'DE Price': 'N/A', 'UK Price': 'N/A', 'NL Price': '€59,188', 'Acceleration 0 to 100': '6.4 sec', 'Top Speed': '200 km/h', 'Range': '400 km', 'Efficiency': '190 Wh/km', 'Fastcharge': '840 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'Peugeote-308 SW', 'DE Price': '€45,765', 'UK Price': '* £38,000', 'NL Price': '€44,875', 'Acceleration 0 to 100': '9.0 sec', 'Top Speed': '150 km/h', 'Range': '300 km', 'Efficiency': '169 Wh/km', 'Fastcharge': '450 km/h', 'Towing capacity in kg': ''}
# {'Name': 'VolkswagenID.3 Pro S - 4 Seats', 'DE Price': '€47,595', 'UK Price': '£42,870', 'NL Price': '€47,990', 'Acceleration 0 to 100': '7.9 sec', 'Top Speed': '160 km/h', 'Range': '455 km', 'Efficiency': '169 Wh/km', 'Fastcharge': '680 km/h', 'Towing capacity in kg': '0'}
# {'Name': 'MercedesEQV 300 Long', 'DE Price': '€71,626', 'UK Price': '£87,995', 'NL Price': '€83,617', 'Acceleration 0 to 100': '12.1 sec', 'Top Speed': '160 km/h', 'Range': '310 km', 'Efficiency': '290 Wh/km', 'Fastcharge': '310 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Hondae Advance', 'DE Price': '€39,900', 'UK Price': '£37,395', 'NL Price': '€40,615', 'Acceleration 0 to 100': '8.3 sec', 'Top Speed': '145 km/h', 'Range': '170 km', 'Efficiency': '168 Wh/km', 'Fastcharge': '180 km/h', 'Towing capacity in kg': ''}
# {'Name': 'AudiQ4 e-tron 45', 'DE Price': '€52,950', 'UK Price': 'N/A', 'NL Price': '€54,865', 'Acceleration 0 to 100': '6.7 sec', 'Top Speed': '180 km/h', 'Range': '420 km', 'Efficiency': '183 Wh/km', 'Fastcharge': '630 km/h', 'Towing capacity in kg': '1200'}
# {'Name': 'MercedesEQS SUV 580 4MATIC', 'DE Price': '€135,434', 'UK Price': '£139,470', 'NL Price': 'N/A', 'Acceleration 0 to 100': '4.6 sec', 'Top Speed': '210 km/h', 'Range': '485 km', 'Efficiency': '224 Wh/km', 'Fastcharge': '720 km/h', 'Towing capacity in kg': '1800'}
# {'Name': 'AudiQ8 e-tron 50 quattro', 'DE Price': '€74,400', 'UK Price': '£67,800', 'NL Price': '€71,385', 'Acceleration 0 to 100': '6.0 sec', 'Top Speed': '200 km/h', 'Range': '425 km', 'Efficiency': '209 Wh/km', 'Fastcharge': '660 km/h', 'Towing capacity in kg': '1800'}
# {'Name': 'LucidAir Grand Touring', 'DE Price': '€159,000', 'UK Price': 'N/A', 'NL Price': '€165,000', 'Acceleration 0 to 100': '3.0 sec', 'Top Speed': '270 km/h', 'Range': '665 km', 'Efficiency': '168 Wh/km', 'Fastcharge': '840 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Polestar2 Standard Range Single Motor', 'DE Price': '€50,775', 'UK Price': '£44,950', 'NL Price': '€51,200', 'Acceleration 0 to 100': '6.4 sec', 'Top Speed': '205 km/h', 'Range': '405 km', 'Efficiency': '165 Wh/km', 'Fastcharge': '480 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'SkodaEnyaq 60', 'DE Price': '€44,200', 'UK Price': '£38,970', 'NL Price': '€44,990', 'Acceleration 0 to 100': '8.7 sec', 'Top Speed': '160 km/h', 'Range': '340 km', 'Efficiency': '171 Wh/km', 'Fastcharge': '460 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'XPENGG9 RWD Long Range', 'DE Price': 'N/A', 'UK Price': 'N/A', 'NL Price': '€63,188', 'Acceleration 0 to 100': '6.4 sec', 'Top Speed': '200 km/h', 'Range': '490 km', 'Efficiency': '190 Wh/km', 'Fastcharge': '1020 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'HongqiE-HS9 84 kWh', 'DE Price': 'N/A', 'UK Price': 'N/A', 'NL Price': '€69,995', 'Acceleration 0 to 100': '6.5 sec', 'Top Speed': '200 km/h', 'Range': '320 km', 'Efficiency': '239 Wh/km', 'Fastcharge': '440 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'RenaultMegane E-Tech EV40 130hp', 'DE Price': '€42,000', 'UK Price': 'N/A', 'NL Price': '€38,370', 'Acceleration 0 to 100': '10.0 sec', 'Top Speed': '150 km/h', 'Range': '260 km', 'Efficiency': '154 Wh/km', 'Fastcharge': '370 km/h', 'Towing capacity in kg': '500'}
# {'Name': 'XPENGP7 Wing Edition', 'DE Price': 'N/A', 'UK Price': 'N/A', 'NL Price': '€71,188', 'Acceleration 0 to 100': '4.1 sec', 'Top Speed': '200 km/h', 'Range': '465 km', 'Efficiency': '178 Wh/km', 'Fastcharge': '650 km/h', 'Towing capacity in kg': ''}
# {'Name': 'SsangYongKorando e-Motion', 'DE Price': '€40,490', 'UK Price': 'N/A', 'NL Price': '€39,990', 'Acceleration 0 to 100': '8.5 sec', 'Top Speed': '156 km/h', 'Range': '290 km', 'Efficiency': '193 Wh/km', 'Fastcharge': '330 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'FiskerOcean Sport', 'DE Price': '€41,560', 'UK Price': '£35,970', 'NL Price': '€43,990', 'Acceleration 0 to 100': '7.4 sec', 'Top Speed': '160 km/h', 'Range': '380 km', 'Efficiency': '197 Wh/km', 'Fastcharge': '480 km/h', 'Towing capacity in kg': '1090'}
# {'Name': 'AudiQ4 e-tron 50 quattro', 'DE Price': 'N/A', 'UK Price': '£57,010', 'NL Price': 'N/A', 'Acceleration 0 to 100': '6.2 sec', 'Top Speed': '180 km/h', 'Range': '385 km', 'Efficiency': '199 Wh/km', 'Fastcharge': '550 km/h', 'Towing capacity in kg': '1200'}
# {'Name': 'MGZS EV Standard Range', 'DE Price': '€33,990', 'UK Price': '£30,495', 'NL Price': '€35,885', 'Acceleration 0 to 100': '8.6 sec', 'Top Speed': '175 km/h', 'Range': '265 km', 'Efficiency': '185 Wh/km', 'Fastcharge': '250 km/h', 'Towing capacity in kg': '500'}
# {'Name': 'Polestar2 Long Range Dual Motor', 'DE Price': '€58,775', 'UK Price': '£52,950', 'NL Price': '€59,900', 'Acceleration 0 to 100': '4.5 sec', 'Top Speed': '205 km/h', 'Range': '450 km', 'Efficiency': '176 Wh/km', 'Fastcharge': '670 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'FordMustang Mach-E ER RWD', 'DE Price': '€58,500', 'UK Price': '* £53,000', 'NL Price': '€59,400', 'Acceleration 0 to 100': '7.0 sec', 'Top Speed': '180 km/h', 'Range': '480 km', 'Efficiency': '190 Wh/km', 'Fastcharge': '420 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'Peugeote-2008 54 kWh', 'DE Price': '€40,050', 'UK Price': '£36,350', 'NL Price': '€41,420', 'Acceleration 0 to 100': '9.1 sec', 'Top Speed': '150 km/h', 'Range': '300 km', 'Efficiency': '169 Wh/km', 'Fastcharge': '480 km/h', 'Towing capacity in kg': ''}
# {'Name': 'RenaultKangoo E-Tech Electric', 'DE Price': '€39,300', 'UK Price': 'N/A', 'NL Price': 'N/A', 'Acceleration 0 to 100': '12.6 sec', 'Top Speed': '132 km/h', 'Range': '220 km', 'Efficiency': '205 Wh/km', 'Fastcharge': '230 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'MercedesEQS SUV 450+', 'DE Price': '€110,801', 'UK Price': 'N/A', 'NL Price': 'N/A', 'Acceleration 0 to 100': '6.7 sec', 'Top Speed': '210 km/h', 'Range': '500 km', 'Efficiency': '217 Wh/km', 'Fastcharge': '750 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'OpelCorsa Electric 51 kWh', 'DE Price': '€38,045', 'UK Price': '£35,475', 'NL Price': '€37,999', 'Acceleration 0 to 100': '8.1 sec', 'Top Speed': '150 km/h', 'Range': '315 km', 'Efficiency': '153 Wh/km', 'Fastcharge': '490 km/h', 'Towing capacity in kg': ''}
# {'Name': 'CUPRATavascan VZ', 'DE Price': '* €58,000', 'UK Price': '* £55,000', 'NL Price': '* €60,000', 'Acceleration 0 to 100': '5.6 sec', 'Top Speed': '180 km/h', 'Range': '430 km', 'Efficiency': '179 Wh/km', 'Fastcharge': '640 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Polestar3 Long Range Dual motor', 'DE Price': '€88,600', 'UK Price': '£79,900', 'NL Price': '€89,900', 'Acceleration 0 to 100': '5.0 sec', 'Top Speed': '210 km/h', 'Range': '490 km', 'Efficiency': '218 Wh/km', 'Fastcharge': '640 km/h', 'Towing capacity in kg': '2200'}
# {'Name': 'RenaultMegane E-Tech EV60 130hp', 'DE Price': '€47,000', 'UK Price': 'N/A', 'NL Price': '€43,970', 'Acceleration 0 to 100': '10.5 sec', 'Top Speed': '150 km/h', 'Range': '380 km', 'Efficiency': '158 Wh/km', 'Fastcharge': '530 km/h', 'Towing capacity in kg': '500'}
# {'Name': 'SkodaEnyaq 85x', 'DE Price': '€51,150', 'UK Price': '£48,605', 'NL Price': 'N/A', 'Acceleration 0 to 100': '6.6 sec', 'Top Speed': '180 km/h', 'Range': '440 km', 'Efficiency': '175 Wh/km', 'Fastcharge': '660 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'KiaEV9 99.8 kWh AWD GT-Line', 'DE Price': '€82,380', 'UK Price': '£73,245', 'NL Price': '€78,895', 'Acceleration 0 to 100': '5.3 sec', 'Top Speed': '200 km/h', 'Range': '415 km', 'Efficiency': '231 Wh/km', 'Fastcharge': '720 km/h', 'Towing capacity in kg': '2500'}
# {'Name': 'JaguarI-Pace EV400', 'DE Price': '€92,400', 'UK Price': '£69,995', 'NL Price': '€95,450', 'Acceleration 0 to 100': '4.8 sec', 'Top Speed': '200 km/h', 'Range': '380 km', 'Efficiency': '223 Wh/km', 'Fastcharge': '360 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'NIOEL7 100 kWh', 'DE Price': '€94,900', 'UK Price': 'N/A', 'NL Price': '€97,900', 'Acceleration 0 to 100': '3.9 sec', 'Top Speed': '200 km/h', 'Range': '430 km', 'Efficiency': '209 Wh/km', 'Fastcharge': '450 km/h', 'Towing capacity in kg': '2000'}
# {'Name': 'NissanAriya 63kWh', 'DE Price': '€47,490', 'UK Price': '£39,645', 'NL Price': '€44,990', 'Acceleration 0 to 100': '7.5 sec', 'Top Speed': '160 km/h', 'Range': '335 km', 'Efficiency': '188 Wh/km', 'Fastcharge': '450 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'MiniCooper SE', 'DE Price': '€36,900', 'UK Price': '£34,500', 'NL Price': '€38,990', 'Acceleration 0 to 100': '6.7 sec', 'Top Speed': '170 km/h', 'Range': '310 km', 'Efficiency': '158 Wh/km', 'Fastcharge': '440 km/h', 'Towing capacity in kg': ''}
# {'Name': 'VolkswagenID.4 Pure', 'DE Price': '€40,335', 'UK Price': 'N/A', 'NL Price': '* €43,000', 'Acceleration 0 to 100': '9.0 sec', 'Top Speed': '160 km/h', 'Range': '285 km', 'Efficiency': '182 Wh/km', 'Fastcharge': '360 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'VolvoC40 Recharge Twin Motor', 'DE Price': '€61,400', 'UK Price': '£53,605', 'NL Price': '€61,495', 'Acceleration 0 to 100': '4.7 sec', 'Top Speed': '180 km/h', 'Range': '400 km', 'Efficiency': '198 Wh/km', 'Fastcharge': '600 km/h', 'Towing capacity in kg': '1800'}
# {'Name': 'MercedesEQE 300', 'DE Price': '€67,187', 'UK Price': '£68,810', 'NL Price': '€69,928', 'Acceleration 0 to 100': '7.3 sec', 'Top Speed': '210 km/h', 'Range': '525 km', 'Efficiency': '170 Wh/km', 'Fastcharge': '660 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'VinFastVF 9 Extended Range', 'DE Price': '€89,790', 'UK Price': 'N/A', 'NL Price': '€91,300', 'Acceleration 0 to 100': '6.5 sec', 'Top Speed': '200 km/h', 'Range': '520 km', 'Efficiency': '237 Wh/km', 'Fastcharge': '520 km/h', 'Towing capacity in kg': ''}
# {'Name': 'LucidAir Dream Edition P', 'DE Price': '€218,000', 'UK Price': 'N/A', 'NL Price': '€222,000', 'Acceleration 0 to 100': '2.7 sec', 'Top Speed': '270 km/h', 'Range': '665 km', 'Efficiency': '177 Wh/km', 'Fastcharge': '840 km/h', 'Towing capacity in kg': ''}
# {'Name': 'MercedesEQE SUV 500 4MATIC', 'DE Price': '€99,841', 'UK Price': 'N/A', 'NL Price': '€116,755', 'Acceleration 0 to 100': '4.9 sec', 'Top Speed': '210 km/h', 'Range': '455 km', 'Efficiency': '211 Wh/km', 'Fastcharge': '630 km/h', 'Towing capacity in kg': '1800'}
# {'Name': 'NIOET7 100 kWh', 'DE Price': '€90,900', 'UK Price': 'N/A', 'NL Price': '€93,900', 'Acceleration 0 to 100': '3.8 sec', 'Top Speed': '200 km/h', 'Range': '505 km', 'Efficiency': '178 Wh/km', 'Fastcharge': '530 km/h', 'Towing capacity in kg': '2000'}
# {'Name': 'FiskerOcean Extreme', 'DE Price': '€69,950', 'UK Price': '£60,880', 'NL Price': '€63,590', 'Acceleration 0 to 100': '3.9 sec', 'Top Speed': '205 km/h', 'Range': '530 km', 'Efficiency': '201 Wh/km', 'Fastcharge': '630 km/h', 'Towing capacity in kg': '1820'}
# {'Name': 'ORAFunky Cat 48 kWh', 'DE Price': '€38,990', 'UK Price': '£31,995', 'NL Price': 'N/A', 'Acceleration 0 to 100': '8.3 sec', 'Top Speed': '160 km/h', 'Range': '260 km', 'Efficiency': '175 Wh/km', 'Fastcharge': '240 km/h', 'Towing capacity in kg': ''}
# {'Name': 'VolvoC40 Recharge Single Motor ER', 'DE Price': '€54,450', 'UK Price': 'N/A', 'NL Price': '€52,995', 'Acceleration 0 to 100': '7.3 sec', 'Top Speed': '180 km/h', 'Range': '420 km', 'Efficiency': '188 Wh/km', 'Fastcharge': '630 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'Citroene-C4 X 54 kWh', 'DE Price': '€41,540', 'UK Price': 'N/A', 'NL Price': '€40,680', 'Acceleration 0 to 100': '10.0 sec', 'Top Speed': '150 km/h', 'Range': '330 km', 'Efficiency': '154 Wh/km', 'Fastcharge': '470 km/h', 'Towing capacity in kg': ''}
# {'Name': 'KiaEV6 Standard Range 2WD', 'DE Price': '€46,990', 'UK Price': 'N/A', 'NL Price': '€45,995', 'Acceleration 0 to 100': '8.5 sec', 'Top Speed': '185 km/h', 'Range': '305 km', 'Efficiency': '177 Wh/km', 'Fastcharge': '750 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'BYDDOLPHIN 44.9 kWh Boost', 'DE Price': '€32,740', 'UK Price': '* £28,500', 'NL Price': '€32,990', 'Acceleration 0 to 100': '8.0 sec', 'Top Speed': '160 km/h', 'Range': '255 km', 'Efficiency': '176 Wh/km', 'Fastcharge': '260 km/h', 'Towing capacity in kg': ''}
# {'Name': 'BMWi7 eDrive50', 'DE Price': '€115,700', 'UK Price': '£100,205', 'NL Price': '€122,463', 'Acceleration 0 to 100': '5.5 sec', 'Top Speed': '205 km/h', 'Range': '520 km', 'Efficiency': '196 Wh/km', 'Fastcharge': '780 km/h', 'Towing capacity in kg': ''}
# {'Name': 'VoyahFree 106 kWh', 'DE Price': 'N/A', 'UK Price': 'N/A', 'NL Price': '€74,150', 'Acceleration 0 to 100': '4.4 sec', 'Top Speed': '200 km/h', 'Range': '480 km', 'Efficiency': '208 Wh/km', 'Fastcharge': '360 km/h', 'Towing capacity in kg': '2000'}
# {'Name': 'MaseratiGranTurismo Folgore', 'DE Price': '* €250,000', 'UK Price': '* £200,000', 'NL Price': '* €250,000', 'Acceleration 0 to 100': '2.7 sec', 'Top Speed': '320 km/h', 'Range': '425 km', 'Efficiency': '195 Wh/km', 'Fastcharge': '990 km/h', 'Towing capacity in kg': ''}
# ...
# {'Name': 'Abarth500e Convertible', 'DE Price': '€40,990', 'UK Price': '£37,195', 'NL Price': '€41,490', 'Acceleration 0 to 100': '7.0 sec', 'Top Speed': '155 km/h', 'Range': '225 km', 'Efficiency': '168 Wh/km', 'Fastcharge': '370 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Citroene-SpaceTourer M 50 kWh', 'DE Price': '€53,640', 'UK Price': '£37,045', 'NL Price': '€57,083', 'Acceleration 0 to 100': '12.1 sec', 'Top Speed': '130 km/h', 'Range': '185 km', 'Efficiency': '250 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'PorscheTaycan 4S Cross Turismo', 'DE Price': '€119,914', 'UK Price': '£95,200', 'NL Price': '€126,064', 'Acceleration 0 to 100': '4.1 sec', 'Top Speed': '240 km/h', 'Range': '440 km', 'Efficiency': '190 Wh/km', 'Fastcharge': '1080 km/h', 'Towing capacity in kg': ''}
# {'Name': 'PorscheTaycan Sport Turismo', 'DE Price': '€94,091', 'UK Price': '£80,200', 'NL Price': '€99,563', 'Acceleration 0 to 100': '5.4 sec', 'Top Speed': '230 km/h', 'Range': '380 km', 'Efficiency': '187 Wh/km', 'Fastcharge': '930 km/h', 'Towing capacity in kg': ''}
# {'Name': 'MercedesEQE AMG 53 4MATIC+', 'DE Price': '€110,706', 'UK Price': '£114,750', 'NL Price': '€128,613', 'Acceleration 0 to 100': '3.5 sec', 'Top Speed': '220 km/h', 'Range': '465 km', 'Efficiency': '195 Wh/km', 'Fastcharge': '690 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'MercedeseVito Tourer Extra-Long 90 kWh', 'DE Price': '€65,140', 'UK Price': '£83,850', 'NL Price': 'N/A', 'Acceleration 0 to 100': '12.0 sec', 'Top Speed': '160 km/h', 'Range': '305 km', 'Efficiency': '295 Wh/km', 'Fastcharge': '310 km/h', 'Towing capacity in kg': ''}
# {'Name': 'PorscheTaycan Turbo', 'DE Price': '€164,420', 'UK Price': '£125,800', 'NL Price': '€171,763', 'Acceleration 0 to 100': '3.2 sec', 'Top Speed': '260 km/h', 'Range': '445 km', 'Efficiency': '188 Wh/km', 'Fastcharge': '1090 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Peugeote-Rifter Standard 50 kWh', 'DE Price': '€41,240', 'UK Price': '£33,120', 'NL Price': '€39,620', 'Acceleration 0 to 100': '11.7 sec', 'Top Speed': '135 km/h', 'Range': '205 km', 'Efficiency': '226 Wh/km', 'Fastcharge': '330 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'GenesisGV60 Sport', 'DE Price': '€63,200', 'UK Price': '£58,365', 'NL Price': 'N/A', 'Acceleration 0 to 100': '5.5 sec', 'Top Speed': '200 km/h', 'Range': '380 km', 'Efficiency': '195 Wh/km', 'Fastcharge': '990 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'OpelZafira-e Life L 75 kWh', 'DE Price': '€70,075', 'UK Price': 'N/A', 'NL Price': '€68,134', 'Acceleration 0 to 100': '13.3 sec', 'Top Speed': '130 km/h', 'Range': '260 km', 'Efficiency': '262 Wh/km', 'Fastcharge': '280 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'GenesisGV60 Sport Plus', 'DE Price': '€73,100', 'UK Price': '£67,505', 'NL Price': 'N/A', 'Acceleration 0 to 100': '4.0 sec', 'Top Speed': '235 km/h', 'Range': '365 km', 'Efficiency': '203 Wh/km', 'Fastcharge': '950 km/h', 'Towing capacity in kg': '1600'}
# {'Name': 'MercedesEQV 300 Extra-Long', 'DE Price': '€72,519', 'UK Price': 'N/A', 'NL Price': '€84,809', 'Acceleration 0 to 100': '12.1 sec', 'Top Speed': '160 km/h', 'Range': '310 km', 'Efficiency': '290 Wh/km', 'Fastcharge': '310 km/h', 'Towing capacity in kg': ''}
# {'Name': 'MercedesEQA 300 4MATIC', 'DE Price': '€53,520', 'UK Price': '* £53,000', 'NL Price': '€58,959', 'Acceleration 0 to 100': '7.7 sec', 'Top Speed': '160 km/h', 'Range': '355 km', 'Efficiency': '187 Wh/km', 'Fastcharge': '510 km/h', 'Towing capacity in kg': '1800'}
# {'Name': 'MercedesEQE AMG 43 4MATIC', 'DE Price': '€104,756', 'UK Price': 'N/A', 'NL Price': '€111,068', 'Acceleration 0 to 100': '4.2 sec', 'Top Speed': '210 km/h', 'Range': '465 km', 'Efficiency': '195 Wh/km', 'Fastcharge': '690 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'Peugeote-Expert Combi Long 75 kWh', 'DE Price': '€58,730', 'UK Price': 'N/A', 'NL Price': '€59,303', 'Acceleration 0 to 100': '14.3 sec', 'Top Speed': '130 km/h', 'Range': '260 km', 'Efficiency': '262 Wh/km', 'Fastcharge': '280 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'FiatE-Ulysse L3 75 kWh', 'DE Price': '€62,990', 'UK Price': 'N/A', 'NL Price': 'N/A', 'Acceleration 0 to 100': '13.3 sec', 'Top Speed': '130 km/h', 'Range': '260 km', 'Efficiency': '262 Wh/km', 'Fastcharge': '280 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'HongqiE-HS9 120 kWh', 'DE Price': 'N/A', 'UK Price': 'N/A', 'NL Price': '€102,995', 'Acceleration 0 to 100': '4.9 sec', 'Top Speed': '200 km/h', 'Range': '460 km', 'Efficiency': '243 Wh/km', 'Fastcharge': '420 km/h', 'Towing capacity in kg': '1500'}
# {'Name': 'Fiat500e Cabrio 24 kWh', 'DE Price': '€35,490', 'UK Price': 'N/A', 'NL Price': '€31,990', 'Acceleration 0 to 100': '9.0 sec', 'Top Speed': '135 km/h', 'Range': '135 km', 'Efficiency': '158 Wh/km', 'Fastcharge': '230 km/h', 'Towing capacity in kg': ''}
# {'Name': 'PorscheTaycan Plus Sport Turismo', 'DE Price': '€99,815', 'UK Price': '£84,654', 'NL Price': '€105,607', 'Acceleration 0 to 100': '5.4 sec', 'Top Speed': '230 km/h', 'Range': '445 km', 'Efficiency': '188 Wh/km', 'Fastcharge': '1090 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Peugeote-Traveller Long 75 kWh', 'DE Price': '€60,430', 'UK Price': 'N/A', 'NL Price': '€68,378', 'Acceleration 0 to 100': '14.3 sec', 'Top Speed': '130 km/h', 'Range': '260 km', 'Efficiency': '262 Wh/km', 'Fastcharge': '280 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'Citroene-Jumpy Combi M 50 kWh', 'DE Price': '€51,940', 'UK Price': 'N/A', 'NL Price': '€48,008', 'Acceleration 0 to 100': '12.1 sec', 'Top Speed': '130 km/h', 'Range': '185 km', 'Efficiency': '250 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'PorscheTaycan Turbo Cross Turismo', 'DE Price': '€165,848', 'UK Price': '£126,800', 'NL Price': '€173,264', 'Acceleration 0 to 100': '3.3 sec', 'Top Speed': '250 km/h', 'Range': '425 km', 'Efficiency': '197 Wh/km', 'Fastcharge': '1050 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Peugeote-Traveller Standard 50 kWh', 'DE Price': '€53,640', 'UK Price': '£42,785', 'NL Price': '€57,428', 'Acceleration 0 to 100': '13.1 sec', 'Top Speed': '130 km/h', 'Range': '185 km', 'Efficiency': '250 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'NIOEL7 75 kWh', 'DE Price': '€85,900', 'UK Price': 'N/A', 'NL Price': '€88,900', 'Acceleration 0 to 100': '3.9 sec', 'Top Speed': '200 km/h', 'Range': '340 km', 'Efficiency': '207 Wh/km', 'Fastcharge': '460 km/h', 'Towing capacity in kg': '2000'}
# {'Name': 'PorscheTaycan Turbo S Sport Turismo', 'DE Price': '€198,692', 'UK Price': '£149,300', 'NL Price': '€207,163', 'Acceleration 0 to 100': '2.8 sec', 'Top Speed': '260 km/h', 'Range': '395 km', 'Efficiency': '212 Wh/km', 'Fastcharge': '970 km/h', 'Towing capacity in kg': ''}
# {'Name': 'VinFastVF 8 Plus Extended Range', 'DE Price': '€58,890', 'UK Price': 'N/A', 'NL Price': '€59,790', 'Acceleration 0 to 100': '5.5 sec', 'Top Speed': '200 km/h', 'Range': '425 km', 'Efficiency': '206 Wh/km', 'Fastcharge': '550 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Peugeote-Traveller Standard 75 kWh', 'DE Price': '€59,640', 'UK Price': 'N/A', 'NL Price': '€66,442', 'Acceleration 0 to 100': '14.3 sec', 'Top Speed': '130 km/h', 'Range': '265 km', 'Efficiency': '257 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'PorscheTaycan Turbo S Cross Turismo', 'DE Price': '€199,168', 'UK Price': '£149,300', 'NL Price': '€207,664', 'Acceleration 0 to 100': '2.9 sec', 'Top Speed': '250 km/h', 'Range': '410 km', 'Efficiency': '204 Wh/km', 'Fastcharge': '1010 km/h', 'Towing capacity in kg': ''}
# {'Name': 'OpelZafira-e Life M 50 kWh', 'DE Price': '€63,250', 'UK Price': '£42,735', 'NL Price': '€57,183', 'Acceleration 0 to 100': '12.1 sec', 'Top Speed': '130 km/h', 'Range': '185 km', 'Efficiency': '250 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'MercedesEQV 250 Long', 'DE Price': '€68,056', 'UK Price': 'N/A', 'NL Price': 'N/A', 'Acceleration 0 to 100': '12.0 sec', 'Top Speed': '160 km/h', 'Range': '210 km', 'Efficiency': '286 Wh/km', 'Fastcharge': '200 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Citroene-SpaceTourer M 75 kWh', 'DE Price': '€59,640', 'UK Price': 'N/A', 'NL Price': '€66,097', 'Acceleration 0 to 100': '13.3 sec', 'Top Speed': '130 km/h', 'Range': '265 km', 'Efficiency': '257 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'Citroene-Berlingo XL 50 kWh', 'DE Price': '€43,640', 'UK Price': '£33,315', 'NL Price': '€43,556', 'Acceleration 0 to 100': '11.7 sec', 'Top Speed': '135 km/h', 'Range': '205 km', 'Efficiency': '226 Wh/km', 'Fastcharge': '330 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'Citroene-Jumpy Combi XL 75 kWh', 'DE Price': '€58,730', 'UK Price': 'N/A', 'NL Price': '€58,958', 'Acceleration 0 to 100': '13.3 sec', 'Top Speed': '130 km/h', 'Range': '260 km', 'Efficiency': '262 Wh/km', 'Fastcharge': '280 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'OpelCombo-e Life XL 50 kWh', 'DE Price': '€44,750', 'UK Price': '£34,685', 'NL Price': 'N/A', 'Acceleration 0 to 100': '11.7 sec', 'Top Speed': '135 km/h', 'Range': '200 km', 'Efficiency': '232 Wh/km', 'Fastcharge': '320 km/h', 'Towing capacity in kg': '750'}
# {'Name': 'MercedeseVito Tourer Long 60 kWh', 'DE Price': '€60,678', 'UK Price': 'N/A', 'NL Price': 'N/A', 'Acceleration 0 to 100': '12.0 sec', 'Top Speed': '160 km/h', 'Range': '210 km', 'Efficiency': '286 Wh/km', 'Fastcharge': '310 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Citroene-SpaceTourer XL 75 kWh', 'DE Price': '€60,430', 'UK Price': 'N/A', 'NL Price': '€68,033', 'Acceleration 0 to 100': '13.3 sec', 'Top Speed': '130 km/h', 'Range': '260 km', 'Efficiency': '262 Wh/km', 'Fastcharge': '280 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'Peugeote-Expert Combi Long 50 kWh', 'DE Price': '€52,730', 'UK Price': 'N/A', 'NL Price': '€50,289', 'Acceleration 0 to 100': '13.1 sec', 'Top Speed': '130 km/h', 'Range': '185 km', 'Efficiency': '250 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'ToyotaPROACE Shuttle L 50 kWh', 'DE Price': 'N/A', 'UK Price': 'N/A', 'NL Price': '€68,595', 'Acceleration 0 to 100': '12.1 sec', 'Top Speed': '130 km/h', 'Range': '180 km', 'Efficiency': '257 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'ToyotaPROACE Shuttle M 75 kWh', 'DE Price': 'N/A', 'UK Price': 'N/A', 'NL Price': '€60,095', 'Acceleration 0 to 100': '13.1 sec', 'Top Speed': '130 km/h', 'Range': '265 km', 'Efficiency': '257 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'PorscheTaycan 4S Plus Sport Turismo', 'DE Price': '€120,081', 'UK Price': '£95,996', 'NL Price': '€127,294', 'Acceleration 0 to 100': '4.0 sec', 'Top Speed': '250 km/h', 'Range': '430 km', 'Efficiency': '195 Wh/km', 'Fastcharge': '1060 km/h', 'Towing capacity in kg': ''}
# {'Name': 'MercedeseVito Tourer Extra-Long 60 kWh', 'DE Price': '€61,571', 'UK Price': 'N/A', 'NL Price': 'N/A', 'Acceleration 0 to 100': '12.0 sec', 'Top Speed': '160 km/h', 'Range': '205 km', 'Efficiency': '293 Wh/km', 'Fastcharge': '300 km/h', 'Towing capacity in kg': ''}
# {'Name': 'ToyotaPROACE Shuttle M 50 kWh', 'DE Price': 'N/A', 'UK Price': 'N/A', 'NL Price': '€58,895', 'Acceleration 0 to 100': '12.1 sec', 'Top Speed': '130 km/h', 'Range': '185 km', 'Efficiency': '250 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'OpelVivaro-e Combi M 50 kWh', 'DE Price': '€50,992', 'UK Price': '£36,995', 'NL Price': '€48,108', 'Acceleration 0 to 100': '12.1 sec', 'Top Speed': '130 km/h', 'Range': '185 km', 'Efficiency': '250 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'FiatE-Ulysse L2 75 kWh', 'DE Price': '€61,990', 'UK Price': 'N/A', 'NL Price': 'N/A', 'Acceleration 0 to 100': '13.3 sec', 'Top Speed': '130 km/h', 'Range': '265 km', 'Efficiency': '257 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'Citroene-SpaceTourer XL 50 kWh', 'DE Price': '€54,430', 'UK Price': '£37,885', 'NL Price': '€59,019', 'Acceleration 0 to 100': '12.1 sec', 'Top Speed': '130 km/h', 'Range': '180 km', 'Efficiency': '257 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'OpelVivaro-e Combi L 75 kWh', 'DE Price': '€57,775', 'UK Price': 'N/A', 'NL Price': '€59,059', 'Acceleration 0 to 100': '13.3 sec', 'Top Speed': '130 km/h', 'Range': '260 km', 'Efficiency': '262 Wh/km', 'Fastcharge': '280 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'Peugeote-Expert Combi Standard 50 kWh', 'DE Price': '€51,940', 'UK Price': 'N/A', 'NL Price': '€48,353', 'Acceleration 0 to 100': '13.1 sec', 'Top Speed': '130 km/h', 'Range': '185 km', 'Efficiency': '250 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'PorscheTaycan 4S Sport Turismo', 'DE Price': '€114,559', 'UK Price': '£91,700', 'NL Price': '€121,463', 'Acceleration 0 to 100': '4.0 sec', 'Top Speed': '250 km/h', 'Range': '370 km', 'Efficiency': '192 Wh/km', 'Fastcharge': '910 km/h', 'Towing capacity in kg': ''}
# {'Name': 'MercedesEQV 250 Extra-Long', 'DE Price': '€68,949', 'UK Price': 'N/A', 'NL Price': 'N/A', 'Acceleration 0 to 100': '12.0 sec', 'Top Speed': '160 km/h', 'Range': '210 km', 'Efficiency': '286 Wh/km', 'Fastcharge': '200 km/h', 'Towing capacity in kg': ''}
# {'Name': 'OpelVivaro-e Combi L 50 kWh', 'DE Price': '€51,825', 'UK Price': '£37,835', 'NL Price': '€50,044', 'Acceleration 0 to 100': '12.1 sec', 'Top Speed': '130 km/h', 'Range': '180 km', 'Efficiency': '257 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'OpelZafira-e Life L 50 kWh', 'DE Price': '€64,075', 'UK Price': '£43,575', 'NL Price': '€59,119', 'Acceleration 0 to 100': '12.1 sec', 'Top Speed': '130 km/h', 'Range': '180 km', 'Efficiency': '257 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'PorscheTaycan Turbo Sport Turismo', 'DE Price': '€165,372', 'UK Price': '£126,800', 'NL Price': '€172,863', 'Acceleration 0 to 100': '3.2 sec', 'Top Speed': '260 km/h', 'Range': '405 km', 'Efficiency': '207 Wh/km', 'Fastcharge': '1000 km/h', 'Towing capacity in kg': ''}
# {'Name': 'Peugeote-Traveller Long 50 kWh', 'DE Price': '€54,430', 'UK Price': '£43,625', 'NL Price': '€59,364', 'Acceleration 0 to 100': '13.1 sec', 'Top Speed': '130 km/h', 'Range': '185 km', 'Efficiency': '250 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'ToyotaPROACE Shuttle L 75 kWh', 'DE Price': 'N/A', 'UK Price': 'N/A', 'NL Price': '€69,795', 'Acceleration 0 to 100': '13.1 sec', 'Top Speed': '130 km/h', 'Range': '260 km', 'Efficiency': '262 Wh/km', 'Fastcharge': '280 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'OpelZafira-e Life M 75 kWh', 'DE Price': '€69,250', 'UK Price': 'N/A', 'NL Price': '€66,198', 'Acceleration 0 to 100': '13.3 sec', 'Top Speed': '130 km/h', 'Range': '265 km', 'Efficiency': '257 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'FiatE-Ulysse L3 50 kWh', 'DE Price': '€56,990', 'UK Price': 'N/A', 'NL Price': 'N/A', 'Acceleration 0 to 100': '12.1 sec', 'Top Speed': '130 km/h', 'Range': '180 km', 'Efficiency': '257 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'FiatE-Ulysse L2 50 kWh', 'DE Price': '€55,990', 'UK Price': 'N/A', 'NL Price': 'N/A', 'Acceleration 0 to 100': '12.1 sec', 'Top Speed': '130 km/h', 'Range': '185 km', 'Efficiency': '250 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}
# {'Name': 'Citroene-Jumpy Combi XL 50 kWh', 'DE Price': '€52,730', 'UK Price': 'N/A', 'NL Price': '€49,944', 'Acceleration 0 to 100': '12.1 sec', 'Top Speed': '130 km/h', 'Range': '180 km', 'Efficiency': '257 Wh/km', 'Fastcharge': '290 km/h', 'Towing capacity in kg': '1000'}

# %%
data_wrappers = pd.DataFrame(cars_list)

data_wrappers
# Out:
#                                    Name DE Price UK Price NL Price  \
# 0    TeslaModel Y Long Range Dual Motor  €59,017  £52,990  €54,993
# 1                             BYDATTO 3  €44,625  £37,195  €42,998
# 2                          TeslaModel 3  €46,220  £39,990  €43,993
# 3    TeslaModel 3 Long Range Dual Motor  €55,220  £49,990  €51,993
# 4                          TeslaModel Y  €47,567  £44,990  €45,993
# ..                                  ...      ...      ...      ...
# 357       ToyotaPROACE Shuttle L 75 kWh      N/A      N/A  €69,795
# 358          OpelZafira-e Life M 75 kWh  €69,250      N/A  €66,198
# 359              FiatE-Ulysse L3 50 kWh  €56,990      N/A      N/A
# 360              FiatE-Ulysse L2 50 kWh  €55,990      N/A      N/A
# 361      Citroene-Jumpy Combi XL 50 kWh  €52,730      N/A  €49,944
#
#     Acceleration 0 to 100 Top Speed   Range Efficiency Fastcharge  \
# 0                 5.0 sec  217 km/h  435 km  172 Wh/km   670 km/h
# 1                 7.3 sec  160 km/h  330 km  183 Wh/km   370 km/h
# 2                 6.1 sec  201 km/h  420 km  137 Wh/km   700 km/h
# 3                 4.4 sec  201 km/h  505 km  149 Wh/km   780 km/h
# 4                 6.9 sec  217 km/h  350 km  164 Wh/km   580 km/h
# ..                    ...       ...     ...        ...        ...
# 357              13.1 sec  130 km/h  260 km  262 Wh/km   280 km/h
# 358              13.3 sec  130 km/h  265 km  257 Wh/km   290 km/h
# 359              12.1 sec  130 km/h  180 km  257 Wh/km   290 km/h
# 360              12.1 sec  130 km/h  185 km  250 Wh/km   290 km/h
# 361              12.1 sec  130 km/h  180 km  257 Wh/km   290 km/h
#
#     Towing capacity in kg
# 0                    1600
# 1
# 2                    1000
# 3                    1000
# 4                    1600
# ..                    ...
# 357                  1000
# 358                  1000
# 359                  1000
# 360                  1000
# 361                  1000
#
# [362 rows x 10 columns]

# %%
csv_file_path = r'C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\ev_prices22_scraping.csv'
data_wrappers.to_csv(csv_file_path, index=False)
