# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen
import re
from datetime import datetime
import calendar
import csv
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time
import csv

# %% [markdown]
# # Getting EV prices information from website

# %%
url = "https://insideevs.com/news/565883/electric-car-prices-us/"

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

# %%
tbody = soup.find('tbody')

# %%
rows = tbody.find_all('tr')

# %%
all_rows = []

for row in tbody.find_all('tr'):
    cols = row.find_all('td')
    cols_text = [ele.text.strip() for ele in cols]
    all_rows.append(cols_text)

# %%
headers = all_rows[0]
data_rows = all_rows[1:]

# %%
ev_prices_scraping = pd.DataFrame(data_rows, columns=headers)
ev_prices_scraping
# Out:
#                                                  Model Base Price  \
# 0                  2023 Audi e-tron GT quattro 20-inch   $104,900
# 1               2023 Audi RS e-tron GT quattro 20-inch   $143,900
# 2                          2024 Audi Q8 e-tron 20-inch    $74,400
# 3    2024 Audi Q8 e-tron Sportback (Ultra pack) 19-...    $77,800
# 4                2024 Audi Q8 e-tron Sportback 20-inch    $77,800
# ..                                                 ...        ...
# 212                   2023 Volvo XC40 Recharge 19-inch    $53,550
# 213                2024 Volvo C40 Recharge RWD 19-inch
# 214                2024 Volvo C40 Recharge AWD 19-inch
# 215               2024 Volvo XC40 Recharge RWD 19-inch
# 216               2024 Volvo XC40 Recharge AWD 19-inch
#
#     Dest. Charge Tax Credit Effective Price
# 0        +$1,495        N/A        $106,395
# 1        +$1,495        N/A        $145,395
# 2        +$1,195        N/A         $75,595
# 3        +$1,195        N/A         $78,995
# 4        +$1,195        N/A         $78,995
# ..           ...        ...             ...
# 212      +$1,095        N/A         $54,645
# 213                     N/A
# 214                     N/A
# 215                     N/A
# 216                     N/A
#
# [217 rows x 5 columns]

# %%
csv_file_path = r'C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\scraping\insideevs_ev_prices_scraping.csv'
ev_prices_scraping.to_csv(csv_file_path, index=False)

# %% [markdown]
# # Getting EV countries Sales, market, and usage share 2022
# ###### Light-duty plug-in electric vehicle stock, market penetration, annual sales, and market share in the top selling countries and regional markets for latest available year

# %%
url2 = "https://en.wikipedia.org/wiki/Electric_car_use_by_country"
ev_sales22 = pd.read_html(url2)[2]
ev_sales22
# Out:
#                                     Country or region  \
# 0                                          China[iii]
# 1                                          Europe[iv]
# 2                                  United States[iii]
# 3                                        Germany[iii]
# 4                                     California[iii]
# 5                                              France
# 6                                      United Kingdom
# 7                                           Norway[v]
# 8                                     Netherlands[vi]
# 9                                              Sweden
# 10                                    Japan[iii][vii]
# 11                                        Canada[iii]
# 12                                  Global total[iii]
# 13  Notes ^ Includes sales or registrations of hig...
#
#                PEV stock/ cumulative sales  (2022)[i]  \
# 0                                      14,100,000[71]
# 1                                       7,800,000[71]
# 2                                       2,960,000[71]
# 3                                       1,877,721[74]
# 4                                       1,385,383[76]
# 5                                         990,000[71]
# 6                                         950,000[71]
# 7                                         817,471[82]
# 8                                         515,838[84]
# 9                                         440,000[71]
# 10                                        410,000[71]
# 11                                        380,000[71]
# 12                                     25,900,000[71]
# 13  Notes ^ Includes sales or registrations of hig...
#
#                                  Annual sales  (2022)  \
# 0                                       5,924,421[72]
# 1                                       2,602,431[73]
# 2                                         990,000[71]
# 3                                         832,652[75]
# 4                                         343,244[76]
# 5                                         346,849[78]
# 6                                         368,617[80]
# 7                                         153,144[83]
# 8                                         106,854[84]
# 9                                         161,649[85]
# 10                                        102,000[71]
# 11                                        114,000[71]
# 12                                     10,200,000[71]
# 13  Notes ^ Includes sales or registrations of hig...
#
#                                  Market share  (2022)  \
# 0                                           30.0%[72]
# 1                                           23.0%[73]
# 2                                            7.7%[71]
# 3                                           31.4%[75]
# 4                                           18.7%[76]
# 5                                           21.6%[79]
# 6                                           22.9%[81]
# 7                                           87.8%[83]
# 8                                           34.9%[84]
# 9                                           56.1%[86]
# 10                                           3.0%[71]
# 11                                           9.4%[71]
# 12                                          14.0%[71]
# 13  Notes ^ Includes sales or registrations of hig...
#
#                           % of cars in use (2022)[ii]
# 0                                            4.9%[71]
# 1                                            2.4%[71]
# 2                                            1.3%[71]
# 3                                           3.85%[74]
# 4                                    3.85% (2021)[77]
# 5                                            2.7%[71]
# 6                                            2.8%[71]
# 7                                          27.73%[82]
# 8                                            5.8%[84]
# 9                                            8.8%[71]
# 10                                           0.6%[71]
# 11                                           1.6%[71]
# 12                                           2.1%[71]
# 13  Notes ^ Includes sales or registrations of hig...

# %%
csv_file_path = r'C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\scraping\wikipedia_ev_sales22_scraping.csv'
ev_sales22.to_csv(csv_file_path, index=False)

# %% [markdown]
# # Ev sales per country 2027-2021
# ###### Light-duty plug-in electric vehicle yearly new sales and end-of-year cumulative sales (or stock) in the top PEV selling countries and regional markets

# %%
url3 = "https://en.wikipedia.org/wiki/Electric_car_use_by_country"
ev_sales = pd.read_html(url3)[3]
ev_sales
# Out:
#                                               Country  \
#                                               Country
# 0                                        China[i][ii]
# 1                                    United States[i]
# 2                                          Germany[i]
# 3                                              France
# 4                                      United Kingdom
# 5                                     Norway[iii][ii]
# 6                                     Netherlands[ii]
# 7                                          Sweden[ii]
# 8                                    Japan[i][iv][ii]
# 9                                              Canada
# 10                                    Global total[i]
# 11  Light-duty plug-in cumulative registrations in...
# 12                                  Europe (EU+3)[vi]
# 13                                      California[i]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                    China[vii] (all class segments)
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2021  \
#                                                 stock
# 0                                  7,842,668 [87][88]
# 1                                      2,322,291 [16]
# 2                                 ≈1,380,000 [18][19]
# 3                                       786,274 [103]
# 4                                      ≈745,000 [109]
# 5                                       647,000 [115]
# 6                                       390,454 [124]
# 7                               355,737 [1][129][130]
# 8                                       337,377 [133]
# 9                                       297,960 [136]
# 10                              17.5 million [5][138]
# 11  Light-duty plug-in cumulative registrations in...
# 12       5.67 million [13][14][15][32][139][140][141]
# 13                      1,072,136 [144][145][20][146]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                9,076,447 [87][89][32][90][93][151]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                        \
#                                                 sales
# 0                                      3,334,000 [87]
# 1                                        607,567 [16]
# 2                                        681,410 [19]
# 3                                       315,978 [103]
# 4                                       305,281 [110]
# 5                                       167,949 [116]
# 6                                        95,464 [125]
# 7                                       138,033 [130]
# 8                                        44,296 [133]
# 9                                        87,700 [136]
# 10                                    6,754,000 [138]
# 11  Light-duty plug-in cumulative registrations in...
# 12                                 2,332,798 [13][15]
# 13                                      237,618 [144]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                                     3,521,000 [87]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2020  \
#                                                 stock
# 0                                      4,508,668 [88]
# 1                                      1,741,566 [94]
# 2                                       ≈700,000 [18]
# 3                                       470,295 [104]
# 4                                    434,282 [1][111]
# 5                                       480,008 [117]
# 6                                       297,380 [126]
# 7                                    193,054 [1][129]
# 8                                         297,181 [2]
# 9                                       209,075 [136]
# 10                                10.8 million [5][v]
# 11  Light-duty plug-in cumulative registrations in...
# 12                  3,336,141 [14][32][139][140][141]
# 13                             834,518 [145][20][146]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                    5,555,447 [89][32][90][93][151]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                        \
#                                                 sales
# 0                                      1,246,000 [89]
# 1                                        297,939 [94]
# 2                                        394,632 [99]
# 3                                       194,881 [104]
# 4                                       175,082 [111]
# 5                                       113,588 [118]
# 6                                        89,362 [127]
# 7                                        96,054 [129]
# 8                                          29,000 [2]
# 9                                        51,376 [136]
# 10                                  3,240,000 [25][v]
# 11  Light-duty plug-in cumulative registrations in...
# 12                                     1,403,812 [14]
# 13                                      132,742 [145]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                                     1,367,000 [89]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2019  \
#                                                 stock
# 0                                       3,349,100 [1]
# 1                                       1,450,020 [1]
# 2                         305,589 [32][100][101][102]
# 3                                       275,575 [104]
# 4                                         259,200 [1]
# 5                                       384,066 [119]
# 6                                       207,922 [126]
# 7                                          97,000 [1]
# 8                                         267,415 [2]
# 9                                         141,100 [1]
# 10                                      7,167,830 [1]
# 11  Light-duty plug-in cumulative registrations in...
# 12                      1,935,010 [32][139][140][141]
# 13                             701,776 [145][20][146]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                        4,188,447 [32][90][93][151]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                        \
#                                                 sales
# 0                                      1,204,000 [90]
# 1                                        329,528 [95]
# 2                                       108,839 [102]
# 3                                        69,466 [105]
# 4                                        72,584 [112]
# 5                                        88,443 [120]
# 6                                          67,520 [1]
# 7                                        41,784 [131]
# 8                                        43,867 [134]
# 9                                          50,960 [1]
# 10                                      2,101,680 [1]
# 11  Light-duty plug-in cumulative registrations in...
# 12                                  588,575 [14][141]
# 13                                      159,081 [145]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                                     1,204,000 [90]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2018  \
#                                                 stock
# 0                                  2,243,772 [91][92]
# 1                                      1,126,000 [96]
# 2                              196,750 [32][100][101]
# 3                         204,617 [52][106][107][108]
# 4                                       197,000 [113]
# 5                                       296,215 [121]
# 6                                       145,882 [126]
# 7                                    79,579 [91][132]
# 8                                         239,242 [2]
# 9                                          90,100 [1]
# 10                                  5,127,297 [8][91]
# 11  Light-duty plug-in cumulative registrations in...
# 12                      1,346,435 [32][142][140][143]
# 13                                  542,695 [20][145]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                            2,984,447 [32][93][151]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                        \
#                                                 sales
# 0                                   1,016,002 [92][i]
# 1                                        361,307 [96]
# 2                                        67,504 [101]
# 3                                        53,745 [108]
# 4                                     59,911 [i][114]
# 5                                        86,290 [122]
# 6                                        29,187 [128]
# 7                                        29,909 [132]
# 8                                        52,013 [135]
# 9                                          44,150 [1]
# 10                                      2,018,247 [8]
# 11  Light-duty plug-in cumulative registrations in...
# 12                                 406,052 [142][143]
# 13                                      163,765 [145]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                                    1,256,000 [151]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#                                                  2017  \
#                                                 stock
# 0                                      1,227,770 [91]
# 1                                    764,666 [97][98]
# 2                                   129,246 [32][100]
# 3                              149,797 [52][106][107]
# 4                                        137,000[113]
# 5                                       209,122 [121]
# 6                                       121,540 [126]
# 7                                         49,670 [91]
# 8                                        205,212 [91]
# 9                                         45,950 [91]
# 10                                     3,109,050 [91]
# 11  Light-duty plug-in cumulative registrations in...
# 12                             940,383 [32][142][140]
# 13                                  378,930 [20][145]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                                 1,728,447 [32][93]
# 16  Notes ^ a b c d e f g h i j Only includes plug...
#
#
#                                                 sales
# 0                                     579,000 [93][i]
# 1                                        199,818 [96]
# 2                                        54,492 [100]
# 3                                        42,799 [108]
# 4                                     49,182 [i][114]
# 5                                        71,737 [123]
# 6                                        11,085 [128]
# 7                                        19,793 [132]
# 8                                         54,100 [91]
# 9                                        18,746 [137]
# 10                                     1,148,700 [91]
# 11  Light-duty plug-in cumulative registrations in...
# 12                                 302,383 [142][140]
# 13                                      107,779 [145]
# 14  Plug-in vehicle cumulative sales for all class...
# 15                                       777,000 [93]
# 16  Notes ^ a b c d e f g h i j Only includes plug...

# %%
csv_file_path = r'C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\scraping\wikipedia_ev_sales_scraping.csv'
ev_sales.to_csv(csv_file_path, index=False)

# %% [markdown]
# # Scraping updated prices

# %%
url = "https://ev-database.org/#sort:path~type~order=.rank~number~desc|range-slider-range:prev~next=0~1200|range-slider-acceleration:prev~next=2~23|range-slider-topspeed:prev~next=110~350|range-slider-battery:prev~next=10~200|range-slider-towweight:prev~next=0~2500|range-slider-fastcharge:prev~next=0~1500|paging:currentPage=0|paging:number=all"

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

# %%
ev_prices2 = []

ev_elements = soup.find_all('div', class_='list-item')

# %%
data_wrappers = soup.find_all('div', class_='data-wrapper')

cars_list = []

for wrapper in data_wrappers:
    car_name_element = wrapper.find('h2')
    car_name = car_name_element.get_text(strip=True) if car_name_element else 'Name not found'

    price_de_element = wrapper.find('span', class_='country_de')
    price_de = price_de_element.get_text(strip=True) if price_de_element else 'DE Price not found'

    price_uk_element = wrapper.find('span', class_='country_uk')
    price_uk = price_uk_element.get_text(strip=True) if price_uk_element else 'UK Price not found'

    price_nl_element = wrapper.find('span', class_='country_nl')  
    price_nl = price_nl_element.get_text(strip=True) if price_nl_element else 'NL Price not found'

    car_acceleration_element = wrapper.find('span', class_='acceleration')  
    car_acceleration = car_acceleration_element.get_text(strip=True) if car_acceleration_element else 'Acceleration not found'

    car_top_speed_element = wrapper.find('span', class_='topspeed')  
    car_top_speed = car_top_speed_element.get_text(strip=True) if car_top_speed_element else 'Top speed not found'

    car_range_element = wrapper.find('span', class_='erange_real')  
    car_range = car_range_element.get_text(strip=True) if car_range_element else 'Range not found'

    car_efficiency_element = wrapper.find('span', class_='efficiency')  
    car_efficiency = car_efficiency_element.get_text(strip=True) if car_efficiency_element else 'Efficiency not found'

    car_fastcharge_element = wrapper.find('span', class_='fastcharge_speed_print')  
    car_fastcharge = car_fastcharge_element.get_text(strip=True) if car_fastcharge_element else 'Fastcharge not found'
    
    car_towing_capacity_element = wrapper.find('span', class_='towweight')  
    car_towing_capacity = car_towing_capacity_element.get_text(strip=True) if car_towing_capacity_element else 'Towing capacity not found' 
    
    car_availability_element = wrapper.find('span', class_='current')  
    car_availability = car_availability_element.get_text(strip=True) if car_availability_element else 'Availability not found' 
    

    car_data = {
        'name': car_name,
        'de_price': price_de,
        'uk_price': price_uk,
        'nl_price': price_nl,
        'acceleration_0-100km/h': car_acceleration,
        'top_speed': car_top_speed,
        'range': car_range,
        'efficiency': car_efficiency,
        'fastcharge': car_fastcharge,
        'towing_capacity(kg)': car_towing_capacity,
        'availability': car_availability
    }
    cars_list.append(car_data)

for car in cars_list:
    print(car)
# Out:
# {'name': 'TeslaModel Y Long Range Dual Motor', 'de_price': '€59,017', 'uk_price': '£52,990', 'nl_price': '€54,993', 'acceleration_0-100km/h': '5.0 sec', 'top_speed': '217 km/h', 'range': '435 km', 'efficiency': '172 Wh/km', 'fastcharge': '670 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since February 2022'}
# {'name': 'BYDATTO 3', 'de_price': '€44,625', 'uk_price': '£37,195', 'nl_price': '€42,998', 'acceleration_0-100km/h': '7.3 sec', 'top_speed': '160 km/h', 'range': '330 km', 'efficiency': '183 Wh/km', 'fastcharge': '370 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since August 2022'}
# {'name': 'TeslaModel 3', 'de_price': '€46,220', 'uk_price': '£39,990', 'nl_price': '€43,993', 'acceleration_0-100km/h': '6.1 sec', 'top_speed': '201 km/h', 'range': '420 km', 'efficiency': '137 Wh/km', 'fastcharge': '700 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since September 2023'}
# {'name': 'TeslaModel 3 Long Range Dual Motor', 'de_price': '€55,220', 'uk_price': '£49,990', 'nl_price': '€51,993', 'acceleration_0-100km/h': '4.4 sec', 'top_speed': '201 km/h', 'range': '505 km', 'efficiency': '149 Wh/km', 'fastcharge': '780 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since September 2023'}
# {'name': 'TeslaModel Y', 'de_price': '€47,567', 'uk_price': '£44,990', 'nl_price': '€45,993', 'acceleration_0-100km/h': '6.9 sec', 'top_speed': '217 km/h', 'range': '350 km', 'efficiency': '164 Wh/km', 'fastcharge': '580 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since November 2022'}
# {'name': 'MGMG4 Electric 64 kWh', 'de_price': '€39,990', 'uk_price': '£29,495', 'nl_price': '€35,785', 'acceleration_0-100km/h': '7.9 sec', 'top_speed': '160 km/h', 'range': '360 km', 'efficiency': '171 Wh/km', 'fastcharge': '630 km/h', 'towing_capacity(kg)': '500', 'availability': 'Available to order since October 2022'}
# {'name': 'BYDSEAL 82.5 kWh AWD Excellence', 'de_price': '€53,668', 'uk_price': '£48,695', 'nl_price': '€50,990', 'acceleration_0-100km/h': '3.8 sec', 'top_speed': '180 km/h', 'range': '485 km', 'efficiency': '170 Wh/km', 'fastcharge': '530 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since September 2023'}
# {'name': 'BMWiX xDrive40', 'de_price': '€77,300', 'uk_price': '£69,905', 'nl_price': '€84,998', 'acceleration_0-100km/h': '6.1 sec', 'top_speed': '200 km/h', 'range': '360 km', 'efficiency': '197 Wh/km', 'fastcharge': '480 km/h', 'towing_capacity(kg)': '2500', 'availability': 'Available to order since October 2021'}
# {'name': 'Citroene-C3', 'de_price': '€23,300', 'uk_price': '* £21,000', 'nl_price': '€24,290', 'acceleration_0-100km/h': '11.0 sec', 'top_speed': '135 km/h', 'range': '250 km', 'efficiency': '176 Wh/km', 'fastcharge': '320 km/h', 'towing_capacity(kg)': '', 'availability': 'Availability not found'}
# {'name': 'BMWi4 eDrive40', 'de_price': '€59,200', 'uk_price': '£57,890', 'nl_price': '€62,992', 'acceleration_0-100km/h': '5.7 sec', 'top_speed': '190 km/h', 'range': '515 km', 'efficiency': '157 Wh/km', 'fastcharge': '800 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since November 2021'}
# {'name': 'BMWiX1 xDrive30', 'de_price': '€55,000', 'uk_price': '£47,465', 'nl_price': '€57,850', 'acceleration_0-100km/h': '5.6 sec', 'top_speed': '180 km/h', 'range': '380 km', 'efficiency': '170 Wh/km', 'fastcharge': '550 km/h', 'towing_capacity(kg)': '1200', 'availability': 'Available to order since November 2022'}
# {'name': 'HyundaiKona Electric 64 kWh', 'de_price': '€42,900', 'uk_price': 'N/A', 'nl_price': 'N/A', 'acceleration_0-100km/h': '7.9 sec', 'top_speed': '167 km/h', 'range': '390 km', 'efficiency': '164 Wh/km', 'fastcharge': '370 km/h', 'towing_capacity(kg)': '300', 'availability': 'Available to order since June 2021'}
# {'name': 'KiaNiro EV', 'de_price': '€45,690', 'uk_price': '£37,295', 'nl_price': '€39,995', 'acceleration_0-100km/h': '7.8 sec', 'top_speed': '167 km/h', 'range': '385 km', 'efficiency': '168 Wh/km', 'fastcharge': '390 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since June 2022'}
# {'name': 'VolvoEX30 Single Motor ER', 'de_price': '€41,790', 'uk_price': '£38,545', 'nl_price': '€41,495', 'acceleration_0-100km/h': '5.3 sec', 'top_speed': '180 km/h', 'range': '370 km', 'efficiency': '173 Wh/km', 'fastcharge': '550 km/h', 'towing_capacity(kg)': '1400', 'availability': 'Available to order since June 2023'}
# {'name': 'BYDHAN', 'de_price': '€70,805', 'uk_price': 'N/A', 'nl_price': '€71,490', 'acceleration_0-100km/h': '3.9 sec', 'top_speed': '180 km/h', 'range': '475 km', 'efficiency': '180 Wh/km', 'fastcharge': '450 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since March 2023'}
# {'name': 'RenaultMegane E-Tech EV60 220hp', 'de_price': '€46,600', 'uk_price': '£36,995', 'nl_price': '€42,970', 'acceleration_0-100km/h': '7.4 sec', 'top_speed': '160 km/h', 'range': '380 km', 'efficiency': '158 Wh/km', 'fastcharge': '530 km/h', 'towing_capacity(kg)': '900', 'availability': 'Available to order since April 2022'}
# {'name': 'Rolls-RoyceSpectre', 'de_price': '* €400,000', 'uk_price': '* £350,000', 'nl_price': '* €400,000', 'acceleration_0-100km/h': '4.5 sec', 'top_speed': '250 km/h', 'range': '465 km', 'efficiency': '219 Wh/km', 'fastcharge': '540 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since October 2023'}
# {'name': 'TeslaModel Y Performance', 'de_price': '€63,667', 'uk_price': '£59,990', 'nl_price': '€60,993', 'acceleration_0-100km/h': '3.7 sec', 'top_speed': '250 km/h', 'range': '415 km', 'efficiency': '181 Wh/km', 'fastcharge': '640 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since March 2022'}
# {'name': 'Smart#1', 'de_price': '€42,490', 'uk_price': '£35,950', 'nl_price': '€41,395', 'acceleration_0-100km/h': '6.7 sec', 'top_speed': '180 km/h', 'range': '335 km', 'efficiency': '185 Wh/km', 'fastcharge': '520 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since March 2023'}
# {'name': 'BYDDOLPHIN 60.4 kWh', 'de_price': '€35,990', 'uk_price': '£30,195', 'nl_price': '€36,490', 'acceleration_0-100km/h': '7.0 sec', 'top_speed': '160 km/h', 'range': '340 km', 'efficiency': '178 Wh/km', 'fastcharge': '340 km/h', 'towing_capacity(kg)': '0', 'availability': 'Available to order since July 2023'}
# {'name': 'DaciaSpring Electric 45', 'de_price': '€22,550', 'uk_price': 'N/A', 'nl_price': '€21,750', 'acceleration_0-100km/h': '19.1 sec', 'top_speed': '125 km/h', 'range': '165 km', 'efficiency': '152 Wh/km', 'fastcharge': '180 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since July 2022'}
# {'name': 'TeslaModel S Plaid', 'de_price': '€110,970', 'uk_price': '* £100,000', 'nl_price': '€110,993', 'acceleration_0-100km/h': '2.1 sec', 'top_speed': '282 km/h', 'range': '560 km', 'efficiency': '170 Wh/km', 'fastcharge': '780 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since November 2022'}
# {'name': 'BMWi5 eDrive40 Sedan', 'de_price': '€70,200', 'uk_price': '£74,105', 'nl_price': '€77,572', 'acceleration_0-100km/h': '6.0 sec', 'top_speed': '193 km/h', 'range': '475 km', 'efficiency': '171 Wh/km', 'fastcharge': '710 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since May 2023'}
# {'name': 'TeslaModel S Dual Motor', 'de_price': '€95,970', 'uk_price': '* £85,000', 'nl_price': '€95,993', 'acceleration_0-100km/h': '3.2 sec', 'top_speed': '250 km/h', 'range': '575 km', 'efficiency': '165 Wh/km', 'fastcharge': '800 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since January 2023'}
# {'name': 'BYDSEAL 82.5 kWh RWD Design', 'de_price': '€47,578', 'uk_price': '£45,695', 'nl_price': '€47,990', 'acceleration_0-100km/h': '5.9 sec', 'top_speed': '180 km/h', 'range': '500 km', 'efficiency': '165 Wh/km', 'fastcharge': '550 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since September 2023'}
# {'name': 'AudiQ8 e-tron 55 quattro', 'de_price': '€85,300', 'uk_price': '£77,800', 'nl_price': '€82,985', 'acceleration_0-100km/h': '5.6 sec', 'top_speed': '200 km/h', 'range': '505 km', 'efficiency': '210 Wh/km', 'fastcharge': '640 km/h', 'towing_capacity(kg)': '1800', 'availability': 'Available to order since December 2022'}
# {'name': 'BMWiX3', 'de_price': '€67,300', 'uk_price': '£64,165', 'nl_price': '€71,462', 'acceleration_0-100km/h': '6.8 sec', 'top_speed': '180 km/h', 'range': '385 km', 'efficiency': '192 Wh/km', 'fastcharge': '520 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since September 2021'}
# {'name': 'HyundaiIONIQ 6 Long Range AWD', 'de_price': '€61,100', 'uk_price': '£50,540', 'nl_price': '€59,395', 'acceleration_0-100km/h': '5.1 sec', 'top_speed': '185 km/h', 'range': '440 km', 'efficiency': '168 Wh/km', 'fastcharge': '1150 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since November 2022'}
# {'name': 'MGZS EV Long Range', 'de_price': '€37,990', 'uk_price': '£32,995', 'nl_price': '€39,885', 'acceleration_0-100km/h': '8.4 sec', 'top_speed': '175 km/h', 'range': '370 km', 'efficiency': '185 Wh/km', 'fastcharge': '420 km/h', 'towing_capacity(kg)': '500', 'availability': 'Available to order since November 2021'}
# {'name': 'BYDTANG', 'de_price': '€71,400', 'uk_price': 'N/A', 'nl_price': '€73,300', 'acceleration_0-100km/h': '4.6 sec', 'top_speed': '180 km/h', 'range': '360 km', 'efficiency': '240 Wh/km', 'fastcharge': '330 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since August 2022'}
# {'name': 'HongqiE-HS9 99 kWh', 'de_price': 'N/A', 'uk_price': 'N/A', 'nl_price': '€79,995', 'acceleration_0-100km/h': '4.9 sec', 'top_speed': '200 km/h', 'range': '370 km', 'efficiency': '243 Wh/km', 'fastcharge': '430 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since December 2022'}
# {'name': 'KiaEV6 Long Range 2WD', 'de_price': '€51,990', 'uk_price': '£45,245', 'nl_price': '€51,995', 'acceleration_0-100km/h': '7.3 sec', 'top_speed': '185 km/h', 'range': '410 km', 'efficiency': '180 Wh/km', 'fastcharge': '1070 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since October 2021'}
# {'name': 'HyundaiKona Electric 65 kWh', 'de_price': '€47,190', 'uk_price': '£38,595', 'nl_price': '€43,995', 'acceleration_0-100km/h': '7.8 sec', 'top_speed': '170 km/h', 'range': '390 km', 'efficiency': '168 Wh/km', 'fastcharge': '400 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since July 2023'}
# {'name': 'TeslaModel Y', 'de_price': '€47,567', 'uk_price': '£44,990', 'nl_price': '€45,993', 'acceleration_0-100km/h': '6.9 sec', 'top_speed': '217 km/h', 'range': '350 km', 'efficiency': '164 Wh/km', 'fastcharge': '810 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since May 2023'}
# {'name': 'ToyotabZ4X FWD', 'de_price': '€47,490', 'uk_price': '£46,110', 'nl_price': '€48,995', 'acceleration_0-100km/h': '7.5 sec', 'top_speed': '160 km/h', 'range': '340 km', 'efficiency': '188 Wh/km', 'fastcharge': '510 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since June 2022'}
# {'name': 'AudiQ4 e-tron 40', 'de_price': 'N/A', 'uk_price': '£50,630', 'nl_price': 'N/A', 'acceleration_0-100km/h': '8.5 sec', 'top_speed': '160 km/h', 'range': '405 km', 'efficiency': '189 Wh/km', 'fastcharge': '630 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since June 2021'}
# {'name': 'BMWiX xDrive50', 'de_price': '€100,100', 'uk_price': '£102,755', 'nl_price': '€105,097', 'acceleration_0-100km/h': '4.6 sec', 'top_speed': '200 km/h', 'range': '505 km', 'efficiency': '208 Wh/km', 'fastcharge': '680 km/h', 'towing_capacity(kg)': '2500', 'availability': 'Available to order since November 2021'}
# {'name': 'BMWi4 M50', 'de_price': '€70,800', 'uk_price': '£71,085', 'nl_price': '€76,786', 'acceleration_0-100km/h': '3.9 sec', 'top_speed': '225 km/h', 'range': '450 km', 'efficiency': '179 Wh/km', 'fastcharge': '700 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since November 2021'}
# {'name': 'Peugeote-3008 73 kWh', 'de_price': '€48,650', 'uk_price': '* £42,000', 'nl_price': '€48,190', 'acceleration_0-100km/h': '8.7 sec', 'top_speed': '170 km/h', 'range': '385 km', 'efficiency': '190 Wh/km', 'fastcharge': '440 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since November 2023'}
# {'name': 'Fiat500e Hatchback 42 kWh', 'de_price': '€34,990', 'uk_price': '£31,195', 'nl_price': '€34,490', 'acceleration_0-100km/h': '9.0 sec', 'top_speed': '150 km/h', 'range': '235 km', 'efficiency': '159 Wh/km', 'fastcharge': '390 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since November 2020'}
# {'name': 'HyundaiIONIQ 6 Long Range 2WD', 'de_price': '€54,000', 'uk_price': '£47,040', 'nl_price': '€50,895', 'acceleration_0-100km/h': '7.4 sec', 'top_speed': '185 km/h', 'range': '495 km', 'efficiency': '149 Wh/km', 'fastcharge': '1290 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since December 2022'}
# {'name': 'RenaultZoe ZE50 R110', 'de_price': '€36,840', 'uk_price': 'N/A', 'nl_price': '€34,895', 'acceleration_0-100km/h': '11.4 sec', 'top_speed': '135 km/h', 'range': '315 km', 'efficiency': '165 Wh/km', 'fastcharge': '230 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since November 2019'}
# {'name': 'BMWi7 xDrive60', 'de_price': '€139,900', 'uk_price': '£113,970', 'nl_price': '€145,453', 'acceleration_0-100km/h': '4.7 sec', 'top_speed': '240 km/h', 'range': '510 km', 'efficiency': '199 Wh/km', 'fastcharge': '760 km/h', 'towing_capacity(kg)': '2000', 'availability': 'Available to order since November 2022'}
# {'name': 'VolkswagenID.7 Pro', 'de_price': '€56,995', 'uk_price': '£55,570', 'nl_price': '€63,990', 'acceleration_0-100km/h': '6.5 sec', 'top_speed': '180 km/h', 'range': '475 km', 'efficiency': '162 Wh/km', 'fastcharge': '710 km/h', 'towing_capacity(kg)': '1200', 'availability': 'Available to order since August 2023'}
# {'name': 'HyundaiIONIQ 5 Long Range 2WD', 'de_price': '€47,900', 'uk_price': '£46,945', 'nl_price': '€52,895', 'acceleration_0-100km/h': '7.3 sec', 'top_speed': '185 km/h', 'range': '390 km', 'efficiency': '190 Wh/km', 'fastcharge': '1020 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since April 2022'}
# {'name': 'SkodaEnyaq 85', 'de_price': '€48,900', 'uk_price': '£44,540', 'nl_price': '€49,990', 'acceleration_0-100km/h': '6.7 sec', 'top_speed': '180 km/h', 'range': '455 km', 'efficiency': '169 Wh/km', 'fastcharge': '680 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since September 2023'}
# {'name': 'Peugeote-208', 'de_price': '€39,100', 'uk_price': '£31,595', 'nl_price': 'N/A', 'acceleration_0-100km/h': '8.1 sec', 'top_speed': '150 km/h', 'range': '285 km', 'efficiency': '162 Wh/km', 'fastcharge': '460 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since November 2021'}
# {'name': 'CUPRABorn 150 kW - 58 kWh', 'de_price': '€39,370', 'uk_price': '£36,475', 'nl_price': '€39,990', 'acceleration_0-100km/h': '7.3 sec', 'top_speed': '160 km/h', 'range': '350 km', 'efficiency': '166 Wh/km', 'fastcharge': '470 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since October 2021'}
# {'name': 'BYDDOLPHIN 44.9 kWh Active', 'de_price': '€29,990', 'uk_price': '* £26,000', 'nl_price': '€29,990', 'acceleration_0-100km/h': '10.0 sec', 'top_speed': '150 km/h', 'range': '255 km', 'efficiency': '176 Wh/km', 'fastcharge': '260 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since July 2023'}
# {'name': 'RenaultTwingo Electric', 'de_price': '€28,000', 'uk_price': 'N/A', 'nl_price': '€24,190', 'acceleration_0-100km/h': '12.6 sec', 'top_speed': '135 km/h', 'range': '135 km', 'efficiency': '158 Wh/km', 'fastcharge': '-', 'towing_capacity(kg)': '', 'availability': 'Available to order since November 2020'}
# {'name': 'MGMG4 Electric 51 kWh', 'de_price': '€34,990', 'uk_price': '£26,995', 'nl_price': '€32,285', 'acceleration_0-100km/h': '7.7 sec', 'top_speed': '160 km/h', 'range': '300 km', 'efficiency': '169 Wh/km', 'fastcharge': '390 km/h', 'towing_capacity(kg)': '500', 'availability': 'Available to order since October 2022'}
# {'name': 'Citroene-C4', 'de_price': '€36,040', 'uk_price': '£31,995', 'nl_price': '€37,830', 'acceleration_0-100km/h': '9.7 sec', 'top_speed': '150 km/h', 'range': '290 km', 'efficiency': '160 Wh/km', 'fastcharge': '460 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since November 2021'}
# {'name': 'MiniCooper SE', 'de_price': '€35,700', 'uk_price': '£32,550', 'nl_price': '€38,690', 'acceleration_0-100km/h': '7.3 sec', 'top_speed': '150 km/h', 'range': '180 km', 'efficiency': '161 Wh/km', 'fastcharge': '260 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since March 2021'}
# {'name': 'MercedesEQA 250+', 'de_price': 'N/A', 'uk_price': '£49,750', 'nl_price': 'N/A', 'acceleration_0-100km/h': '8.6 sec', 'top_speed': '160 km/h', 'range': '420 km', 'efficiency': '168 Wh/km', 'fastcharge': '580 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since June 2022'}
# {'name': 'HyundaiIONIQ 5 N', 'de_price': 'N/A', 'uk_price': '£65,000', 'nl_price': 'N/A', 'acceleration_0-100km/h': '3.4 sec', 'top_speed': '260 km/h', 'range': '385 km', 'efficiency': '208 Wh/km', 'fastcharge': '950 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since November 2023'}
# {'name': 'VolkswagenID.3 Pro', 'de_price': '€39,995', 'uk_price': '£37,115', 'nl_price': '€44,990', 'acceleration_0-100km/h': '7.3 sec', 'top_speed': '160 km/h', 'range': '350 km', 'efficiency': '166 Wh/km', 'fastcharge': '450 km/h', 'towing_capacity(kg)': '0', 'availability': 'Available to order since March 2023'}
# {'name': 'KiaEV6 GT', 'de_price': '€72,990', 'uk_price': '£62,645', 'nl_price': '€69,295', 'acceleration_0-100km/h': '3.5 sec', 'top_speed': '260 km/h', 'range': '360 km', 'efficiency': '206 Wh/km', 'fastcharge': '940 km/h', 'towing_capacity(kg)': '1800', 'availability': 'Available to order since April 2022'}
# {'name': 'BMWi4 eDrive35', 'de_price': '€56,500', 'uk_price': '£49,995', 'nl_price': '€59,362', 'acceleration_0-100km/h': '6.0 sec', 'top_speed': '190 km/h', 'range': '430 km', 'efficiency': '156 Wh/km', 'fastcharge': '580 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since November 2022'}
# {'name': 'JeepAvenger Electric', 'de_price': '€37,000', 'uk_price': '£35,700', 'nl_price': '€39,500', 'acceleration_0-100km/h': '9.0 sec', 'top_speed': '150 km/h', 'range': '310 km', 'efficiency': '164 Wh/km', 'fastcharge': '500 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since January 2023'}
# {'name': 'KiaEV9 99.8 kWh AWD', 'de_price': '€76,490', 'uk_price': 'N/A', 'nl_price': '€71,495', 'acceleration_0-100km/h': '6.0 sec', 'top_speed': '200 km/h', 'range': '425 km', 'efficiency': '226 Wh/km', 'fastcharge': '740 km/h', 'towing_capacity(kg)': '2500', 'availability': 'Available to order since September 2023'}
# {'name': 'Zeekr001 Performance AWD', 'de_price': '€63,970', 'uk_price': 'N/A', 'nl_price': '€63,490', 'acceleration_0-100km/h': '3.8 sec', 'top_speed': '200 km/h', 'range': '505 km', 'efficiency': '186 Wh/km', 'fastcharge': '700 km/h', 'towing_capacity(kg)': '2000', 'availability': 'Available to order since September 2023'}
# {'name': 'VolkswagenID. Buzz Pro', 'de_price': '€64,581', 'uk_price': '£58,915', 'nl_price': '€66,160', 'acceleration_0-100km/h': '10.2 sec', 'top_speed': '145 km/h', 'range': '345 km', 'efficiency': '223 Wh/km', 'fastcharge': '480 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since September 2022'}
# {'name': 'VolkswagenID.4 Pro', 'de_price': '€46,335', 'uk_price': '£46,035', 'nl_price': '* €52,000', 'acceleration_0-100km/h': '6.7 sec', 'top_speed': '180 km/h', 'range': '435 km', 'efficiency': '177 Wh/km', 'fastcharge': '650 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since October 2023'}
# {'name': 'Audie-tron GT RS', 'de_price': '€146,050', 'uk_price': '£119,000', 'nl_price': '€154,835', 'acceleration_0-100km/h': '3.3 sec', 'top_speed': '250 km/h', 'range': '405 km', 'efficiency': '210 Wh/km', 'fastcharge': '1000 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since March 2021'}
# {'name': 'Hondae:Ny1', 'de_price': '€47,590', 'uk_price': '£44,995', 'nl_price': '€48,750', 'acceleration_0-100km/h': '7.6 sec', 'top_speed': '160 km/h', 'range': '335 km', 'efficiency': '185 Wh/km', 'fastcharge': '300 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since June 2023'}
# {'name': 'BMWiX1 eDrive20', 'de_price': '€47,900', 'uk_price': '£45,465', 'nl_price': '€48,316', 'acceleration_0-100km/h': '8.3 sec', 'top_speed': '170 km/h', 'range': '390 km', 'efficiency': '166 Wh/km', 'fastcharge': '560 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since September 2023'}
# {'name': 'OpelAstra Electric', 'de_price': '€41,990', 'uk_price': '£37,795', 'nl_price': '€39,999', 'acceleration_0-100km/h': '9.2 sec', 'top_speed': '170 km/h', 'range': '305 km', 'efficiency': '167 Wh/km', 'fastcharge': '490 km/h', 'towing_capacity(kg)': '0', 'availability': 'Available to order since June 2023'}
# {'name': 'OpelCorsa-e', 'de_price': 'N/A', 'uk_price': '£33,930', 'nl_price': 'N/A', 'acceleration_0-100km/h': '8.1 sec', 'top_speed': '150 km/h', 'range': '295 km', 'efficiency': '157 Wh/km', 'fastcharge': '470 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since November 2021'}
# {'name': 'NissanAriya 87kWh', 'de_price': '€58,990', 'uk_price': '£44,645', 'nl_price': '€47,990', 'acceleration_0-100km/h': '7.6 sec', 'top_speed': '160 km/h', 'range': '450 km', 'efficiency': '193 Wh/km', 'fastcharge': '540 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since July 2022'}
# {'name': 'Peugeote-3008 98 kWh Long Range', 'de_price': '* €55,000', 'uk_price': '* £48,000', 'nl_price': '* €55,000', 'acceleration_0-100km/h': '9.0 sec', 'top_speed': '170 km/h', 'range': '505 km', 'efficiency': '194 Wh/km', 'fastcharge': '660 km/h', 'towing_capacity(kg)': '', 'availability': 'Availability not found'}
# {'name': 'NissanLeaf', 'de_price': '€33,400', 'uk_price': '£28,995', 'nl_price': '€35,090', 'acceleration_0-100km/h': '7.9 sec', 'top_speed': '144 km/h', 'range': '235 km', 'efficiency': '166 Wh/km', 'fastcharge': '230 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since March 2022'}
# {'name': 'Smart#1 Brabus', 'de_price': '€48,990', 'uk_price': '£43,450', 'nl_price': '€48,895', 'acceleration_0-100km/h': '3.9 sec', 'top_speed': '180 km/h', 'range': '315 km', 'efficiency': '197 Wh/km', 'fastcharge': '490 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since March 2023'}
# {'name': 'LucidAir Dream Edition R', 'de_price': '€218,000', 'uk_price': 'N/A', 'nl_price': '€222,000', 'acceleration_0-100km/h': '2.9 sec', 'top_speed': '270 km/h', 'range': '685 km', 'efficiency': '172 Wh/km', 'fastcharge': '870 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since January 2022'}
# {'name': 'LotusEletre', 'de_price': '€95,990', 'uk_price': '£89,500', 'nl_price': '€98,690', 'acceleration_0-100km/h': '4.5 sec', 'top_speed': '250 km/h', 'range': '495 km', 'efficiency': '220 Wh/km', 'fastcharge': '1040 km/h', 'towing_capacity(kg)': '2250', 'availability': 'Available to order since March 2023'}
# {'name': 'VolvoEX30 Single Motor', 'de_price': '€36,590', 'uk_price': '£33,795', 'nl_price': '€36,795', 'acceleration_0-100km/h': '5.7 sec', 'top_speed': '180 km/h', 'range': '280 km', 'efficiency': '175 Wh/km', 'fastcharge': '430 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since June 2023'}
# {'name': 'MGMG4 Electric 77 kWh', 'de_price': '€45,990', 'uk_price': '£36,495', 'nl_price': '€41,285', 'acceleration_0-100km/h': '6.5 sec', 'top_speed': '180 km/h', 'range': '425 km', 'efficiency': '175 Wh/km', 'fastcharge': '430 km/h', 'towing_capacity(kg)': '500', 'availability': 'Available to order since August 2023'}
# {'name': 'HyundaiIONIQ 5 Standard Range 2WD', 'de_price': '€43,900', 'uk_price': '£43,445', 'nl_price': '€49,295', 'acceleration_0-100km/h': '8.5 sec', 'top_speed': '185 km/h', 'range': '295 km', 'efficiency': '183 Wh/km', 'fastcharge': '720 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since July 2021'}
# {'name': 'CUPRABorn 170 kW - 77 kWh', 'de_price': '€46,450', 'uk_price': '£41,975', 'nl_price': '€51,990', 'acceleration_0-100km/h': '7.0 sec', 'top_speed': '160 km/h', 'range': '450 km', 'efficiency': '171 Wh/km', 'fastcharge': '630 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since March 2022'}
# {'name': 'FiskerOcean One', 'de_price': '€69,950', 'uk_price': '£60,880', 'nl_price': 'N/A', 'acceleration_0-100km/h': '3.9 sec', 'top_speed': '205 km/h', 'range': '530 km', 'efficiency': '201 Wh/km', 'fastcharge': '630 km/h', 'towing_capacity(kg)': '1820', 'availability': 'Available to order since March 2023'}
# {'name': 'VolkswagenID.7 Pro S', 'de_price': '* €60,000', 'uk_price': '* £59,000', 'nl_price': '* €68,000', 'acceleration_0-100km/h': '7.0 sec', 'top_speed': '180 km/h', 'range': '520 km', 'efficiency': '165 Wh/km', 'fastcharge': '800 km/h', 'towing_capacity(kg)': '', 'availability': 'Availability not found'}
# {'name': 'SubaruSolterra AWD', 'de_price': '€57,490', 'uk_price': '£49,995', 'nl_price': '€56,395', 'acceleration_0-100km/h': '6.9 sec', 'top_speed': '160 km/h', 'range': '320 km', 'efficiency': '200 Wh/km', 'fastcharge': '480 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since June 2022'}
# {'name': 'MGMG4 Electric XPOWER', 'de_price': '€46,990', 'uk_price': '£36,495', 'nl_price': '€42,285', 'acceleration_0-100km/h': '3.8 sec', 'top_speed': '200 km/h', 'range': '320 km', 'efficiency': '193 Wh/km', 'fastcharge': '560 km/h', 'towing_capacity(kg)': '500', 'availability': 'Available to order since August 2023'}
# {'name': 'Smart#3', 'de_price': '€43,490', 'uk_price': '* £37,000', 'nl_price': '* €42,500', 'acceleration_0-100km/h': '6.7 sec', 'top_speed': '180 km/h', 'range': '355 km', 'efficiency': '175 Wh/km', 'fastcharge': '550 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Availability not found'}
# {'name': 'MazdaMX-30', 'de_price': '€35,990', 'uk_price': '£31,250', 'nl_price': '€36,440', 'acceleration_0-100km/h': '9.7 sec', 'top_speed': '140 km/h', 'range': '170 km', 'efficiency': '176 Wh/km', 'fastcharge': '210 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since May 2022'}
# {'name': 'Polestar4 Long Range Dual Motor', 'de_price': '* €65,000', 'uk_price': '* £60,000', 'nl_price': '* €65,000', 'acceleration_0-100km/h': '3.8 sec', 'top_speed': '200 km/h', 'range': '465 km', 'efficiency': '202 Wh/km', 'fastcharge': '690 km/h', 'towing_capacity(kg)': '2000', 'availability': 'Availability not found'}
# {'name': 'Polestar2 Long Range Single Motor', 'de_price': '€54,475', 'uk_price': '£48,950', 'nl_price': '€55,200', 'acceleration_0-100km/h': '6.2 sec', 'top_speed': '205 km/h', 'range': '470 km', 'efficiency': '168 Wh/km', 'fastcharge': '700 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since January 2023'}
# {'name': 'Zeekr001 Long Range RWD', 'de_price': '€60,970', 'uk_price': 'N/A', 'nl_price': '€60,490', 'acceleration_0-100km/h': '7.2 sec', 'top_speed': '200 km/h', 'range': '530 km', 'efficiency': '177 Wh/km', 'fastcharge': '740 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since September 2023'}
# {'name': 'MGMG5 Electric Long Range', 'de_price': '€38,490', 'uk_price': '£30,995', 'nl_price': '€38,885', 'acceleration_0-100km/h': '7.7 sec', 'top_speed': '185 km/h', 'range': '335 km', 'efficiency': '171 Wh/km', 'fastcharge': '330 km/h', 'towing_capacity(kg)': '500', 'availability': 'Available to order since March 2022'}
# {'name': 'OpelMokka-e', 'de_price': '€40,650', 'uk_price': '£38,835', 'nl_price': '€39,749', 'acceleration_0-100km/h': '9.2 sec', 'top_speed': '150 km/h', 'range': '260 km', 'efficiency': '178 Wh/km', 'fastcharge': '420 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since November 2021'}
# {'name': 'LexusRZ 450e', 'de_price': '€68,000', 'uk_price': '£64,500', 'nl_price': '€67,495', 'acceleration_0-100km/h': '5.6 sec', 'top_speed': '160 km/h', 'range': '320 km', 'efficiency': '200 Wh/km', 'fastcharge': '480 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since February 2023'}
# {'name': 'FiskerOcean Ultra', 'de_price': '€57,000', 'uk_price': '£49,880', 'nl_price': '€58,990', 'acceleration_0-100km/h': '4.2 sec', 'top_speed': '200 km/h', 'range': '535 km', 'efficiency': '199 Wh/km', 'fastcharge': '640 km/h', 'towing_capacity(kg)': '1820', 'availability': 'Available to order since March 2023'}
# {'name': 'TeslaModel X Dual Motor', 'de_price': '€100,970', 'uk_price': '* £105,000', 'nl_price': '€100,993', 'acceleration_0-100km/h': '3.9 sec', 'top_speed': '250 km/h', 'range': '475 km', 'efficiency': '200 Wh/km', 'fastcharge': '660 km/h', 'towing_capacity(kg)': '2250', 'availability': 'Available to order since January 2023'}
# {'name': 'RenaultZoe ZE50 R135', 'de_price': '€37,840', 'uk_price': '£29,995', 'nl_price': '€36,195', 'acceleration_0-100km/h': '9.5 sec', 'top_speed': '140 km/h', 'range': '310 km', 'efficiency': '168 Wh/km', 'fastcharge': '230 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since November 2019'}
# {'name': 'SkodaEnyaq Coupe 85', 'de_price': '€51,150', 'uk_price': '£46,440', 'nl_price': '€52,990', 'acceleration_0-100km/h': '6.7 sec', 'top_speed': '180 km/h', 'range': '485 km', 'efficiency': '159 Wh/km', 'fastcharge': '720 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since September 2023'}
# {'name': 'NIOET7 75 kWh', 'de_price': '€81,900', 'uk_price': 'N/A', 'nl_price': '€84,900', 'acceleration_0-100km/h': '3.8 sec', 'top_speed': '200 km/h', 'range': '400 km', 'efficiency': '176 Wh/km', 'fastcharge': '540 km/h', 'towing_capacity(kg)': '2000', 'availability': 'Available to order since October 2022'}
# {'name': 'Peugeote-308', 'de_price': '€44,765', 'uk_price': '* £42,025', 'nl_price': '€43,585', 'acceleration_0-100km/h': '9.8 sec', 'top_speed': '170 km/h', 'range': '300 km', 'efficiency': '169 Wh/km', 'fastcharge': '450 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since April 2023'}
# {'name': 'MercedesEQB 250+', 'de_price': '€53,514', 'uk_price': 'N/A', 'nl_price': '€54,966', 'acceleration_0-100km/h': '8.9 sec', 'top_speed': '160 km/h', 'range': '415 km', 'efficiency': '170 Wh/km', 'fastcharge': '560 km/h', 'towing_capacity(kg)': '1400', 'availability': 'Available to order since October 2023'}
# {'name': 'VolvoEX30 Twin Motor Performance', 'de_price': '€48,490', 'uk_price': '£40,995', 'nl_price': '€49,995', 'acceleration_0-100km/h': '3.6 sec', 'top_speed': '180 km/h', 'range': '360 km', 'efficiency': '178 Wh/km', 'fastcharge': '540 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since June 2023'}
# {'name': 'MercedesEQB 350 4MATIC', 'de_price': 'N/A', 'uk_price': '£56,810', 'nl_price': 'N/A', 'acceleration_0-100km/h': '6.2 sec', 'top_speed': '160 km/h', 'range': '340 km', 'efficiency': '196 Wh/km', 'fastcharge': '490 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since February 2022'}
# {'name': 'HyundaiIONIQ 5 Long Range AWD', 'de_price': '€59,200', 'uk_price': '£50,445', 'nl_price': '€60,995', 'acceleration_0-100km/h': '5.1 sec', 'top_speed': '185 km/h', 'range': '385 km', 'efficiency': '192 Wh/km', 'fastcharge': '1010 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since April 2022'}
# {'name': 'BMWi5 M60 xDrive Sedan', 'de_price': '€99,500', 'uk_price': '£97,745', 'nl_price': '€108,427', 'acceleration_0-100km/h': '3.8 sec', 'top_speed': '230 km/h', 'range': '425 km', 'efficiency': '191 Wh/km', 'fastcharge': '630 km/h', 'towing_capacity(kg)': '2000', 'availability': 'Available to order since May 2023'}
# {'name': 'KiaEV6 Long Range AWD', 'de_price': '€55,980', 'uk_price': '£51,745', 'nl_price': '€57,995', 'acceleration_0-100km/h': '5.2 sec', 'top_speed': '185 km/h', 'range': '400 km', 'efficiency': '185 Wh/km', 'fastcharge': '1050 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since October 2021'}
# {'name': 'HyundaiKona Electric 39 kWh', 'de_price': '€36,400', 'uk_price': 'N/A', 'nl_price': 'N/A', 'acceleration_0-100km/h': '9.9 sec', 'top_speed': '155 km/h', 'range': '245 km', 'efficiency': '160 Wh/km', 'fastcharge': '210 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since June 2021'}
# {'name': 'MercedesEQS 450+', 'de_price': '€109,551', 'uk_price': 'N/A', 'nl_price': '€112,720', 'acceleration_0-100km/h': '6.1 sec', 'top_speed': '210 km/h', 'range': '635 km', 'efficiency': '171 Wh/km', 'fastcharge': '950 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since June 2023'}
# {'name': 'HyundaiIONIQ 6 Standard Range 2WD', 'de_price': '€43,900', 'uk_price': 'N/A', 'nl_price': '€45,895', 'acceleration_0-100km/h': '8.8 sec', 'top_speed': '185 km/h', 'range': '365 km', 'efficiency': '148 Wh/km', 'fastcharge': '900 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since January 2023'}
# {'name': 'AudiQ8 e-tron Sportback 55 quattro', 'de_price': '€87,550', 'uk_price': '£80,300', 'nl_price': '€85,385', 'acceleration_0-100km/h': '5.6 sec', 'top_speed': '200 km/h', 'range': '525 km', 'efficiency': '202 Wh/km', 'fastcharge': '660 km/h', 'towing_capacity(kg)': '1800', 'availability': 'Available to order since December 2022'}
# {'name': 'VolvoXC40 Recharge Single Motor ER', 'de_price': '€53,000', 'uk_price': 'N/A', 'nl_price': '€51,495', 'acceleration_0-100km/h': '7.3 sec', 'top_speed': '180 km/h', 'range': '405 km', 'efficiency': '195 Wh/km', 'fastcharge': '600 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since December 2022'}
# {'name': 'Fiat600e', 'de_price': '€36,490', 'uk_price': '* £31,000', 'nl_price': '€35,990', 'acceleration_0-100km/h': '9.0 sec', 'top_speed': '150 km/h', 'range': '305 km', 'efficiency': '167 Wh/km', 'fastcharge': '490 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since July 2023'}
# {'name': 'MaxusMIFA 9', 'de_price': '€68,990', 'uk_price': '£65,290', 'nl_price': 'N/A', 'acceleration_0-100km/h': '9.2 sec', 'top_speed': '180 km/h', 'range': '365 km', 'efficiency': '230 Wh/km', 'fastcharge': '330 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since February 2023'}
# {'name': 'Citroene-C4 X', 'de_price': '€37,540', 'uk_price': '£31,995', 'nl_price': '€38,680', 'acceleration_0-100km/h': '9.7 sec', 'top_speed': '150 km/h', 'range': '285 km', 'efficiency': '162 Wh/km', 'fastcharge': '460 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since November 2022'}
# {'name': 'BMWiX M60', 'de_price': '€136,100', 'uk_price': '£122,775', 'nl_price': '€138,383', 'acceleration_0-100km/h': '3.8 sec', 'top_speed': '250 km/h', 'range': '485 km', 'efficiency': '217 Wh/km', 'fastcharge': '650 km/h', 'towing_capacity(kg)': '2500', 'availability': 'Available to order since April 2022'}
# {'name': 'VolvoXC40 Recharge Twin Motor', 'de_price': '€59,950', 'uk_price': '£51,755', 'nl_price': '€59,995', 'acceleration_0-100km/h': '4.8 sec', 'top_speed': '180 km/h', 'range': '390 km', 'efficiency': '203 Wh/km', 'fastcharge': '580 km/h', 'towing_capacity(kg)': '1800', 'availability': 'Available to order since December 2022'}
# {'name': 'MercedesEQB 300 4MATIC', 'de_price': 'N/A', 'uk_price': '£55,310', 'nl_price': 'N/A', 'acceleration_0-100km/h': '8.0 sec', 'top_speed': '160 km/h', 'range': '340 km', 'efficiency': '196 Wh/km', 'fastcharge': '490 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since February 2022'}
# {'name': 'VolkswagenID.5 Pro', 'de_price': '€48,970', 'uk_price': '£50,940', 'nl_price': '* €56,000', 'acceleration_0-100km/h': '6.7 sec', 'top_speed': '180 km/h', 'range': '455 km', 'efficiency': '169 Wh/km', 'fastcharge': '680 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since October 2023'}
# {'name': 'MGMarvel R', 'de_price': '€46,990', 'uk_price': 'N/A', 'nl_price': '€49,485', 'acceleration_0-100km/h': '7.9 sec', 'top_speed': '200 km/h', 'range': '365 km', 'efficiency': '192 Wh/km', 'fastcharge': '400 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since October 2021'}
# {'name': 'ZeekrX Privilege AWD', 'de_price': '€50,470', 'uk_price': 'N/A', 'nl_price': '€50,490', 'acceleration_0-100km/h': '3.8 sec', 'top_speed': '180 km/h', 'range': '350 km', 'efficiency': '183 Wh/km', 'fastcharge': '520 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since October 2023'}
# {'name': 'NIOET5 100 kWh', 'de_price': '€68,500', 'uk_price': 'N/A', 'nl_price': '€71,700', 'acceleration_0-100km/h': '4.0 sec', 'top_speed': '200 km/h', 'range': '500 km', 'efficiency': '180 Wh/km', 'fastcharge': '520 km/h', 'towing_capacity(kg)': '1400', 'availability': 'Available to order since December 2022'}
# {'name': 'Polestar4 Long Range Single Motor', 'de_price': '* €60,000', 'uk_price': '* £55,000', 'nl_price': '* €60,000', 'acceleration_0-100km/h': '7.4 sec', 'top_speed': '180 km/h', 'range': '495 km', 'efficiency': '190 Wh/km', 'fastcharge': '740 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Availability not found'}
# {'name': 'TeslaModel X Plaid', 'de_price': '€115,970', 'uk_price': '* £120,000', 'nl_price': '€115,993', 'acceleration_0-100km/h': '2.6 sec', 'top_speed': '262 km/h', 'range': '455 km', 'efficiency': '209 Wh/km', 'fastcharge': '630 km/h', 'towing_capacity(kg)': '2250', 'availability': 'Available to order since November 2022'}
# {'name': 'Audie-tron GT quattro', 'de_price': '€106,050', 'uk_price': '£87,800', 'nl_price': '€111,115', 'acceleration_0-100km/h': '4.1 sec', 'top_speed': '245 km/h', 'range': '420 km', 'efficiency': '202 Wh/km', 'fastcharge': '1030 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since March 2021'}
# {'name': 'NissanLeaf e+', 'de_price': '€41,100', 'uk_price': '£34,945', 'nl_price': '€41,890', 'acceleration_0-100km/h': '6.9 sec', 'top_speed': '157 km/h', 'range': '340 km', 'efficiency': '174 Wh/km', 'fastcharge': '240 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since March 2022'}
# {'name': 'BMWiX2 xDrive30', 'de_price': '€56,500', 'uk_price': '£57,445', 'nl_price': '€59,350', 'acceleration_0-100km/h': '5.6 sec', 'top_speed': '180 km/h', 'range': '380 km', 'efficiency': '170 Wh/km', 'fastcharge': '550 km/h', 'towing_capacity(kg)': '1200', 'availability': 'Available to order since October 2023'}
# {'name': 'ToyotabZ4X AWD', 'de_price': '€57,390', 'uk_price': '£52,510', 'nl_price': '€59,995', 'acceleration_0-100km/h': '6.9 sec', 'top_speed': '160 km/h', 'range': '315 km', 'efficiency': '203 Wh/km', 'fastcharge': '470 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since June 2022'}
# {'name': 'MercedesEQA 250', 'de_price': '€50,777', 'uk_price': 'N/A', 'nl_price': 'N/A', 'acceleration_0-100km/h': '8.6 sec', 'top_speed': '160 km/h', 'range': '405 km', 'efficiency': '164 Wh/km', 'fastcharge': '580 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since October 2023'}
# {'name': 'VolvoXC40 Recharge Single Motor', 'de_price': '€47,500', 'uk_price': '£46,505', 'nl_price': '€45,995', 'acceleration_0-100km/h': '7.3 sec', 'top_speed': '180 km/h', 'range': '345 km', 'efficiency': '191 Wh/km', 'fastcharge': '420 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since December 2022'}
# {'name': 'Smart#3 Brabus', 'de_price': '€50,990', 'uk_price': '* £45,000', 'nl_price': '* €51,000', 'acceleration_0-100km/h': '3.7 sec', 'top_speed': '180 km/h', 'range': '330 km', 'efficiency': '188 Wh/km', 'fastcharge': '510 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Availability not found'}
# {'name': 'MercedesEQE 350+', 'de_price': 'N/A', 'uk_price': 'N/A', 'nl_price': '€82,028', 'acceleration_0-100km/h': '6.4 sec', 'top_speed': '210 km/h', 'range': '530 km', 'efficiency': '171 Wh/km', 'fastcharge': '790 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since June 2023'}
# {'name': 'MGMarvel R Performance', 'de_price': '€50,990', 'uk_price': 'N/A', 'nl_price': '€52,485', 'acceleration_0-100km/h': '4.9 sec', 'top_speed': '200 km/h', 'range': '350 km', 'efficiency': '200 Wh/km', 'fastcharge': '380 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since October 2021'}
# {'name': 'KiaEV9 99.8 kWh RWD', 'de_price': '€72,490', 'uk_price': '£64,995', 'nl_price': '€67,995', 'acceleration_0-100km/h': '9.4 sec', 'top_speed': '185 km/h', 'range': '450 km', 'efficiency': '213 Wh/km', 'fastcharge': '780 km/h', 'towing_capacity(kg)': '900', 'availability': 'Available to order since June 2023'}
# {'name': 'DaciaSpring Electric 65 Extreme', 'de_price': '€24,550', 'uk_price': 'N/A', 'nl_price': '€23,400', 'acceleration_0-100km/h': '13.7 sec', 'top_speed': '125 km/h', 'range': '160 km', 'efficiency': '156 Wh/km', 'fastcharge': '170 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since January 2023'}
# {'name': 'XPENGG9 RWD Standard Range', 'de_price': 'N/A', 'uk_price': 'N/A', 'nl_price': '€59,188', 'acceleration_0-100km/h': '6.4 sec', 'top_speed': '200 km/h', 'range': '400 km', 'efficiency': '190 Wh/km', 'fastcharge': '840 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since February 2023'}
# {'name': 'Peugeote-308 SW', 'de_price': '€45,765', 'uk_price': '* £38,000', 'nl_price': '€44,875', 'acceleration_0-100km/h': '9.0 sec', 'top_speed': '150 km/h', 'range': '300 km', 'efficiency': '169 Wh/km', 'fastcharge': '450 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since August 2023'}
# {'name': 'VolkswagenID.3 Pro S - 4 Seats', 'de_price': '€47,595', 'uk_price': '£42,870', 'nl_price': '€47,990', 'acceleration_0-100km/h': '7.9 sec', 'top_speed': '160 km/h', 'range': '455 km', 'efficiency': '169 Wh/km', 'fastcharge': '680 km/h', 'towing_capacity(kg)': '0', 'availability': 'Available to order since March 2023'}
# {'name': 'MercedesEQV 300 Long', 'de_price': '€71,626', 'uk_price': '£87,995', 'nl_price': '€83,617', 'acceleration_0-100km/h': '12.1 sec', 'top_speed': '160 km/h', 'range': '310 km', 'efficiency': '290 Wh/km', 'fastcharge': '310 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since September 2020'}
# {'name': 'AudiQ4 e-tron 45', 'de_price': '€52,950', 'uk_price': 'N/A', 'nl_price': '€54,865', 'acceleration_0-100km/h': '6.7 sec', 'top_speed': '180 km/h', 'range': '420 km', 'efficiency': '183 Wh/km', 'fastcharge': '630 km/h', 'towing_capacity(kg)': '1200', 'availability': 'Available to order since September 2023'}
# {'name': 'MercedesEQS SUV 580 4MATIC', 'de_price': '€135,434', 'uk_price': '£139,470', 'nl_price': 'N/A', 'acceleration_0-100km/h': '4.6 sec', 'top_speed': '210 km/h', 'range': '485 km', 'efficiency': '224 Wh/km', 'fastcharge': '720 km/h', 'towing_capacity(kg)': '1800', 'availability': 'Available to order since December 2022'}
# {'name': 'AudiQ8 e-tron 50 quattro', 'de_price': '€74,400', 'uk_price': '£67,800', 'nl_price': '€71,385', 'acceleration_0-100km/h': '6.0 sec', 'top_speed': '200 km/h', 'range': '425 km', 'efficiency': '209 Wh/km', 'fastcharge': '660 km/h', 'towing_capacity(kg)': '1800', 'availability': 'Available to order since December 2022'}
# {'name': 'Polestar2 Standard Range Single Motor', 'de_price': '€50,775', 'uk_price': '£44,950', 'nl_price': '€51,200', 'acceleration_0-100km/h': '6.4 sec', 'top_speed': '205 km/h', 'range': '405 km', 'efficiency': '165 Wh/km', 'fastcharge': '480 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since January 2023'}
# {'name': 'LucidAir Grand Touring', 'de_price': '€159,000', 'uk_price': 'N/A', 'nl_price': '€165,000', 'acceleration_0-100km/h': '3.0 sec', 'top_speed': '270 km/h', 'range': '665 km', 'efficiency': '168 Wh/km', 'fastcharge': '840 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since February 2023'}
# {'name': 'SkodaEnyaq 60', 'de_price': '€44,200', 'uk_price': '£38,970', 'nl_price': '€44,990', 'acceleration_0-100km/h': '8.7 sec', 'top_speed': '160 km/h', 'range': '340 km', 'efficiency': '171 Wh/km', 'fastcharge': '460 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since September 2023'}
# {'name': 'XPENGG9 RWD Long Range', 'de_price': 'N/A', 'uk_price': 'N/A', 'nl_price': '€63,188', 'acceleration_0-100km/h': '6.4 sec', 'top_speed': '200 km/h', 'range': '480 km', 'efficiency': '194 Wh/km', 'fastcharge': '1000 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since February 2023'}
# {'name': 'HongqiE-HS9 84 kWh', 'de_price': 'N/A', 'uk_price': 'N/A', 'nl_price': '€69,995', 'acceleration_0-100km/h': '6.5 sec', 'top_speed': '200 km/h', 'range': '320 km', 'efficiency': '239 Wh/km', 'fastcharge': '440 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since December 2022'}
# {'name': 'RenaultMegane E-Tech EV40 130hp', 'de_price': '€42,000', 'uk_price': 'N/A', 'nl_price': '€38,370', 'acceleration_0-100km/h': '10.0 sec', 'top_speed': '150 km/h', 'range': '260 km', 'efficiency': '154 Wh/km', 'fastcharge': '370 km/h', 'towing_capacity(kg)': '500', 'availability': 'Available to order since April 2022'}
# {'name': 'XPENGP7 Wing Edition', 'de_price': 'N/A', 'uk_price': 'N/A', 'nl_price': '€71,188', 'acceleration_0-100km/h': '4.1 sec', 'top_speed': '200 km/h', 'range': '465 km', 'efficiency': '178 Wh/km', 'fastcharge': '650 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since February 2023'}
# {'name': 'SsangYongKorando e-Motion', 'de_price': '€40,490', 'uk_price': 'N/A', 'nl_price': '€39,990', 'acceleration_0-100km/h': '8.5 sec', 'top_speed': '156 km/h', 'range': '290 km', 'efficiency': '193 Wh/km', 'fastcharge': '330 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since February 2022'}
# {'name': 'AudiQ4 e-tron 50 quattro', 'de_price': 'N/A', 'uk_price': '£57,010', 'nl_price': 'N/A', 'acceleration_0-100km/h': '6.2 sec', 'top_speed': '180 km/h', 'range': '385 km', 'efficiency': '199 Wh/km', 'fastcharge': '550 km/h', 'towing_capacity(kg)': '1200', 'availability': 'Available to order since July 2021'}
# {'name': 'FiskerOcean Sport', 'de_price': '€41,560', 'uk_price': '£35,970', 'nl_price': '€43,990', 'acceleration_0-100km/h': '7.4 sec', 'top_speed': '160 km/h', 'range': '380 km', 'efficiency': '197 Wh/km', 'fastcharge': '480 km/h', 'towing_capacity(kg)': '1090', 'availability': 'Available to order since March 2023'}
# {'name': 'MGZS EV Standard Range', 'de_price': '€33,990', 'uk_price': '£30,495', 'nl_price': '€35,885', 'acceleration_0-100km/h': '8.6 sec', 'top_speed': '175 km/h', 'range': '265 km', 'efficiency': '185 Wh/km', 'fastcharge': '250 km/h', 'towing_capacity(kg)': '500', 'availability': 'Available to order since November 2021'}
# {'name': 'FordMustang Mach-E ER RWD', 'de_price': '€58,500', 'uk_price': '* £53,000', 'nl_price': '€59,400', 'acceleration_0-100km/h': '7.0 sec', 'top_speed': '180 km/h', 'range': '480 km', 'efficiency': '190 Wh/km', 'fastcharge': '420 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since October 2023'}
# ...
# {'name': 'GenesisGV60 Sport Plus', 'de_price': '€73,100', 'uk_price': '£67,505', 'nl_price': 'N/A', 'acceleration_0-100km/h': '4.0 sec', 'top_speed': '235 km/h', 'range': '365 km', 'efficiency': '203 Wh/km', 'fastcharge': '950 km/h', 'towing_capacity(kg)': '1600', 'availability': 'Available to order since June 2022'}
# {'name': 'MercedesEQV 300 Extra-Long', 'de_price': '€72,519', 'uk_price': 'N/A', 'nl_price': '€84,809', 'acceleration_0-100km/h': '12.1 sec', 'top_speed': '160 km/h', 'range': '310 km', 'efficiency': '290 Wh/km', 'fastcharge': '310 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since October 2020'}
# {'name': 'MercedesEQA 300 4MATIC', 'de_price': '€53,520', 'uk_price': '* £53,000', 'nl_price': '€58,959', 'acceleration_0-100km/h': '7.7 sec', 'top_speed': '160 km/h', 'range': '355 km', 'efficiency': '187 Wh/km', 'fastcharge': '510 km/h', 'towing_capacity(kg)': '1800', 'availability': 'Available to order since October 2023'}
# {'name': 'MercedesEQE AMG 43 4MATIC', 'de_price': '€104,756', 'uk_price': 'N/A', 'nl_price': '€111,068', 'acceleration_0-100km/h': '4.2 sec', 'top_speed': '210 km/h', 'range': '465 km', 'efficiency': '195 Wh/km', 'fastcharge': '690 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since June 2023'}
# {'name': 'Peugeote-Expert Combi Long 75 kWh', 'de_price': '€58,730', 'uk_price': 'N/A', 'nl_price': '€59,303', 'acceleration_0-100km/h': '14.3 sec', 'top_speed': '130 km/h', 'range': '260 km', 'efficiency': '262 Wh/km', 'fastcharge': '280 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since February 2021'}
# {'name': 'HongqiE-HS9 120 kWh', 'de_price': 'N/A', 'uk_price': 'N/A', 'nl_price': '€102,995', 'acceleration_0-100km/h': '4.9 sec', 'top_speed': '200 km/h', 'range': '460 km', 'efficiency': '243 Wh/km', 'fastcharge': '420 km/h', 'towing_capacity(kg)': '1500', 'availability': 'Available to order since September 2023'}
# {'name': 'FiatE-Ulysse L3 75 kWh', 'de_price': '€62,990', 'uk_price': 'N/A', 'nl_price': 'N/A', 'acceleration_0-100km/h': '13.3 sec', 'top_speed': '130 km/h', 'range': '260 km', 'efficiency': '262 Wh/km', 'fastcharge': '280 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since June 2022'}
# {'name': 'Fiat500e Cabrio 24 kWh', 'de_price': '€35,490', 'uk_price': 'N/A', 'nl_price': '€31,990', 'acceleration_0-100km/h': '9.0 sec', 'top_speed': '135 km/h', 'range': '135 km', 'efficiency': '158 Wh/km', 'fastcharge': '230 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since July 2022'}
# {'name': 'PorscheTaycan Plus Sport Turismo', 'de_price': '€99,815', 'uk_price': '£84,654', 'nl_price': '€105,607', 'acceleration_0-100km/h': '5.4 sec', 'top_speed': '230 km/h', 'range': '445 km', 'efficiency': '188 Wh/km', 'fastcharge': '1090 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since March 2022'}
# {'name': 'PorscheTaycan Turbo Cross Turismo', 'de_price': '€165,848', 'uk_price': '£126,800', 'nl_price': '€173,264', 'acceleration_0-100km/h': '3.3 sec', 'top_speed': '250 km/h', 'range': '425 km', 'efficiency': '197 Wh/km', 'fastcharge': '1050 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since January 2023'}
# {'name': 'Peugeote-Traveller Long 75 kWh', 'de_price': '€60,430', 'uk_price': 'N/A', 'nl_price': '€68,378', 'acceleration_0-100km/h': '14.3 sec', 'top_speed': '130 km/h', 'range': '260 km', 'efficiency': '262 Wh/km', 'fastcharge': '280 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since February 2021'}
# {'name': 'Citroene-Jumpy Combi M 50 kWh', 'de_price': '€51,940', 'uk_price': 'N/A', 'nl_price': '€48,008', 'acceleration_0-100km/h': '12.1 sec', 'top_speed': '130 km/h', 'range': '185 km', 'efficiency': '250 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since November 2020'}
# {'name': 'Peugeote-Traveller Standard 50 kWh', 'de_price': '€53,640', 'uk_price': '£42,785', 'nl_price': '€57,428', 'acceleration_0-100km/h': '13.1 sec', 'top_speed': '130 km/h', 'range': '185 km', 'efficiency': '250 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since November 2020'}
# {'name': 'NIOEL7 75 kWh', 'de_price': '€85,900', 'uk_price': 'N/A', 'nl_price': '€88,900', 'acceleration_0-100km/h': '3.9 sec', 'top_speed': '200 km/h', 'range': '340 km', 'efficiency': '207 Wh/km', 'fastcharge': '460 km/h', 'towing_capacity(kg)': '2000', 'availability': 'Available to order since December 2022'}
# {'name': 'PorscheTaycan Turbo S Sport Turismo', 'de_price': '€198,692', 'uk_price': '£149,300', 'nl_price': '€207,163', 'acceleration_0-100km/h': '2.8 sec', 'top_speed': '260 km/h', 'range': '395 km', 'efficiency': '212 Wh/km', 'fastcharge': '970 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since March 2022'}
# {'name': 'VinFastVF 8 Plus Extended Range', 'de_price': '€58,890', 'uk_price': 'N/A', 'nl_price': '€59,790', 'acceleration_0-100km/h': '5.5 sec', 'top_speed': '200 km/h', 'range': '425 km', 'efficiency': '206 Wh/km', 'fastcharge': '550 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since November 2023'}
# {'name': 'Peugeote-Traveller Standard 75 kWh', 'de_price': '€59,640', 'uk_price': 'N/A', 'nl_price': '€66,442', 'acceleration_0-100km/h': '14.3 sec', 'top_speed': '130 km/h', 'range': '265 km', 'efficiency': '257 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since February 2021'}
# {'name': 'PorscheTaycan Turbo S Cross Turismo', 'de_price': '€199,168', 'uk_price': '£149,300', 'nl_price': '€207,664', 'acceleration_0-100km/h': '2.9 sec', 'top_speed': '250 km/h', 'range': '410 km', 'efficiency': '204 Wh/km', 'fastcharge': '1010 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since January 2023'}
# {'name': 'OpelZafira-e Life M 50 kWh', 'de_price': '€63,250', 'uk_price': '£42,735', 'nl_price': '€57,183', 'acceleration_0-100km/h': '12.1 sec', 'top_speed': '130 km/h', 'range': '185 km', 'efficiency': '250 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since November 2020'}
# {'name': 'MercedesEQV 250 Long', 'de_price': '€68,056', 'uk_price': 'N/A', 'nl_price': 'N/A', 'acceleration_0-100km/h': '12.0 sec', 'top_speed': '160 km/h', 'range': '210 km', 'efficiency': '286 Wh/km', 'fastcharge': '200 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since October 2021'}
# {'name': 'Citroene-SpaceTourer M 75 kWh', 'de_price': '€59,640', 'uk_price': 'N/A', 'nl_price': '€66,097', 'acceleration_0-100km/h': '13.3 sec', 'top_speed': '130 km/h', 'range': '265 km', 'efficiency': '257 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since February 2021'}
# {'name': 'Citroene-Berlingo XL 50 kWh', 'de_price': '€43,640', 'uk_price': '£33,315', 'nl_price': '€43,556', 'acceleration_0-100km/h': '11.7 sec', 'top_speed': '135 km/h', 'range': '205 km', 'efficiency': '226 Wh/km', 'fastcharge': '330 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since September 2021'}
# {'name': 'Citroene-Jumpy Combi XL 75 kWh', 'de_price': '€58,730', 'uk_price': 'N/A', 'nl_price': '€58,958', 'acceleration_0-100km/h': '13.3 sec', 'top_speed': '130 km/h', 'range': '260 km', 'efficiency': '262 Wh/km', 'fastcharge': '280 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since November 2020'}
# {'name': 'OpelCombo-e Life XL 50 kWh', 'de_price': '€44,750', 'uk_price': '£34,685', 'nl_price': 'N/A', 'acceleration_0-100km/h': '11.7 sec', 'top_speed': '135 km/h', 'range': '200 km', 'efficiency': '232 Wh/km', 'fastcharge': '320 km/h', 'towing_capacity(kg)': '750', 'availability': 'Available to order since October 2021'}
# {'name': 'MercedeseVito Tourer Long 60 kWh', 'de_price': '€60,678', 'uk_price': 'N/A', 'nl_price': 'N/A', 'acceleration_0-100km/h': '12.0 sec', 'top_speed': '160 km/h', 'range': '210 km', 'efficiency': '286 Wh/km', 'fastcharge': '310 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since January 2022'}
# {'name': 'Citroene-SpaceTourer XL 75 kWh', 'de_price': '€60,430', 'uk_price': 'N/A', 'nl_price': '€68,033', 'acceleration_0-100km/h': '13.3 sec', 'top_speed': '130 km/h', 'range': '260 km', 'efficiency': '262 Wh/km', 'fastcharge': '280 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since February 2021'}
# {'name': 'Peugeote-Expert Combi Long 50 kWh', 'de_price': '€52,730', 'uk_price': 'N/A', 'nl_price': '€50,289', 'acceleration_0-100km/h': '13.1 sec', 'top_speed': '130 km/h', 'range': '185 km', 'efficiency': '250 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since February 2021'}
# {'name': 'ToyotaPROACE Shuttle L 50 kWh', 'de_price': 'N/A', 'uk_price': 'N/A', 'nl_price': '€68,595', 'acceleration_0-100km/h': '12.1 sec', 'top_speed': '130 km/h', 'range': '180 km', 'efficiency': '257 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since June 2021'}
# {'name': 'ToyotaPROACE Shuttle M 75 kWh', 'de_price': 'N/A', 'uk_price': 'N/A', 'nl_price': '€60,095', 'acceleration_0-100km/h': '13.1 sec', 'top_speed': '130 km/h', 'range': '265 km', 'efficiency': '257 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since June 2021'}
# {'name': 'PorscheTaycan 4S Plus Sport Turismo', 'de_price': '€120,081', 'uk_price': '£95,996', 'nl_price': '€127,294', 'acceleration_0-100km/h': '4.0 sec', 'top_speed': '250 km/h', 'range': '430 km', 'efficiency': '195 Wh/km', 'fastcharge': '1060 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since March 2022'}
# {'name': 'MercedeseVito Tourer Extra-Long 60 kWh', 'de_price': '€61,571', 'uk_price': 'N/A', 'nl_price': 'N/A', 'acceleration_0-100km/h': '12.0 sec', 'top_speed': '160 km/h', 'range': '205 km', 'efficiency': '293 Wh/km', 'fastcharge': '300 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since January 2022'}
# {'name': 'OpelVivaro-e Combi M 50 kWh', 'de_price': '€50,992', 'uk_price': '£36,995', 'nl_price': '€48,108', 'acceleration_0-100km/h': '12.1 sec', 'top_speed': '130 km/h', 'range': '185 km', 'efficiency': '250 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since October 2020'}
# {'name': 'ToyotaPROACE Shuttle M 50 kWh', 'de_price': 'N/A', 'uk_price': 'N/A', 'nl_price': '€58,895', 'acceleration_0-100km/h': '12.1 sec', 'top_speed': '130 km/h', 'range': '185 km', 'efficiency': '250 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since June 2021'}
# {'name': 'Citroene-SpaceTourer XL 50 kWh', 'de_price': '€54,430', 'uk_price': '£37,885', 'nl_price': '€59,019', 'acceleration_0-100km/h': '12.1 sec', 'top_speed': '130 km/h', 'range': '180 km', 'efficiency': '257 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since November 2020'}
# {'name': 'FiatE-Ulysse L2 75 kWh', 'de_price': '€61,990', 'uk_price': 'N/A', 'nl_price': 'N/A', 'acceleration_0-100km/h': '13.3 sec', 'top_speed': '130 km/h', 'range': '265 km', 'efficiency': '257 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since June 2022'}
# {'name': 'OpelVivaro-e Combi L 75 kWh', 'de_price': '€57,775', 'uk_price': 'N/A', 'nl_price': '€59,059', 'acceleration_0-100km/h': '13.3 sec', 'top_speed': '130 km/h', 'range': '260 km', 'efficiency': '262 Wh/km', 'fastcharge': '280 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since October 2020'}
# {'name': 'PorscheTaycan 4S Sport Turismo', 'de_price': '€114,559', 'uk_price': '£91,700', 'nl_price': '€121,463', 'acceleration_0-100km/h': '4.0 sec', 'top_speed': '250 km/h', 'range': '370 km', 'efficiency': '192 Wh/km', 'fastcharge': '910 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since March 2022'}
# {'name': 'Peugeote-Expert Combi Standard 50 kWh', 'de_price': '€51,940', 'uk_price': 'N/A', 'nl_price': '€48,353', 'acceleration_0-100km/h': '13.1 sec', 'top_speed': '130 km/h', 'range': '185 km', 'efficiency': '250 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since February 2021'}
# {'name': 'MercedesEQV 250 Extra-Long', 'de_price': '€68,949', 'uk_price': 'N/A', 'nl_price': 'N/A', 'acceleration_0-100km/h': '12.0 sec', 'top_speed': '160 km/h', 'range': '210 km', 'efficiency': '286 Wh/km', 'fastcharge': '200 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since October 2021'}
# {'name': 'PorscheTaycan Turbo Sport Turismo', 'de_price': '€165,372', 'uk_price': '£126,800', 'nl_price': '€172,863', 'acceleration_0-100km/h': '3.2 sec', 'top_speed': '260 km/h', 'range': '405 km', 'efficiency': '207 Wh/km', 'fastcharge': '1000 km/h', 'towing_capacity(kg)': '', 'availability': 'Available to order since March 2022'}
# {'name': 'OpelVivaro-e Combi L 50 kWh', 'de_price': '€51,825', 'uk_price': '£37,835', 'nl_price': '€50,044', 'acceleration_0-100km/h': '12.1 sec', 'top_speed': '130 km/h', 'range': '180 km', 'efficiency': '257 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since October 2020'}
# {'name': 'OpelZafira-e Life L 50 kWh', 'de_price': '€64,075', 'uk_price': '£43,575', 'nl_price': '€59,119', 'acceleration_0-100km/h': '12.1 sec', 'top_speed': '130 km/h', 'range': '180 km', 'efficiency': '257 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since November 2020'}
# {'name': 'Peugeote-Traveller Long 50 kWh', 'de_price': '€54,430', 'uk_price': '£43,625', 'nl_price': '€59,364', 'acceleration_0-100km/h': '13.1 sec', 'top_speed': '130 km/h', 'range': '185 km', 'efficiency': '250 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since November 2020'}
# {'name': 'ToyotaPROACE Shuttle L 75 kWh', 'de_price': 'N/A', 'uk_price': 'N/A', 'nl_price': '€69,795', 'acceleration_0-100km/h': '13.1 sec', 'top_speed': '130 km/h', 'range': '260 km', 'efficiency': '262 Wh/km', 'fastcharge': '280 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since June 2021'}
# {'name': 'OpelZafira-e Life M 75 kWh', 'de_price': '€69,250', 'uk_price': 'N/A', 'nl_price': '€66,198', 'acceleration_0-100km/h': '13.3 sec', 'top_speed': '130 km/h', 'range': '265 km', 'efficiency': '257 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since February 2021'}
# {'name': 'FiatE-Ulysse L2 50 kWh', 'de_price': '€55,990', 'uk_price': 'N/A', 'nl_price': 'N/A', 'acceleration_0-100km/h': '12.1 sec', 'top_speed': '130 km/h', 'range': '185 km', 'efficiency': '250 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since June 2022'}
# {'name': 'FiatE-Ulysse L3 50 kWh', 'de_price': '€56,990', 'uk_price': 'N/A', 'nl_price': 'N/A', 'acceleration_0-100km/h': '12.1 sec', 'top_speed': '130 km/h', 'range': '180 km', 'efficiency': '257 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since June 2022'}
# {'name': 'Citroene-Jumpy Combi XL 50 kWh', 'de_price': '€52,730', 'uk_price': 'N/A', 'nl_price': '€49,944', 'acceleration_0-100km/h': '12.1 sec', 'top_speed': '130 km/h', 'range': '180 km', 'efficiency': '257 Wh/km', 'fastcharge': '290 km/h', 'towing_capacity(kg)': '1000', 'availability': 'Available to order since November 2020'}

# %%
data_wrappers = pd.DataFrame(cars_list)

data_wrappers
# Out:
#                                    name de_price uk_price nl_price  \
# 0    TeslaModel Y Long Range Dual Motor  €59,017  £52,990  €54,993
# 1                             BYDATTO 3  €44,625  £37,195  €42,998
# 2                          TeslaModel 3  €46,220  £39,990  €43,993
# 3    TeslaModel 3 Long Range Dual Motor  €55,220  £49,990  €51,993
# 4                          TeslaModel Y  €47,567  £44,990  €45,993
# ..                                  ...      ...      ...      ...
# 356       ToyotaPROACE Shuttle L 75 kWh      N/A      N/A  €69,795
# 357          OpelZafira-e Life M 75 kWh  €69,250      N/A  €66,198
# 358              FiatE-Ulysse L2 50 kWh  €55,990      N/A      N/A
# 359              FiatE-Ulysse L3 50 kWh  €56,990      N/A      N/A
# 360      Citroene-Jumpy Combi XL 50 kWh  €52,730      N/A  €49,944
#
#     acceleration_0-100km/h top_speed   range efficiency fastcharge  \
# 0                  5.0 sec  217 km/h  435 km  172 Wh/km   670 km/h
# 1                  7.3 sec  160 km/h  330 km  183 Wh/km   370 km/h
# 2                  6.1 sec  201 km/h  420 km  137 Wh/km   700 km/h
# 3                  4.4 sec  201 km/h  505 km  149 Wh/km   780 km/h
# 4                  6.9 sec  217 km/h  350 km  164 Wh/km   580 km/h
# ..                     ...       ...     ...        ...        ...
# 356               13.1 sec  130 km/h  260 km  262 Wh/km   280 km/h
# 357               13.3 sec  130 km/h  265 km  257 Wh/km   290 km/h
# 358               12.1 sec  130 km/h  185 km  250 Wh/km   290 km/h
# 359               12.1 sec  130 km/h  180 km  257 Wh/km   290 km/h
# 360               12.1 sec  130 km/h  180 km  257 Wh/km   290 km/h
#
#     towing_capacity(kg)                             availability
# 0                  1600   Available to order since February 2022
# 1                           Available to order since August 2022
# 2                  1000  Available to order since September 2023
# 3                  1000  Available to order since September 2023
# 4                  1600   Available to order since November 2022
# ..                  ...                                      ...
# 356                1000       Available to order since June 2021
# 357                1000   Available to order since February 2021
# 358                1000       Available to order since June 2022
# 359                1000       Available to order since June 2022
# 360                1000   Available to order since November 2020
#
# [361 rows x 11 columns]

# %%
csv_file_path = r'C:\Users\photo\Desktop\Ironhack\projects\EV-Market-Dynamics\data\scraping\ev-database_prices22_scraping.csv'
data_wrappers.to_csv(csv_file_path, index=False)
